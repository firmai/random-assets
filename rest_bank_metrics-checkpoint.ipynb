# %%
import pandas as pd
import numpy as np

full_review_play = pd.read_csv("full_review_play.csv").iloc[:,1:]

full_review_play = full_review_play.sort_values("closedate_ifclose")

### This one looks just at the last few years, the effect is diminsihed
full_review_play_2 = full_review_play[full_review_play["year"]>2016]

full_review_new = full_review_play_2.drop(["business_id","name","year","state","closedate_ifclose"],axis=1).copy()

# %%
Y = full_review_new.pop("is_open")
Y = Y.astype(int)
X = full_review_new

X = X.drop(X.filter(regex="days|diffs").columns,axis=1)
X["diffs_mean"] = full_review_new["diffs_mean"]
X["days_mean"] = full_review_new["days_mean"]
#X["lat_long"] = full_review_new["latitude"] + full_review_new["longitude"]

# %%
Y.value_counts()
# Out:
# 1    33471
# 0     2867
# Name: is_open, dtype: int64

# %%
#full_review_s["days"] = full_review_s['yelping_since'] - datetime.now()

# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from sklearn.metrics import confusion_matrix,precision_recall_curve,auc,roc_auc_score,roc_curve,recall_score,classification_report,accuracy_score
import lightgbm as lgb

#X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33)
#########  X = X.iloc[:,lit]
train = 0.67
range_size = int(len(X)*train)
X_train, X_test, y_train, y_test = X.iloc[:range_size,:], X.iloc[range_size:,:], Y.iloc[:range_size], Y.iloc[range_size:]

d_train = lgb.Dataset(X_train, label=y_train)
d_test = lgb.Dataset(X_test, label=y_test)

# %%
# This is what I expect a human to get 
Y.sum()/(Y.count())

#from lightgbm import LGBMClassifier


params = {
    "max_bin": 512,
    "learning_rate": 0.05,
    "boosting_type": "gbdt",
    "objective": "binary",
    "metric": "binary_logloss",
    "num_leaves": 10,
    "verbose": -1,
    "min_data": 100,
    "boost_from_average": True
}

#model = lgb.train(params, d_train, 10000, valid_sets=[d_test], early_stopping_rounds=50, verbose_eval=1000)

model_full = lgb.train(params, d_train, 10000, valid_sets=[d_test], early_stopping_rounds=50, verbose_eval=1000)
# Out:
# Training until validation scores don't improve for 50 rounds.
# [1000]	valid_0's binary_logloss: 0.141131
# Early stopping, best iteration is:
# [1813]	valid_0's binary_logloss: 0.137643

# %%
y_pred = model.predict(X_test)

# %%
y_pred = y_pred.round(0)
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test, y_pred)
# Out:
# 0.7204463840970192

# %%
### As you rightly thought permutation took extremely long, so you would leave it for later.

import numpy as np
from eli5.permutation_importance import get_score_importances

# ... load data, define score function
def score(X, Y):
    y_pred = model.predict(X)
    #y_pred = y_pred.round(0)
    return roc_auc_score(Y, y_pred)

base_score, score_decreases = get_score_importances(score, X.iloc[:,:4].as_matrix(), Y.as_matrix())
feature_importances = np.mean(score_decreases, axis=0)

score_decreases

feature_importances

# %%
#### Here you would do some form of permutation test
# Author:  Alexandre Gramfort <alexandre.gramfort@inria.fr>
# License: BSD 3 clause

print(__doc__)

import numpy as np
import matplotlib.pyplot as plt

from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import permutation_test_score
from sklearn import datasets
# Out:
# Automatically created module for IPython interactive environment

# %%
X.shape
# Out:
# (36338, 408)

# %%
from lightgbm import LGBMClassifier

cv = LGBMClassifier(boosting_type='gbdt', objective='binary',
                       num_class=1,early_stopping = 50, metric="binary_logloss",
                       is_enable_sparse='true',tree_learner='data',num_leaves=31,num_iteration=10000,min_data_in_leaf=100,max_depth=14,
                       learning_rate=0.06, n_estimators=1000, max_bin=512, 
                       min_split_gain=5, min_child_weight=5, min_child_samples=5, subsample=0.995, 
                       subsample_freq=1, colsample_bytree=1, reg_alpha=0, 
                       reg_lambda=0, seed=0, nthread=-1, num_leaves=10, min_data=100 silent=True,)

#cv.fit(X_train, y_train, eval_set=[(X_train, y_train)],eval_metric='AUC', early_stopping_rounds=5)


# Some noisy data not correlated
random = np.random.RandomState(seed=0)
E = random.normal(size=(len(X), 2200))
n_classes = np.unique(Y).size

# Add noisy data to the informative features for make the task harder
X_2 = np.c_[X.as_matrix(), E]

#svm = SVC(kernel='linear')
cv = StratifiedKFold(2)

score, permutation_scores, pvalue = permutation_test_score(
    cv, X_2, Y, scoring="accuracy", cv=cv, n_permutations=100, n_jobs=1)

print("Classification score %s (pvalue : %s)" % (score, pvalue))

# #############################################################################
# View histogram of permutation scores
plt.hist(permutation_scores, 20, label='Permutation scores',
         edgecolor='black')
ylim = plt.ylim()
# BUG: vlines(..., linestyle='--') fails on older versions of matplotlib
# plt.vlines(score, ylim[0], ylim[1], linestyle='--',
#          color='g', linewidth=3, label='Classification Score'
#          ' (pvalue %s)' % pvalue)
# plt.vlines(1.0 / n_classes, ylim[0], ylim[1], linestyle='--',
#          color='k', linewidth=3, label='Luck')
plt.plot(2 * [score], ylim, '--g', linewidth=3,
         label='Classification Score'
         ' (pvalue %s)' % pvalue)
plt.plot(2 * [1. / n_classes], ylim, '--k', linewidth=3, label='Luck')

plt.ylim(ylim)
plt.legend()
plt.xlabel('Score')
plt.show()

# %%
#y_pred = model.predict(X_test)

y_pred = model_full.predict(X_test)

drap = y_test.to_frame()

drap["pred"] = y_pred

drap["tail"] = drap["is_open"] - drap["pred"]

full_review_new.iloc[16973,:]

drap[drap["is_open"]==0]

drap["other"] = 1-drap["pred"]

new = drap[["other","pred"]].as_matrix()

# %%
#wodel = model

# %%
# %matplotlib notebook
#y_pred_proba = model.predict_proba(X_test)
#accuracy_score(y_test, y_pred)

import matplotlib.pyplot as plt
import scikitplot as skplt

skplt.metrics.plot_roc_curve(drap["is_open"], new)

plt.figure(figsize=(40, 36))


plt.show()

ga = pd.DataFrame()

ga["name"] = X.columns
ga["imp"] = model.feature_importance()
print(accuracy_score(y_test, y_pred.round(0)))
pd.set_option("display.max_rows",None)
# Out:
# <img src="data:image/png;base64,..." width="541">
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: The spectral and spectral_r colormap was deprecated in version 2.0. Use nipy_spectral and nipy_spectral_r instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# <img src="data:image/png;base64,..." width="2880">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-193-34993d94abdd> in <module>()
#      16
#      17 ga["name"] = X.columns
# ---> 18 ga["imp"] = model.feature_importance()
#      19 print(accuracy_score(y_test, y_pred.round(0)))
#      20 pd.set_option("display.max_rows",None)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2583
#    2584         self._ensure_valid_index(value)
# -> 2585         value = self._sanitize_column(key, value)
#    2586         NDFrame._set_item(self, key, value)
#    2587
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    2758
#    2759             # turn me into an ndarray
# -> 2760             value = _sanitize_index(value, self.index, copy=False)
#    2761             if not isinstance(value, (np.ndarray, Index)):
#    2762                 if isinstance(value, list) and len(value) > 0:
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/series.py in _sanitize_index(data, index, copy)
#    3119
#    3120     if len(data) != len(index):
# -> 3121         raise ValueError('Length of values does not match length of ' 'index')
#    3122
#    3123     if isinstance(data, PeriodIndex):
#
# ValueError: Length of values does not match length of index

# %%
ga = ga.sort_values("imp",ascending=False)

# %%
ga
# Out:
#                                      name  imp
# 32                         first_sent_std  327
# 56                          oldest_review  299
# 74                     average_stars_mean  284
# 75                      average_stars_std  272
# 135                   first_min_last_sent  261
# 33                          last_sent_std  248
# 39                            useful_mean  246
# 31                         last_sent_mean  245
# 121                     Female Importance  230
# 5                              gender_std  223
# 134                        friends/review  223
# 110                      elite_count_mean  222
# 51                               latitude  215
# 30                        first_sent_mean  214
# 111                       elite_count_std  213
# 114                                Female  203
# 117                           Connoisseur  200
# 59                      stars_linear_coef  196
# 36                             useful_std  195
# 118                     Food Aestheticist  192
# 61                     restaurant_density  177
# 63                      zreview_count_all  177
# 0                              rating_std  177
# 26                     senti_polarity_min  176
# 25                     senti_polarity_std  173
# 64                   zreview_per_week_all  173
# 34                         first_sent_sum  168
# 46                               cool_std  160
# 38                             useful_sum  158
# 200        zreview_per_week_all_chain_avg  157
# 28                    senti_polarity_mean  156
# 41                              funny_std  156
# 29                     senti_polarity_max  151
# 116                           Low Network  151
# 35                          last_sent_sum  151
# 27                     senti_polarity_sum  146
# 49                              cool_mean  143
# 73                      average_stars_sum  142
# 44                             funny_mean  141
# 270         first_min_last_sent_chain_avg  140
# 23                  review_count_usr_mean  138
# 72                               fans_std  137
# 192               oldest_review_chain_avg  137
# 191            reviews_per_week_chain_avg  135
# 55                       reviews_per_week  134
# 112                        Male to Female  134
# 24                   review_count_usr_max  134
# 115                          High Network  133
# 2                              rating_sum  132
# 8                             gender_mean  130
# 199           zreview_count_all_chain_avg  123
# 168              first_sent_std_chain_avg  121
# 60                     reactions_per_week  121
# 80                   compliment_more_mean  117
# 14                       friend_count_max  115
# 113                                  Male  112
# 10                       friend_count_std  111
# 96                   compliment_plain_std  111
# 12                       friend_count_sum  107
# 187                    latitude_chain_avg  102
# 20                   review_count_usr_std  102
# 406                              lat_long  101
# 52                              longitude  101
# 246             elite_count_std_chain_avg   99
# 13                      friend_count_mean   99
# 71                              fans_mean   98
# 57                           std_of_stars   97
# 180                  funny_mean_chain_avg   96
# 141                  gender_std_chain_avg   95
# 105                 compliment_writer_std   94
# 175                 useful_mean_chain_avg   93
# 15                        photo_count_std   93
# 18                       photo_count_mean   92
# 83                compliment_profile_mean   92
# 120                           First Visit   92
# 162          senti_polarity_min_chain_avg   92
# 95                  compliment_plain_mean   91
# 201                   zstar_all_chain_avg   90
# 182                    cool_std_chain_avg   86
# 86                   compliment_cute_mean   86
# 167              last_sent_mean_chain_avg   86
# 91                    compliment_note_sum   82
# 22                   review_count_usr_sum   81
# 122              Average Customer Network   80
# 77                    compliment_hot_mean   79
# 65                              zstar_all   79
# 210           average_stars_std_chain_avg   78
# 104                compliment_writer_mean   78
# 157        review_count_usr_min_chain_avg   77
# 166             first_sent_mean_chain_avg   77
# 48                               cool_sum   76
# 252                 Connoisseur_chain_avg   75
# 109                       elite_count_sum   75
# 62             restaurant_similar_density   75
# 87                    compliment_cute_std   74
# 195           stars_linear_coef_chain_avg   74
# 256           Female Importance_chain_avg   73
# 3                             rating_mean   73
# 196          reactions_per_week_chain_avg   73
# 89                   compliment_list_mean   73
# 93                    compliment_note_std   72
# 81                    compliment_more_std   72
# 40                            useful_amax   72
# 43                              funny_sum   71
# 84                 compliment_profile_std   70
# 164         senti_polarity_mean_chain_avg   70
# 249                      Female_chain_avg   69
# 169               last_sent_std_chain_avg   68
# 172                  useful_std_chain_avg   68
# 17                        photo_count_sum   68
# 177                   funny_std_chain_avg   68
# 161          senti_polarity_std_chain_avg   68
# 136                  rating_std_chain_avg   66
# 21                   review_count_usr_min   66
# 119                               Patrons   64
# 253           Food Aestheticist_chain_avg   63
# 99                    compliment_cool_std   63
# 7                              gender_sum   63
# 245            elite_count_mean_chain_avg   62
# 198  restaurant_similar_density_chain_avg   62
# 103                 compliment_writer_sum   60
# 92                   compliment_note_mean   60
# 165          senti_polarity_max_chain_avg   59
# 244             elite_count_sum_chain_avg   58
# 90                    compliment_list_std   58
# 176                 useful_amax_chain_avg   58
# 209          average_stars_mean_chain_avg   57
# 188                   longitude_chain_avg   56
# 250                High Network_chain_avg   55
# 70                               fans_sum   55
# 181                  funny_amax_chain_avg   54
# 88                    compliment_list_sum   52
# 247              Male to Female_chain_avg   51
# 185                   cool_mean_chain_avg   51
# 98                   compliment_cool_mean   51
# 190            count_categories_chain_avg   50
# 79                    compliment_more_sum   50
# 54                       count_categories   50
# 76                     compliment_hot_sum   49
# 336                   zstar_all_chain_std   49
# 94                   compliment_plain_sum   49
# 19                        photo_count_max   49
# 269              friends/review_chain_avg   48
# 97                    compliment_cool_sum   47
# 146            friend_count_std_chain_avg   47
# 254                     Patrons_chain_avg   46
# 144                 gender_mean_chain_avg   46
# 193                std_of_stars_chain_avg   45
# 159       review_count_usr_mean_chain_avg   44
# 150            friend_count_max_chain_avg   44
# 78                     compliment_hot_std   44
# 186                   cool_amax_chain_avg   43
# 197          restaurant_density_chain_avg   41
# 323                   longitude_chain_std   40
# 218     compliment_profile_mean_chain_avg   39
# 179                   funny_sum_chain_avg   39
# 143                  gender_sum_chain_avg   39
# 251                 Low Network_chain_avg   39
# 50                              cool_amax   38
# 219      compliment_profile_std_chain_avg   38
# 82                 compliment_profile_sum   37
# 124                   Number of Reviewers   37
# 85                    compliment_cute_sum   36
# 171               last_sent_sum_chain_avg   36
# 405         first_min_last_sent_chain_std   35
# 309                  useful_sum_chain_std   35
# 160        review_count_usr_max_chain_avg   35
# 207                    fans_std_chain_avg   34
# 248                        Male_chain_avg   34
# 206                   fans_mean_chain_avg   34
# 45                             funny_amax   34
# 156        review_count_usr_std_chain_avg   34
# 125                     Convenience Level   34
# 257    Average Customer Network_chain_avg   33
# 255                 First Visit_chain_avg   33
# 319                    cool_sum_chain_std   33
# 234         compliment_cool_std_chain_avg   33
# 174                  useful_sum_chain_avg   33
# 149           friend_count_mean_chain_avg   33
# 131                          Bike Parking   32
# 153             photo_count_sum_chain_avg   32
# 216         compliment_more_std_chain_avg   30
# 154            photo_count_mean_chain_avg   30
# 225         compliment_list_std_chain_avg   30
# 231        compliment_plain_std_chain_avg   29
# 148            friend_count_sum_chain_avg   29
# 163          senti_polarity_sum_chain_avg   28
# 138                  rating_sum_chain_avg   28
# 291        review_count_usr_std_chain_std   27
# 307                  useful_std_chain_std   27
# 260           Convenience Level_chain_avg   27
# 217      compliment_profile_sum_chain_avg   27
# 213          compliment_hot_std_chain_avg   26
# 229        compliment_plain_sum_chain_avg   26
# 226         compliment_note_sum_chain_avg   26
# 224        compliment_list_mean_chain_avg   25
# 304               last_sent_std_chain_std   25
# 155             photo_count_max_chain_avg   25
# 325            count_categories_chain_std   25
# 239      compliment_writer_mean_chain_avg   25
# 137                  rating_min_chain_avg   25
# 228         compliment_note_std_chain_avg   24
# 230       compliment_plain_mean_chain_avg   24
# 212         compliment_hot_mean_chain_avg   24
# 380            elite_count_mean_chain_std   24
# 170              first_sent_sum_chain_avg   23
# 227        compliment_note_mean_chain_avg   23
# 222         compliment_cute_std_chain_avg   23
# 345           average_stars_std_chain_std   22
# 259         Number of Reviewers_chain_avg   22
# 221        compliment_cute_mean_chain_avg   22
# 266                Bike Parking_chain_avg   21
# 223         compliment_list_sum_chain_avg   21
# 322                    latitude_chain_std   21
# 334           zreview_count_all_chain_std   20
# 133                      review_count_loc   20
# 305              first_sent_sum_chain_std   19
# 220         compliment_cute_sum_chain_avg   19
# 317                    cool_std_chain_std   19
# 158        review_count_usr_sum_chain_avg   19
# 295        review_count_usr_max_chain_std   18
# 240       compliment_writer_std_chain_avg   18
# 382              Male to Female_chain_std   18
# 302              last_sent_mean_chain_std   17
# 184                    cool_sum_chain_avg   17
# 368        compliment_cool_mean_chain_std   17
# 390                 First Visit_chain_std   17
# 332          restaurant_density_chain_std   16
# 335        zreview_per_week_all_chain_std   16
# 344          average_stars_mean_chain_std   16
# 215        compliment_more_mean_chain_avg   16
# 128                       Outdoor Seating   16
# 276                  gender_std_chain_std   15
# 139                 rating_mean_chain_avg   15
# 326            reviews_per_week_chain_std   15
# 329             median_of_stars_chain_std   15
# 274                 rating_mean_chain_std   15
# 208           average_stars_sum_chain_avg   15
# 303              first_sent_std_chain_std   15
# 391           Female Importance_chain_std   14
# 401                Bike Parking_chain_std   14
# 340                    fans_sum_chain_std   13
# 238       compliment_writer_sum_chain_avg   13
# 211          compliment_hot_sum_chain_avg   13
# 11                       friend_count_min   13
# 205                    fans_sum_chain_avg   13
# 315                  funny_mean_chain_std   12
# 232         compliment_cool_sum_chain_avg   12
# 369         compliment_cool_std_chain_std   12
# 151             photo_count_std_chain_avg   12
# 384                      Female_chain_std   11
# 214         compliment_more_sum_chain_avg   11
# 296          senti_polarity_std_chain_std   11
# 289            photo_count_mean_chain_std   10
# 389                     Patrons_chain_std   10
# 275                  rating_max_chain_std   10
# 387                 Connoisseur_chain_std   10
# 279                 gender_mean_chain_std   10
# 394         Number of Reviewers_chain_std   10
# 404              friends/review_chain_std   10
# 363         compliment_note_std_chain_std    9
# 233        compliment_cool_mean_chain_avg    9
# 392    Average Customer Network_chain_std    9
# 330           stars_linear_coef_chain_std    9
# 312                   funny_std_chain_std    9
# 285            friend_count_max_chain_std    9
# 300          senti_polarity_max_chain_std    9
# 281            friend_count_std_chain_std    8
# 268            review_count_loc_chain_avg    8
# 58                        median_of_stars    7
# 356        compliment_cute_mean_chain_std    7
# 367         compliment_cool_sum_chain_std    7
# 381             elite_count_std_chain_std    7
# 331          reactions_per_week_chain_std    7
# 328                std_of_stars_chain_std    7
# 361         compliment_note_sum_chain_std    6
# 383                        Male_chain_std    6
# 350        compliment_more_mean_chain_std    6
# 290             photo_count_max_chain_std    6
# 284           friend_count_mean_chain_std    6
# 358         compliment_list_sum_chain_std    5
# 53                             rating_pub    5
# 327               oldest_review_chain_std    5
# 288             photo_count_sum_chain_std    5
# 314                   funny_sum_chain_std    5
# 373       compliment_writer_sum_chain_std    5
# 310                 useful_mean_chain_std    5
# 349         compliment_more_sum_chain_std    5
# 292        review_count_usr_min_chain_std    5
# 282            friend_count_min_chain_std    5
# 130                                Caters    5
# 194             median_of_stars_chain_avg    5
# 271                  rating_std_chain_std    4
# 320                   cool_mean_chain_std    4
# 366        compliment_plain_std_chain_std    4
# 364        compliment_plain_sum_chain_std    4
# 189                  rating_pub_chain_avg    4
# 316                  funny_amax_chain_std    4
# 298          senti_polarity_sum_chain_std    4
# 306               last_sent_sum_chain_std    4
# 278                  gender_sum_chain_std    4
# 346          compliment_hot_sum_chain_std    4
# 386                 Low Network_chain_std    3
# 265                      Caters_chain_avg    3
# 263             Outdoor Seating_chain_avg    3
# 395           Convenience Level_chain_std    3
# 379             elite_count_sum_chain_std    3
# 147            friend_count_min_chain_avg    3
# 333  restaurant_similar_density_chain_std    3
# 321                   cool_amax_chain_std    3
# 341                   fans_mean_chain_std    3
# 342                    fans_std_chain_std    3
# 343           average_stars_sum_chain_std    3
# 273                  rating_sum_chain_std    3
# 357         compliment_cute_std_chain_std    3
# 283            friend_count_sum_chain_std    3
# 385                High Network_chain_std    2
# 286             photo_count_std_chain_std    2
# 351         compliment_more_std_chain_std    2
# 353     compliment_profile_mean_chain_std    2
# 355         compliment_cute_sum_chain_std    2
# 348          compliment_hot_std_chain_std    2
# 365       compliment_plain_mean_chain_std    2
# 294       review_count_usr_mean_chain_std    2
# 301             first_sent_mean_chain_std    2
# 297          senti_polarity_min_chain_std    2
# 311                 useful_amax_chain_std    2
# 403            review_count_loc_chain_std    2
# 375       compliment_writer_std_chain_std    1
# 324                  rating_pub_chain_std    1
# 299         senti_polarity_mean_chain_std    1
# 140                  rating_max_chain_avg    1
# 388           Food Aestheticist_chain_std    1
# 37                            useful_amin    1
# 360         compliment_list_std_chain_std    1
# 362        compliment_note_mean_chain_std    1
# 374      compliment_writer_mean_chain_std    1
# 204                   stars_std_chain_avg    0
# 173                 useful_amin_chain_avg    0
# 370        compliment_funny_sum_chain_std    0
# 16                        photo_count_min    0
# 371       compliment_funny_mean_chain_std    0
# 132                                 Noisy    0
# 372        compliment_funny_std_chain_std    0
# 1                              rating_min    0
# 66                               is_chain    0
# 9                              gender_max    0
# 402                       Noisy_chain_std    0
# 397          Takes Reservations_chain_std    0
# 152             photo_count_min_chain_avg    0
# 393               Total Network_chain_std    0
# 145                  gender_max_chain_avg    0
# 396                  Free Wi-Fi_chain_std    0
# 142                  gender_min_chain_avg    0
# 6                              gender_min    0
# 4                              rating_max    0
# 400                      Caters_chain_std    0
# 202                   stars_sum_chain_avg    0
# 398             Outdoor Seating_chain_std    0
# 378       compliment_photos_std_chain_std    0
# 377      compliment_photos_mean_chain_std    0
# 376       compliment_photos_sum_chain_std    0
# 399                    Delivery_chain_std    0
# 183                   cool_amin_chain_avg    0
# 287             photo_count_min_chain_std    0
# 235        compliment_funny_sum_chain_avg    0
# 313                  funny_amin_chain_std    0
# 101                 compliment_funny_mean    0
# 258               Total Network_chain_avg    0
# 68                             stars_mean    0
# 261                  Free Wi-Fi_chain_avg    0
# 69                              stars_std    0
# 318                   cool_amin_chain_std    0
# 262          Takes Reservations_chain_avg    0
# 264                    Delivery_chain_avg    0
# 267                       Noisy_chain_avg    0
# 236       compliment_funny_mean_chain_avg    0
# 100                  compliment_funny_sum    0
# 308                 useful_amin_chain_std    0
# 47                              cool_amin    0
# 272                  rating_min_chain_std    0
# 277                  gender_min_chain_std    0
# 280                  gender_max_chain_std    0
# 293        review_count_usr_sum_chain_std    0
# 178                  funny_amin_chain_avg    0
# 102                  compliment_funny_std    0
# 106                 compliment_photos_sum    0
# 107                compliment_photos_mean    0
# 108                 compliment_photos_std    0
# 359        compliment_list_mean_chain_std    0
# 237        compliment_funny_std_chain_avg    0
# 241       compliment_photos_sum_chain_avg    0
# 354      compliment_profile_std_chain_std    0
# 352      compliment_profile_sum_chain_std    0
# 242      compliment_photos_mean_chain_avg    0
# 243       compliment_photos_std_chain_avg    0
# 347         compliment_hot_mean_chain_std    0
# 129                              Delivery    0
# 127                    Takes Reservations    0
# 339                   stars_std_chain_std    0
# 338                  stars_mean_chain_std    0
# 337                   stars_sum_chain_std    0
# 67                              stars_sum    0
# 126                            Free Wi-Fi    0
# 123                         Total Network    0
# 42                             funny_amin    0
# 203                  stars_mean_chain_avg    0

# %%
import shap
shap_values = shap.TreeExplainer(model).shap_values(X)

# %%
cat = pd.DataFrame(shap_values[0:,:-1], columns = list(X.columns)).sum().to_frame().sort_values(0,ascending=False)

# %%
cat = pd.DataFrame(shap_values[0:,:-1], columns = list(X.columns)).sum().to_frame().sort_values(0,ascending=False)
# Out:
#                                                 0
# oldest_review_chain_avg               1257.783115
# review_count_usr_sum                  1085.682832
# oldest_review                          856.551979
# compliment_plain_sum                   849.654029
# compliment_writer_std                  843.126423
# compliment_cool_std                    728.170548
# friend_count_sum                       665.989954
# zreview_count_all_chain_avg            631.179991
# average_stars_sum                      585.602765
# senti_polarity_mean_chain_avg          545.961602
# Female                                 538.938287
# elite_count_std                        494.787401
# elite_count_sum                        478.352092
# fans_mean                              459.183956
# compliment_writer_mean                 457.253191
# review_count_usr_std                   452.711267
# Male_chain_avg                         382.117895
# Connoisseur                            371.714435
# reviews_per_week_chain_avg             371.556655
# friend_count_std                       367.734334
# Male                                   347.246403
# Number of Reviewers_chain_avg          319.669353
# rating_sum_chain_avg                   306.549155
# compliment_cute_mean                   295.585986
# longitude                              293.351875
# stars_linear_coef                      287.796979
# cool_amax                              286.607314
# senti_polarity_std                     281.793084
# funny_sum                              281.416609
# review_count_usr_sum_chain_avg         281.040064
# compliment_more_std_chain_avg          277.886624
# compliment_profile_mean_chain_avg      274.404671
# senti_polarity_max_chain_avg           270.285013
# compliment_plain_std_chain_avg         267.274244
# review_count_usr_max                   259.970464
# Food Aestheticist                      256.367735
# funny_mean                             254.892514
# compliment_hot_sum_chain_avg           252.234596
# average_stars_sum_chain_avg            242.010654
# compliment_list_mean                   236.822609
# compliment_cute_sum_chain_avg          236.708070
# average_stars_mean_chain_std           233.285944
# last_sent_std_chain_avg                229.677692
# compliment_plain_mean                  220.725912
# elite_count_sum_chain_avg              218.054762
# gender_sum_chain_avg                   218.038881
# Female_chain_avg                       216.120642
# compliment_hot_mean_chain_avg          204.767735
# gender_sum                             197.294195
# senti_polarity_min_chain_avg           197.050677
# std_of_stars                           195.825848
# senti_polarity_max                     187.544656
# compliment_more_mean_chain_std         186.155599
# zreview_count_all_chain_std            180.821950
# compliment_cool_std_chain_std          175.500724
# funny_std_chain_std                    173.584672
# first_min_last_sent_chain_avg          165.866875
# photo_count_mean                       165.292904
# compliment_plain_std                   165.197485
# compliment_cool_mean                   162.874588
# compliment_writer_mean_chain_avg       162.836697
# compliment_hot_sum                     159.723638
# average_stars_std                      159.425313
# cool_std_chain_std                     149.936278
# useful_std_chain_std                   147.882736
# Male_chain_std                         139.145365
# restaurant_density                     136.875164
# first_sent_std_chain_avg               133.613051
# gender_std_chain_std                   133.260970
# Low Network_chain_avg                  130.925909
# restaurant_similar_density_chain_avg   130.523214
# reactions_per_week_chain_std           128.192378
# first_sent_std                         118.879089
# useful_sum_chain_avg                   117.645187
# photo_count_max                        116.233587
# funny_sum_chain_avg                    116.178245
# useful_amax_chain_avg                  114.976432
# photo_count_max_chain_std              114.571674
# longitude_chain_std                    114.011669
# senti_polarity_sum_chain_std           112.590509
# gender_mean_chain_avg                  112.370500
# compliment_profile_sum_chain_avg       109.933229
# useful_mean                            109.282856
# zstar_all_chain_avg                    107.510593
# compliment_writer_std_chain_avg        106.735758
# Low Network_chain_std                  105.956218
# useful_amax_chain_std                  105.314716
# fans_sum_chain_std                     103.040761
# first_sent_mean_chain_avg               98.492511
# compliment_note_mean_chain_std          95.366408
# fans_std_chain_avg                      94.987335
# compliment_more_sum_chain_std           94.220120
# review_count_loc_chain_std              91.479706
# review_count_usr_max_chain_avg          90.707081
# First Visit_chain_avg                   89.869407
# Male to Female_chain_std                83.989752
# senti_polarity_sum                      81.315015
# reviews_per_week_chain_std              74.183928
# fans_mean_chain_std                     73.115379
# rating_max_chain_std                    71.874540
# elite_count_mean_chain_avg              70.201307
# average_stars_mean_chain_avg            69.942531
# first_sent_sum_chain_std                66.926468
# senti_polarity_sum_chain_avg            64.252640
# review_count_usr_mean_chain_std         62.389891
# cool_amax_chain_std                     58.228668
# compliment_plain_sum_chain_std          58.172941
# funny_std_chain_avg                     57.445233
# elite_count_std_chain_std               56.183902
# first_sent_sum_chain_avg                55.880507
# compliment_list_mean_chain_std          55.783665
# average_stars_std_chain_std             55.110715
# Female Importance_chain_std             53.141879
# first_sent_std_chain_std                52.242444
# cool_amax_chain_avg                     51.168312
# friend_count_max_chain_avg              50.280450
# cool_sum_chain_std                      47.385430
# photo_count_std_chain_std               47.173043
# reactions_per_week                      46.140260
# friend_count_sum_chain_std              45.397182
# compliment_more_sum                     44.133846
# latitude_chain_std                      43.113467
# Average Customer Network_chain_std      41.052212
# compliment_plain_mean_chain_std         40.989375
# compliment_list_sum_chain_std           38.904868
# Food Aestheticist_chain_std             37.987616
# compliment_plain_std_chain_std          36.884434
# std_of_stars_chain_std                  36.616878
# review_count_usr_min_chain_std          35.534689
# photo_count_sum_chain_std               34.610113
# compliment_plain_sum_chain_avg          33.522921
# Female Importance                       33.336741
# Caters_chain_avg                        32.551186
# stars_linear_coef_chain_std             32.049373
# median_of_stars_chain_avg               30.872880
# Outdoor Seating                         30.349542
# compliment_list_sum_chain_avg           29.674814
# Convenience Level_chain_avg             29.337236
# rating_std_chain_std                    28.622567
# median_of_stars                         28.091225
# Bike Parking_chain_avg                  27.611033
# Patrons_chain_std                       27.013709
# gender_mean                             24.301334
# compliment_writer_mean_chain_std        23.495352
# funny_std                               23.344099
# Connoisseur_chain_std                   23.000077
# restaurant_density_chain_std            21.734427
# senti_polarity_min_chain_std            21.523149
# useful_mean_chain_avg                   19.599136
# senti_polarity_max_chain_std            18.521757
# last_sent_sum_chain_avg                 18.202223
# Female Importance_chain_avg             16.378430
# rating_sum_chain_std                    16.325420
# Outdoor Seating_chain_avg               15.190371
# cool_sum_chain_avg                      14.702103
# friend_count_min                        14.412147
# compliment_more_std_chain_std           13.815391
# rating_mean_chain_std                   12.976162
# first_sent_mean_chain_std               11.726516
# compliment_cute_sum_chain_std           11.071637
# compliment_hot_mean_chain_std           10.784700
# Female_chain_std                        10.766581
# compliment_profile_sum_chain_std        10.641482
# compliment_cool_mean_chain_avg           9.374902
# last_sent_sum_chain_std                  8.886420
# friend_count_min_chain_avg               8.593490
# stars_std_chain_avg                      7.664455
# review_count_usr_max_chain_std           7.088957
# rating_min_chain_std                     7.083340
# High Network_chain_avg                   6.298794
# Caters                                   2.829484
# elite_count_mean_chain_std               1.822810
# fans_sum_chain_avg                       0.095170
# Free Wi-Fi_chain_avg                     0.000000
# Takes Reservations_chain_avg             0.000000
# Total Network                            0.000000
# Caters_chain_std                         0.000000
# Delivery_chain_avg                       0.000000
# Total Network_chain_avg                  0.000000
# Free Wi-Fi                               0.000000
# Noisy_chain_avg                          0.000000
# Delivery                                 0.000000
# Takes Reservations                       0.000000
# stars_mean                               0.000000
# photo_count_min                          0.000000
# Delivery_chain_std                       0.000000
# Outdoor Seating_chain_std                0.000000
# Takes Reservations_chain_std             0.000000
# compliment_photos_std_chain_avg          0.000000
# compliment_photos_mean_chain_avg         0.000000
# compliment_photos_sum_chain_avg          0.000000
# compliment_funny_std_chain_avg           0.000000
# compliment_funny_mean_chain_avg          0.000000
# compliment_funny_sum_chain_avg           0.000000
# stars_std_chain_std                      0.000000
# Noisy_chain_std                          0.000000
# stars_std                                0.000000
# Noisy                                    0.000000
# compliment_funny_std_chain_std           0.000000
# compliment_funny_mean_chain_std          0.000000
# compliment_photos_sum_chain_std          0.000000
# compliment_photos_mean_chain_std         0.000000
# cool_amin_chain_std                      0.000000
# rating_max                               0.000000
# funny_amin_chain_std                     0.000000
# compliment_funny_sum_chain_std           0.000000
# gender_min                               0.000000
# useful_amin_chain_std                    0.000000
# compliment_funny_sum                     0.000000
# compliment_funny_mean                    0.000000
# compliment_funny_std                     0.000000
# gender_max                               0.000000
# compliment_photos_std_chain_std          0.000000
# compliment_photos_sum                    0.000000
# compliment_photos_mean                   0.000000
# stars_sum_chain_std                      0.000000
# compliment_photos_std                    0.000000
# photo_count_min_chain_std                0.000000
# gender_max_chain_std                     0.000000
# stars_mean_chain_std                     0.000000
# gender_min_chain_std                     0.000000
# Free Wi-Fi_chain_std                     0.000000
# stars_mean_chain_avg                     0.000000
# is_chain                                 0.000000
# funny_amin_chain_avg                     0.000000
# funny_amin                               0.000000
# stars_sum                                0.000000
# gender_min_chain_avg                     0.000000
# cool_amin                                0.000000
# useful_amin                              0.000000
# gender_max_chain_avg                     0.000000
# cool_amin_chain_avg                      0.000000
# Total Network_chain_std                  0.000000
# stars_sum_chain_avg                      0.000000
# photo_count_min_chain_avg                0.000000
# useful_mean_chain_std                   -0.234939
# compliment_writer_std_chain_std         -0.677112
# compliment_writer_sum_chain_avg         -0.893658
# useful_amin_chain_avg                   -1.255145
# Number of Reviewers_chain_std           -1.640608
# Convenience Level_chain_std             -2.238939
# cool_std_chain_avg                      -2.512772
# zreview_per_week_all_chain_avg          -3.383995
# std_of_stars_chain_avg                  -3.823963
# review_count_usr_sum_chain_std          -4.228844
# rating_pub_chain_avg                    -4.974334
# oldest_review_chain_std                 -5.040258
# gender_sum_chain_std                    -5.271748
# compliment_hot_std_chain_std            -5.579914
# First Visit                             -6.026971
# friends/review_chain_std                -6.240327
# count_categories_chain_std              -9.609881
# rating_pub                             -10.409627
# friend_count_min_chain_std             -11.323288
# review_count_loc                       -11.716405
# rating_min_chain_avg                   -13.509126
# compliment_list_std_chain_avg          -13.862315
# funny_sum_chain_std                    -14.649451
# High Network_chain_std                 -15.154840
# fans_std_chain_std                     -15.293319
# compliment_hot_sum_chain_std           -15.443598
# cool_mean_chain_avg                    -15.688829
# count_categories                       -16.442336
# compliment_cute_mean_chain_avg         -16.616005
# compliment_note_sum_chain_std          -16.661586
# friend_count_mean_chain_avg            -17.066657
# compliment_list_std_chain_std          -17.925381
# Convenience Level                      -18.572321
# First Visit_chain_std                  -19.418105
# compliment_profile_sum                 -19.824091
# compliment_cool_sum_chain_std          -21.454258
# compliment_profile_mean_chain_std      -23.173702
# Bike Parking_chain_std                 -25.513377
# Patrons_chain_avg                      -25.832488
# rating_pub_chain_std                   -26.370181
# last_sent_std                          -27.249265
# cool_mean_chain_std                    -30.054527
# compliment_more_sum_chain_avg          -30.176140
# compliment_cool_std_chain_avg          -33.801384
# compliment_cute_std_chain_std          -34.317699
# compliment_profile_mean                -34.386859
# compliment_note_std_chain_avg          -34.399287
# review_count_usr_std_chain_avg         -34.427490
# Food Aestheticist_chain_avg            -35.483693
# latitude                               -36.756171
# elite_count_sum_chain_std              -38.772275
# compliment_cute_mean_chain_std         -38.983338
# rating_min                             -39.705075
# review_count_usr_std_chain_std         -40.059904
# longitude_chain_avg                    -40.548711
# compliment_writer_sum_chain_std        -40.953763
# compliment_hot_std_chain_avg           -41.585800
# friend_count_mean_chain_std            -42.311711
# review_count_loc_chain_avg             -42.586311
# friends/review_chain_avg               -43.268025
# senti_polarity_std_chain_avg           -43.690829
# friend_count_max_chain_std             -44.582502
# senti_polarity_std_chain_std           -45.480082
# compliment_plain_mean_chain_avg        -47.187737
# Average Customer Network_chain_avg     -49.621039
# friend_count_std_chain_avg             -50.015763
# restaurant_density_chain_avg           -50.510181
# friend_count_std_chain_std             -52.092309
# compliment_more_mean_chain_avg         -52.656579
# funny_mean_chain_avg                   -53.040210
# rating_max_chain_avg                   -56.128204
# funny_amax_chain_std                   -56.236865
# useful_std                             -56.872744
# rating_mean                            -58.092854
# useful_sum_chain_std                   -58.409267
# median_of_stars_chain_std              -61.183904
# stars_linear_coef_chain_avg            -62.779428
# compliment_note_std_chain_std          -64.543781
# cool_std                               -66.657195
# review_count_usr_min                   -70.382721
# compliment_cool_sum_chain_avg          -71.715620
# compliment_profile_std_chain_std       -72.885515
# rating_mean_chain_avg                  -73.231085
# Low Network                            -80.079538
# senti_polarity_mean                    -81.770473
# zstar_all                              -81.786491
# compliment_note_std                    -83.302661
# photo_count_sum_chain_avg              -88.039536
# reactions_per_week_chain_avg           -88.606120
# average_stars_sum_chain_std            -99.359512
# review_count_usr_min_chain_avg        -101.835717
# photo_count_mean_chain_avg            -102.498555
# last_sent_mean_chain_std              -105.007893
# restaurant_similar_density            -106.020854
# photo_count_std_chain_avg             -107.263983
# last_sent_std_chain_std               -116.000272
# senti_polarity_mean_chain_std         -118.726627
# first_min_last_sent_chain_std         -120.495553
# Bike Parking                          -120.617167
# count_categories_chain_avg            -121.998958
# compliment_hot_mean                   -124.493795
# first_min_last_sent                   -129.465790
# friend_count_mean                     -129.909120
# senti_polarity_min                    -130.853619
# Number of Reviewers                   -131.514256
# funny_mean_chain_std                  -132.052478
# zreview_per_week_all_chain_std        -137.631618
# rating_std_chain_avg                  -138.207064
# gender_mean_chain_std                 -148.775193
# friends/review                        -148.960561
# Male to Female_chain_avg              -151.036601
# last_sent_sum                         -151.181635
# friend_count_max                      -152.174388
# photo_count_sum                       -152.204094
# compliment_profile_std_chain_avg      -152.786959
# Male to Female                        -153.923234
# funny_amax                            -154.526430
# gender_std_chain_avg                  -161.831942
# compliment_list_std                   -164.086141
# useful_amax                           -169.115839
# Connoisseur_chain_avg                 -170.248370
# zstar_all_chain_std                   -177.437648
# elite_count_mean                      -185.739829
# Patrons                               -188.003842
# funny_amax_chain_avg                  -189.228369
# friend_count_sum_chain_avg            -195.740508
# compliment_list_sum                   -195.867775
# rating_std                            -196.487978
# average_stars_std_chain_avg           -197.966190
# compliment_note_mean_chain_avg        -198.005150
# useful_std_chain_avg                  -207.020828
# compliment_cute_std_chain_avg         -207.832433
# fans_sum                              -213.641440
# photo_count_max_chain_avg             -214.605916
# reviews_per_week                      -220.382382
# restaurant_similar_density_chain_std  -246.372241
# photo_count_mean_chain_std            -253.750229
# compliment_cute_std                   -259.181923
# Average Customer Network              -262.011213
# rating_sum                            -264.193279
# compliment_cute_sum                   -270.820740
# review_count_usr_mean                 -287.738698
# compliment_note_sum_chain_avg         -300.846250
# fans_mean_chain_avg                   -311.569148
# compliment_writer_sum                 -317.295782
# zreview_per_week_all                  -320.329928
# compliment_hot_std                    -320.948446
# average_stars_mean                    -328.551479
# zreview_count_all                     -328.910427
# compliment_more_std                   -351.606691
# compliment_list_mean_chain_avg        -364.880704
# compliment_cool_mean_chain_std        -374.192408
# latitude_chain_avg                    -408.454947
# High Network                          -413.021884
# review_count_usr_mean_chain_avg       -423.358211
# useful_sum                            -424.169958
# photo_count_std                       -445.047003
# first_sent_mean                       -447.244814
# cool_mean                             -491.960205
# cool_sum                              -524.883681
# compliment_note_sum                   -556.423845
# last_sent_mean                        -577.466779
# compliment_note_mean                  -585.114821
# first_sent_sum                        -591.906427
# compliment_profile_std                -594.524588
# last_sent_mean_chain_avg              -614.242866
# compliment_cool_sum                   -680.751154
# elite_count_std_chain_avg             -731.190474
# fans_std                              -752.365579
# compliment_more_mean                  -846.945155
# gender_std                           -1251.106312

# %%
cat["Direction"] = cat[0].apply(lambda x: "-" if x<0else "+")

# %%
shap = pd.DataFrame(shap_values[0:,:-1], columns = list(X.columns)).abs().sum().to_frame().sort_values(0,ascending=False)
shap.columns = ["Shap"]

# %%
shap["Shap Rank"] = shap['Shap'].rank(ascending=0)

# %%
shape = pd.merge(shap, cat["Direction"].to_frame(), right_index=True, left_index=True, how="left")

# %%
gainz = pd.read_excel("feats_inter_sans.xlsx")

# %%
gainz.head()
# Out:
#                Interaction         Gain  FScore    wFScore  Average wFScore  \
# 0               useful_sum  2910.823740     112  30.159502         0.269281
# 1  oldest_review_chain_avg  2844.021270      96  35.660975         0.371468
# 2            oldest_review  1598.369262     183  38.353424         0.209582
# 3        stars_linear_coef  1281.892154     141  19.815984         0.140539
# 4     zreview_per_week_all  1155.919067     105  18.291196         0.174202
#
#    Average Gain  Expected Gain  Gain Rank  FScore Rank  wFScore Rank  \
# 0     25.989498    1128.075191          1            3             3
# 1     29.625222    2423.644273          2           10             2
# 2      8.734258     478.671771          3            1             1
# 3      9.091434     281.268226          4            2             5
# 4     11.008753     274.541567          5            6             7
#
#    Avg wFScore Rank  Avg Gain Rank  Expected Gain Rank  Average Rank  \
# 0                 9              4                   2      3.666667
# 1                 5              3                   1      3.833333
# 2                13             24                   3      7.500000
# 3                24             23                   8     11.000000
# 4                17             18                   9     10.333333
#
#    Average Tree Index  Average Tree Depth
# 0           26.571429            3.383929
# 1           32.895833            3.166667
# 2           44.704918            4.295082
# 3           35.085106            4.347518
# 4           42.819048            4.000000

# %%
shape2 = pd.merge(shape, gainz.set_index("Interaction")[["Gain","Gain Rank"]], left_index=True, right_index=True, how="left")

# %%
shape2 = shape2.dropna(axis=0)

# %%
shape2["Shap Rank"] = shape2['Shap'].rank(ascending=0).astype(int)
shape2["Gain Rank"] = shape2['Gain'].rank(ascending=0).astype(int)

# %%
shape2["Shap"] = shape2["Shap"]/shape2["Shap"].max()
shape2["Gain"] = shape2["Gain"]/shape2["Gain"].max()

# %%
shape2["Shap"] = (shape2["Shap"]*100).astype(int)

# %%
shape2["Gain"] = shape2["Gain"].fillna(value=0)
shape2["Gain"] = (shape2["Gain"]*100).astype(int)

# %%
shape2.columns
# Out:
# Index(['Shap', 'Shap Rank', 'Direction', 'Gain', 'Gain Rank'], dtype='object')

# %%
#shape3 = pd.merge(shape2, ga.set_index("name"), left_index=True, right_index=True, how="left")

# %%
shape3 = pd.merge(shape2, vat["relevant"].to_frame(), left_index=True, right_index=True, how="left")

# %%
shape3
# Out:
#                                  Shap  Shap Rank Direction  Gain  Gain Rank  \
# oldest_review                     100          1         +    54          3
# oldest_review_chain_avg            86          2         +    97          2
# useful_mean                        51          3         +    25          9
# stars_linear_coef                  50          4         +    44          4
# useful_sum                         49          5         -   100          1
# gender_std                         43          6         -     9         50
# restaurant_density                 42          7         +    24         11
# Connoisseur                        39          8         +    21         14
# rating_sum                         38          9         -     7         77
# reviews_per_week                   37         10         -    16         21
# latitude                           33         11         -    19         16
# zreview_count_all                  33         12         -    23         12
# average_stars_mean                 32         13         -    20         15
# zstar_all_chain_std                32         14         -    17         20
# elite_count_mean                   31         15         -    12         37
# first_sent_mean                    31         16         -    14         31
# Male to Female                     30         17         -    10         44
# first_sent_std_chain_avg           29         18         +    18         17
# zreview_per_week_all               29         19         -    39          5
# elite_count_std                    29         20         +    15         24
# zreview_count_all_chain_avg        25         21         +    25         10
# rating_std                         25         22         -    14         33
# reviews_per_week_chain_avg         25         23         +    11         38
# first_sent_std                     24         24         +    15         26
# last_sent_std                      23         25         -    15         23
# funny_std                          22         26         +     8         70
# useful_mean_chain_avg              22         27         +    18         18
# last_sent_sum                      21         28         -     7         81
# average_stars_std                  21         29         +    14         29
# review_count_usr_mean              21         30         -     7         82
# High Network                       20         31         -     9         49
# Food Aestheticist                  20         32         +    14         32
# friends/review                     20         33         -    13         34
# Female                             20         34         +     9         51
# latitude_chain_avg                 20         35         -     8         64
# senti_polarity_mean                19         36         -     8         61
# first_sent_sum                     19         37         -    30          8
# zstar_all_chain_avg                19         38         +    15         27
# zreview_per_week_all_chain_avg     19         39         -    30          6
# last_sent_mean                     18         40         -     7         78
# useful_std                         18         41         -     5         97
# average_stars_std_chain_avg        17         42         -     6         94
# first_min_last_sent_chain_avg      17         43         +     9         52
# senti_polarity_std                 17         44         +    18         19
# longitude                          17         45         +    12         36
# cool_std                           17         46         -     9         58
# elite_count_std_chain_avg          17         47         -    10         46
# restaurant_similar_density         16         48         -     6         92
# senti_polarity_min                 16         49         -    11         42
# first_min_last_sent                16         50         -    15         22
# elite_count_sum                    16         51         +     8         69
# last_sent_mean_chain_avg           16         52         -     7         80
# cool_mean                          15         53         -     7         79
# senti_polarity_min_chain_avg       15         54         +     9         53
# senti_polarity_sum                 15         55         +    11         40
# Connoisseur_chain_avg              14         56         -    15         25
# review_count_usr_mean_chain_avg    14         57         -     6         95
# zstar_all                          14         58         -    15         28
# rating_std_chain_avg               14         59         -    11         41
# cool_std_chain_std                 14         60         +     7         76
# Female Importance                  13         61         +    14         30
# review_count_usr_sum               13         62         +     5         99
# senti_polarity_max_chain_avg       13         63         +     7         74
# Low Network                        12         64         -     9         56
# average_stars_mean_chain_std       12         65         +     7         72
# review_count_usr_max               12         66         +     5         98
# Male to Female_chain_avg           12         67         -     6         91
# friend_count_std                   11         68         +     8         66
# review_count_usr_min               11         69         -     8         63
# Food Aestheticist_chain_avg        11         70         -    23         13
# Number of Reviewers_chain_avg      11         71         +    13         35
# useful_std_chain_avg               10         72         -     7         71
# useful_std_chain_std               10         73         +     9         57
# funny_mean                         10         74         +     6         86
# reactions_per_week                 10         75         +     8         62
# average_stars_sum                  10         76         +    11         39
# longitude_chain_std                 9         77         +    10         48
# senti_polarity_mean_chain_avg       9         78         +     8         67
# review_count_usr_std                9         79         +    10         47
# gender_mean                         9         80         +     8         60
# rating_sum_chain_avg                9         81         +     9         55
# longitude_chain_avg                 9         82         -     6         83
# compliment_plain_std                9         83         +     6         90
# stars_linear_coef_chain_avg         8         84         -    30          7
# friend_count_mean                   8         85         -     5        100
# review_count_usr_std_chain_std      7         86         -    10         45
# rating_mean                         7         87         -     6         84
# gender_std_chain_avg                7         88         -     9         59
# elite_count_mean_chain_avg          6         89         +     6         87
# funny_mean_chain_avg                6         90         -     9         54
# average_stars_sum_chain_avg         5         91         +    10         43
# High Network_chain_avg              5         92         +     8         68
# senti_polarity_std_chain_avg        5         93         -     6         85
# fans_sum                            5         94         -     7         73
# friends/review_chain_avg            5         95         -     6         93
# Number of Reviewers                 5         96         -     7         75
# Patrons_chain_avg                   4         97         -     6         96
# std_of_stars_chain_avg              3         98         -     6         89
# restaurant_density_chain_avg        3         99         -     6         88
# latitude_chain_std                  2        100         +     8         65
#
#                                  relevant
# oldest_review                        True
# oldest_review_chain_avg              True
# useful_mean                          True
# stars_linear_coef                    True
# useful_sum                           True
# gender_std                          False
# restaurant_density                   True
# Connoisseur                          True
# rating_sum                          False
# reviews_per_week                     True
# latitude                            False
# zreview_count_all                    True
# average_stars_mean                   True
# zstar_all_chain_std                  True
# elite_count_mean                    False
# first_sent_mean                      True
# Male to Female                      False
# first_sent_std_chain_avg             True
# zreview_per_week_all                 True
# elite_count_std                      True
# zreview_count_all_chain_avg          True
# rating_std                           True
# reviews_per_week_chain_avg           True
# first_sent_std                       True
# last_sent_std                        True
# funny_std                            True
# useful_mean_chain_avg               False
# last_sent_sum                        True
# average_stars_std                    True
# review_count_usr_mean               False
# High Network                        False
# Food Aestheticist                    True
# friends/review                       True
# Female                              False
# latitude_chain_avg                   True
# senti_polarity_mean                  True
# first_sent_sum                       True
# zstar_all_chain_avg                 False
# zreview_per_week_all_chain_avg       True
# last_sent_mean                      False
# useful_std                           True
# average_stars_std_chain_avg          True
# first_min_last_sent_chain_avg       False
# senti_polarity_std                   True
# longitude                            True
# cool_std                             True
# elite_count_std_chain_avg            True
# restaurant_similar_density           True
# senti_polarity_min                   True
# first_min_last_sent                  True
# elite_count_sum                     False
# last_sent_mean_chain_avg             True
# cool_mean                            True
# senti_polarity_min_chain_avg         True
# senti_polarity_sum                   True
# Connoisseur_chain_avg                True
# review_count_usr_mean_chain_avg      True
# zstar_all                            True
# rating_std_chain_avg                 True
# cool_std_chain_std                   True
# Female Importance                   False
# review_count_usr_sum                False
# senti_polarity_max_chain_avg         True
# Low Network                          True
# average_stars_mean_chain_std         True
# review_count_usr_max                False
# Male to Female_chain_avg             True
# friend_count_std                     True
# review_count_usr_min                False
# Food Aestheticist_chain_avg          True
# Number of Reviewers_chain_avg        True
# useful_std_chain_avg                 True
# useful_std_chain_std                 True
# funny_mean                           True
# reactions_per_week                   True
# average_stars_sum                   False
# longitude_chain_std                  True
# senti_polarity_mean_chain_avg        True
# review_count_usr_std                False
# gender_mean                         False
# rating_sum_chain_avg                 True
# longitude_chain_avg                  True
# compliment_plain_std                 True
# stars_linear_coef_chain_avg          True
# friend_count_mean                    True
# review_count_usr_std_chain_std       True
# rating_mean                         False
# gender_std_chain_avg                 True
# elite_count_mean_chain_avg           True
# funny_mean_chain_avg                 True
# average_stars_sum_chain_avg          True
# High Network_chain_avg               True
# senti_polarity_std_chain_avg         True
# fans_sum                             True
# friends/review_chain_avg             True
# Number of Reviewers                 False
# Patrons_chain_avg                    True
# std_of_stars_chain_avg               True
# restaurant_density_chain_avg         True
# latitude_chain_std                   True

# %%
#shape3['imp_rank'] = shape3['imp'].rank(ascending=0)

# %%
#shape3["Imp Rank"] = shape3['imp'].rank(ascending=0).astype(int)

# %%
from tsfresh.feature_selection.relevance import calculate_relevance_table

# %%
vat = calculate_relevance_table(X, Y)

# %%
vat = calculate_relevance_table(X, Y)
# Out:
#                                                                    feature  \
# feature
# oldest_review_chain_avg                            oldest_review_chain_avg
# is_chain                                                          is_chain
# latitude_chain_std                                      latitude_chain_std
# Female Importance_chain_std                    Female Importance_chain_std
# Average Customer Network_chain_std      Average Customer Network_chain_std
# longitude_chain_std                                    longitude_chain_std
# Male to Female_chain_std                          Male to Female_chain_std
# Low Network_chain_std                                Low Network_chain_std
# friends/review_chain_std                          friends/review_chain_std
# first_sent_std_chain_std                          first_sent_std_chain_std
# compliment_profile_std_chain_std          compliment_profile_std_chain_std
# funny_std_chain_std                                    funny_std_chain_std
# compliment_profile_mean_chain_std        compliment_profile_mean_chain_std
# gender_std_chain_std                                  gender_std_chain_std
# cool_std_chain_std                                      cool_std_chain_std
# friend_count_mean_chain_std                    friend_count_mean_chain_std
# senti_polarity_std_chain_std                  senti_polarity_std_chain_std
# compliment_photos_mean_chain_std          compliment_photos_mean_chain_std
# photo_count_mean_chain_std                      photo_count_mean_chain_std
# zstar_all_chain_std                                    zstar_all_chain_std
# useful_std_chain_std                                  useful_std_chain_std
# average_stars_mean_chain_std                  average_stars_mean_chain_std
# first_sent_mean_chain_std                        first_sent_mean_chain_std
# review_count_usr_std_chain_std              review_count_usr_std_chain_std
# average_stars_std_chain_std                    average_stars_std_chain_std
# photo_count_std_chain_std                        photo_count_std_chain_std
# compliment_photos_std_chain_std            compliment_photos_std_chain_std
# compliment_list_mean_chain_std              compliment_list_mean_chain_std
# last_sent_std_chain_std                            last_sent_std_chain_std
# stars_mean_chain_std                                  stars_mean_chain_std
# rating_mean_chain_std                                rating_mean_chain_std
# last_sent_mean_chain_std                          last_sent_mean_chain_std
# First Visit_chain_std                                First Visit_chain_std
# Food Aestheticist_chain_std                    Food Aestheticist_chain_std
# compliment_hot_mean_chain_std                compliment_hot_mean_chain_std
# senti_polarity_mean_chain_std                senti_polarity_mean_chain_std
# funny_amax_chain_std                                  funny_amax_chain_std
# compliment_more_std_chain_std                compliment_more_std_chain_std
# compliment_cute_mean_chain_std              compliment_cute_mean_chain_std
# funny_mean_chain_std                                  funny_mean_chain_std
# compliment_list_std_chain_std                compliment_list_std_chain_std
# friend_count_std_chain_std                      friend_count_std_chain_std
# gender_mean_chain_std                                gender_mean_chain_std
# compliment_more_mean_chain_std              compliment_more_mean_chain_std
# compliment_profile_sum_chain_std          compliment_profile_sum_chain_std
# compliment_hot_std_chain_std                  compliment_hot_std_chain_std
# compliment_cool_mean_chain_std              compliment_cool_mean_chain_std
# compliment_funny_mean_chain_std            compliment_funny_mean_chain_std
# Female_chain_std                                          Female_chain_std
# High Network_chain_std                              High Network_chain_std
# compliment_cute_std_chain_std                compliment_cute_std_chain_std
# compliment_writer_mean_chain_std          compliment_writer_mean_chain_std
# Connoisseur_chain_std                                Connoisseur_chain_std
# compliment_writer_std_chain_std            compliment_writer_std_chain_std
# rating_std_chain_std                                  rating_std_chain_std
# stars_std_chain_std                                    stars_std_chain_std
# Male_chain_std                                              Male_chain_std
# useful_amax_chain_std                                useful_amax_chain_std
# elite_count_std_chain_std                        elite_count_std_chain_std
# cool_mean_chain_std                                    cool_mean_chain_std
# review_count_usr_mean_chain_std            review_count_usr_mean_chain_std
# review_count_usr_max_chain_std              review_count_usr_max_chain_std
# compliment_cool_std_chain_std                compliment_cool_std_chain_std
# compliment_funny_std_chain_std              compliment_funny_std_chain_std
# rating_pub_chain_std                                  rating_pub_chain_std
# cool_amax_chain_std                                    cool_amax_chain_std
# compliment_photos_sum_chain_std            compliment_photos_sum_chain_std
# photo_count_sum_chain_std                        photo_count_sum_chain_std
# compliment_plain_mean_chain_std            compliment_plain_mean_chain_std
# compliment_note_mean_chain_std              compliment_note_mean_chain_std
# restaurant_density_chain_std                  restaurant_density_chain_std
# senti_polarity_min_chain_std                  senti_polarity_min_chain_std
# fans_mean_chain_std                                    fans_mean_chain_std
# std_of_stars_chain_std                              std_of_stars_chain_std
# friend_count_max_chain_std                      friend_count_max_chain_std
# compliment_cute_sum_chain_std                compliment_cute_sum_chain_std
# Patrons_chain_std                                        Patrons_chain_std
# photo_count_max_chain_std                        photo_count_max_chain_std
# compliment_hot_sum_chain_std                  compliment_hot_sum_chain_std
# compliment_list_sum_chain_std                compliment_list_sum_chain_std
# compliment_more_sum_chain_std                compliment_more_sum_chain_std
# fans_std_chain_std                                      fans_std_chain_std
# restaurant_similar_density_chain_std  restaurant_similar_density_chain_std
# compliment_note_std_chain_std                compliment_note_std_chain_std
# compliment_cool_sum_chain_std                compliment_cool_sum_chain_std
# compliment_funny_sum_chain_std              compliment_funny_sum_chain_std
# compliment_plain_std_chain_std              compliment_plain_std_chain_std
# Total Network_chain_std                            Total Network_chain_std
# friend_count_sum_chain_std                      friend_count_sum_chain_std
# zreview_count_all_chain_std                    zreview_count_all_chain_std
# compliment_writer_sum_chain_std            compliment_writer_sum_chain_std
# elite_count_mean_chain_std                      elite_count_mean_chain_std
# first_min_last_sent_chain_std                first_min_last_sent_chain_std
# senti_polarity_max_chain_std                  senti_polarity_max_chain_std
# funny_sum_chain_std                                    funny_sum_chain_std
# zreview_per_week_all_chain_std              zreview_per_week_all_chain_std
# compliment_plain_sum_chain_std              compliment_plain_sum_chain_std
# compliment_note_sum_chain_std                compliment_note_sum_chain_std
# useful_mean_chain_std                                useful_mean_chain_std
# useful_mean                                                    useful_mean
# fans_sum_chain_std                                      fans_sum_chain_std
# oldest_review_chain_std                            oldest_review_chain_std
# cool_sum_chain_std                                      cool_sum_chain_std
# stars_linear_coef_chain_std                    stars_linear_coef_chain_std
# review_count_usr_sum_chain_std              review_count_usr_sum_chain_std
# Number of Reviewers_chain_std                Number of Reviewers_chain_std
# median_of_stars_chain_std                        median_of_stars_chain_std
# gender_sum_chain_std                                  gender_sum_chain_std
# elite_count_sum_chain_std                        elite_count_sum_chain_std
# useful_sum_chain_std                                  useful_sum_chain_std
# review_count_loc_chain_std                      review_count_loc_chain_std
# average_stars_sum_chain_std                    average_stars_sum_chain_std
# last_sent_sum_chain_std                            last_sent_sum_chain_std
# rating_sum_chain_std                                  rating_sum_chain_std
# stars_sum_chain_std                                    stars_sum_chain_std
# first_sent_sum_chain_std                          first_sent_sum_chain_std
# senti_polarity_sum_chain_std                  senti_polarity_sum_chain_std
# reactions_per_week_chain_std                  reactions_per_week_chain_std
# reviews_per_week_chain_std                      reviews_per_week_chain_std
# review_count_usr_min_chain_std              review_count_usr_min_chain_std
# oldest_review                                                oldest_review
# first_sent_std_chain_avg                          first_sent_std_chain_avg
# count_categories_chain_std                      count_categories_chain_std
# Convenience Level_chain_std                    Convenience Level_chain_std
# stars_linear_coef                                        stars_linear_coef
# rating_min_chain_avg                                  rating_min_chain_avg
# compliment_profile_sum_chain_avg          compliment_profile_sum_chain_avg
# senti_polarity_std_chain_avg                  senti_polarity_std_chain_avg
# compliment_profile_std_chain_avg          compliment_profile_std_chain_avg
# senti_polarity_min_chain_avg                  senti_polarity_min_chain_avg
# compliment_profile_mean_chain_avg        compliment_profile_mean_chain_avg
# rating_max_chain_std                                  rating_max_chain_std
# compliment_list_sum_chain_avg                compliment_list_sum_chain_avg
# compliment_more_sum_chain_avg                compliment_more_sum_chain_avg
# review_count_usr_min_chain_avg              review_count_usr_min_chain_avg
# compliment_hot_sum_chain_avg                  compliment_hot_sum_chain_avg
# compliment_photos_sum_chain_avg            compliment_photos_sum_chain_avg
# photo_count_sum_chain_avg                        photo_count_sum_chain_avg
# photo_count_max_chain_avg                        photo_count_max_chain_avg
# compliment_list_std_chain_avg                compliment_list_std_chain_avg
# elite_count_sum_chain_avg                        elite_count_sum_chain_avg
# compliment_cute_sum_chain_avg                compliment_cute_sum_chain_avg
# compliment_funny_sum_chain_avg              compliment_funny_sum_chain_avg
# compliment_cool_sum_chain_avg                compliment_cool_sum_chain_avg
# review_count_usr_sum_chain_avg              review_count_usr_sum_chain_avg
# gender_sum_chain_avg                                  gender_sum_chain_avg
# compliment_more_std_chain_avg                compliment_more_std_chain_avg
# compliment_writer_sum_chain_avg            compliment_writer_sum_chain_avg
# compliment_plain_sum_chain_avg              compliment_plain_sum_chain_avg
# friend_count_sum_chain_avg                      friend_count_sum_chain_avg
# Total Network_chain_avg                            Total Network_chain_avg
# review_count_loc_chain_avg                      review_count_loc_chain_avg
# compliment_list_mean_chain_avg              compliment_list_mean_chain_avg
# Number of Reviewers_chain_avg                Number of Reviewers_chain_avg
# last_sent_std_chain_avg                            last_sent_std_chain_avg
# compliment_photos_std_chain_avg            compliment_photos_std_chain_avg
# photo_count_std_chain_avg                        photo_count_std_chain_avg
# compliment_note_sum_chain_avg                compliment_note_sum_chain_avg
# compliment_hot_std_chain_avg                  compliment_hot_std_chain_avg
# average_stars_sum_chain_avg                    average_stars_sum_chain_avg
# compliment_more_mean_chain_avg              compliment_more_mean_chain_avg
# rating_sum_chain_avg                                  rating_sum_chain_avg
# stars_sum_chain_avg                                    stars_sum_chain_avg
# restaurant_density                                      restaurant_density
# compliment_photos_mean_chain_avg          compliment_photos_mean_chain_avg
# photo_count_mean_chain_avg                      photo_count_mean_chain_avg
# compliment_cute_std_chain_avg                compliment_cute_std_chain_avg
# compliment_hot_mean_chain_avg                compliment_hot_mean_chain_avg
# reactions_per_week                                      reactions_per_week
# senti_polarity_max_chain_avg                  senti_polarity_max_chain_avg
# friend_count_max_chain_avg                      friend_count_max_chain_avg
# Outdoor Seating_chain_std                        Outdoor Seating_chain_std
# Female Importance_chain_avg                    Female Importance_chain_avg
# Male to Female_chain_avg                          Male to Female_chain_avg
# fans_sum_chain_avg                                      fans_sum_chain_avg
# restaurant_similar_density                      restaurant_similar_density
# compliment_writer_std_chain_avg            compliment_writer_std_chain_avg
# Bike Parking_chain_std                              Bike Parking_chain_std
# Food Aestheticist_chain_avg                    Food Aestheticist_chain_avg
# compliment_cute_mean_chain_avg              compliment_cute_mean_chain_avg
# compliment_cool_std_chain_avg                compliment_cool_std_chain_avg
# compliment_funny_std_chain_avg              compliment_funny_std_chain_avg
# compliment_funny_mean_chain_avg            compliment_funny_mean_chain_avg
# compliment_cool_mean_chain_avg              compliment_cool_mean_chain_avg
# compliment_plain_mean_chain_avg            compliment_plain_mean_chain_avg
# compliment_plain_std_chain_avg              compliment_plain_std_chain_avg
# review_count_usr_max_chain_avg              review_count_usr_max_chain_avg
# review_count_usr_mean_chain_avg            review_count_usr_mean_chain_avg
# Average Customer Network_chain_avg      Average Customer Network_chain_avg
# cool_amax_chain_avg                                    cool_amax_chain_avg
# compliment_writer_mean_chain_avg          compliment_writer_mean_chain_avg
# friend_count_std_chain_avg                      friend_count_std_chain_avg
# compliment_note_mean_chain_avg              compliment_note_mean_chain_avg
# funny_sum_chain_avg                                    funny_sum_chain_avg
# Patrons_chain_avg                                        Patrons_chain_avg
# compliment_note_std_chain_avg                compliment_note_std_chain_avg
# rating_min_chain_std                                  rating_min_chain_std
# funny_amax_chain_avg                                  funny_amax_chain_avg
# gender_max_chain_avg                                  gender_max_chain_avg
# review_count_usr_std_chain_avg              review_count_usr_std_chain_avg
# friend_count_mean_chain_avg                    friend_count_mean_chain_avg
# first_sent_sum_chain_avg                          first_sent_sum_chain_avg
# gender_mean_chain_avg                                gender_mean_chain_avg
# Connoisseur_chain_avg                                Connoisseur_chain_avg
# cool_sum_chain_avg                                      cool_sum_chain_avg
# Outdoor Seating_chain_avg                        Outdoor Seating_chain_avg
# friend_count_min_chain_std                      friend_count_min_chain_std
# senti_polarity_sum_chain_avg                  senti_polarity_sum_chain_avg
# elite_count_mean_chain_avg                      elite_count_mean_chain_avg
# fans_std_chain_avg                                      fans_std_chain_avg
# average_stars_std_chain_avg                    average_stars_std_chain_avg
# last_sent_sum_chain_avg                            last_sent_sum_chain_avg
# reviews_per_week                                          reviews_per_week
# friend_count_min_chain_avg                      friend_count_min_chain_avg
# fans_mean_chain_avg                                    fans_mean_chain_avg
# cool_std_chain_avg                                      cool_std_chain_avg
# useful_std                                                      useful_std
# latitude_chain_avg                                      latitude_chain_avg
# Caters_chain_std                                          Caters_chain_std
# funny_std_chain_avg                                    funny_std_chain_avg
# friends/review_chain_avg                          friends/review_chain_avg
# High Network_chain_avg                              High Network_chain_avg
# useful_sum_chain_avg                                  useful_sum_chain_avg
# useful_amax_chain_avg                                useful_amax_chain_avg
# Low Network_chain_avg                                Low Network_chain_avg
# elite_count_std_chain_avg                        elite_count_std_chain_avg
# Caters_chain_avg                                          Caters_chain_avg
# First Visit_chain_avg                                First Visit_chain_avg
# rating_mean_chain_avg                                rating_mean_chain_avg
# stars_mean_chain_avg                                  stars_mean_chain_avg
# rating_pub_chain_avg                                  rating_pub_chain_avg
# Female_chain_avg                                          Female_chain_avg
# Male_chain_avg                                              Male_chain_avg
# longitude_chain_avg                                    longitude_chain_avg
# funny_mean_chain_avg                                  funny_mean_chain_avg
# cool_mean                                                        cool_mean
# senti_polarity_mean_chain_avg                senti_polarity_mean_chain_avg
# count_categories_chain_avg                      count_categories_chain_avg
# Convenience Level_chain_avg                    Convenience Level_chain_avg
# median_of_stars_chain_avg                        median_of_stars_chain_avg
# std_of_stars_chain_avg                              std_of_stars_chain_avg
# last_sent_mean_chain_avg                          last_sent_mean_chain_avg
# first_sent_std                                              first_sent_std
# Bike Parking_chain_avg                              Bike Parking_chain_avg
# useful_sum                                                      useful_sum
# cool_mean_chain_avg                                    cool_mean_chain_avg
# gender_min_chain_std                                  gender_min_chain_std
# gender_min_chain_avg                                  gender_min_chain_avg
# stars_std_chain_avg                                    stars_std_chain_avg
# rating_std_chain_avg                                  rating_std_chain_avg
# zreview_per_week_all_chain_avg              zreview_per_week_all_chain_avg
# senti_polarity_std                                      senti_polarity_std
# useful_std_chain_avg                                  useful_std_chain_avg
# first_sent_mean_chain_avg                        first_sent_mean_chain_avg
# useful_amax                                                    useful_amax
# zreview_count_all                                        zreview_count_all
# funny_mean                                                      funny_mean
# average_stars_mean_chain_avg                  average_stars_mean_chain_avg
# rating_max_chain_avg                                  rating_max_chain_avg
# restaurant_density_chain_avg                  restaurant_density_chain_avg
# gender_max_chain_std                                  gender_max_chain_std
# zreview_per_week_all                                  zreview_per_week_all
# average_stars_mean                                      average_stars_mean
# first_min_last_sent                                    first_min_last_sent
# gender_std_chain_avg                                  gender_std_chain_avg
# restaurant_similar_density_chain_avg  restaurant_similar_density_chain_avg
# useful_amin_chain_std                                useful_amin_chain_std
# first_sent_mean                                            first_sent_mean
# zreview_count_all_chain_avg                    zreview_count_all_chain_avg
# count_categories                                          count_categories
# reviews_per_week_chain_avg                      reviews_per_week_chain_avg
# cool_std                                                          cool_std
# Noisy_chain_std                                            Noisy_chain_std
# cool_sum                                                          cool_sum
# fans_mean                                                        fans_mean
# Noisy_chain_avg                                            Noisy_chain_avg
# funny_std                                                        funny_std
# reactions_per_week_chain_avg                  reactions_per_week_chain_avg
# useful_amin_chain_avg                                useful_amin_chain_avg
# Bike Parking                                                  Bike Parking
# compliment_cute_mean                                  compliment_cute_mean
# fans_std                                                          fans_std
# senti_polarity_min                                      senti_polarity_min
# friends/review                                              friends/review
# funny_sum                                                        funny_sum
# compliment_cute_std                                    compliment_cute_std
# compliment_writer_mean                              compliment_writer_mean
# compliment_list_mean                                  compliment_list_mean
# friend_count_mean                                        friend_count_mean
# first_sent_sum                                              first_sent_sum
# elite_count_std                                            elite_count_std
# rating_max                                                      rating_max
# Food Aestheticist                                        Food Aestheticist
# compliment_note_mean                                  compliment_note_mean
# senti_polarity_sum                                      senti_polarity_sum
# compliment_funny_mean                                compliment_funny_mean
# compliment_cool_mean                                  compliment_cool_mean
# last_sent_std                                                last_sent_std
# friend_count_std                                          friend_count_std
# compliment_list_std                                    compliment_list_std
# Average Customer Network                          Average Customer Network
# compliment_note_std                                    compliment_note_std
# compliment_writer_std                                compliment_writer_std
# funny_amax                                                      funny_amax
# compliment_hot_mean                                    compliment_hot_mean
# senti_polarity_mean                                    senti_polarity_mean
# compliment_more_mean                                  compliment_more_mean
# cool_amax                                                        cool_amax
# compliment_cute_sum                                    compliment_cute_sum
# compliment_funny_std                                  compliment_funny_std
# compliment_cool_std                                    compliment_cool_std
# longitude                                                        longitude
# fans_sum                                                          fans_sum
# compliment_profile_mean                            compliment_profile_mean
# compliment_plain_mean                                compliment_plain_mean
# compliment_list_sum                                    compliment_list_sum
# compliment_hot_std                                      compliment_hot_std
# compliment_more_std                                    compliment_more_std
# last_sent_sum                                                last_sent_sum
# Connoisseur                                                    Connoisseur
# stars_linear_coef_chain_avg                    stars_linear_coef_chain_avg
# average_stars_std                                        average_stars_std
# Low Network                                                    Low Network
# compliment_photos_mean                              compliment_photos_mean
# photo_count_mean                                          photo_count_mean
# friend_count_max                                          friend_count_max
# useful_amin                                                    useful_amin
# funny_amin_chain_std                                  funny_amin_chain_std
# compliment_plain_std                                  compliment_plain_std
# compliment_note_sum                                    compliment_note_sum
# Delivery_chain_avg                                      Delivery_chain_avg
# zstar_all                                                        zstar_all
# stars_std                                                        stars_std
# rating_std                                                      rating_std
# median_of_stars                                            median_of_stars
# compliment_writer_sum                                compliment_writer_sum
# compliment_profile_std                              compliment_profile_std
# photo_count_std                                            photo_count_std
# compliment_photos_std                                compliment_photos_std
# funny_amin_chain_avg                                  funny_amin_chain_avg
# compliment_cool_sum                                    compliment_cool_sum
# compliment_funny_sum                                  compliment_funny_sum
# useful_mean_chain_avg                                useful_mean_chain_avg
# compliment_hot_sum                                      compliment_hot_sum
# friend_count_sum                                          friend_count_sum
# Total Network                                                Total Network
# Delivery_chain_std                                      Delivery_chain_std
# review_count_usr_std                                  review_count_usr_std
# photo_count_min_chain_std                        photo_count_min_chain_std
# compliment_more_sum                                    compliment_more_sum
# compliment_plain_sum                                  compliment_plain_sum
# photo_count_min_chain_avg                        photo_count_min_chain_avg
# zstar_all_chain_avg                                    zstar_all_chain_avg
# photo_count_sum                                            photo_count_sum
# compliment_photos_sum                                compliment_photos_sum
# Female Importance                                        Female Importance
# compliment_profile_sum                              compliment_profile_sum
# photo_count_max                                            photo_count_max
# stars_sum                                                        stars_sum
# rating_sum                                                      rating_sum
# elite_count_mean                                          elite_count_mean
# average_stars_sum                                        average_stars_sum
# Patrons                                                            Patrons
# review_count_usr_max                                  review_count_usr_max
# std_of_stars                                                  std_of_stars
# Noisy                                                                Noisy
# Free Wi-Fi                                                      Free Wi-Fi
# rating_min                                                      rating_min
# Outdoor Seating                                            Outdoor Seating
# stars_mean                                                      stars_mean
# rating_mean                                                    rating_mean
# gender_max                                                      gender_max
# review_count_loc                                          review_count_loc
# elite_count_sum                                            elite_count_sum
# Number of Reviewers                                    Number of Reviewers
# First Visit                                                    First Visit
# Takes Reservations_chain_std                  Takes Reservations_chain_std
# review_count_usr_mean                                review_count_usr_mean
# Male                                                                  Male
# gender_sum                                                      gender_sum
# funny_amin                                                      funny_amin
# Takes Reservations_chain_avg                  Takes Reservations_chain_avg
# friend_count_min                                          friend_count_min
# Convenience Level                                        Convenience Level
# senti_polarity_max                                      senti_polarity_max
# last_sent_mean                                              last_sent_mean
# review_count_usr_sum                                  review_count_usr_sum
# gender_std                                                      gender_std
# Female                                                              Female
# Takes Reservations                                      Takes Reservations
# first_min_last_sent_chain_avg                first_min_last_sent_chain_avg
# Caters                                                              Caters
# photo_count_min                                            photo_count_min
# High Network                                                  High Network
# cool_amin_chain_avg                                    cool_amin_chain_avg
# rating_pub                                                      rating_pub
# Male to Female                                              Male to Female
# latitude                                                          latitude
# cool_amin                                                        cool_amin
# review_count_usr_min                                  review_count_usr_min
# gender_mean                                                    gender_mean
# Delivery                                                          Delivery
# Free Wi-Fi_chain_avg                                  Free Wi-Fi_chain_avg
# gender_min                                                      gender_min
# cool_amin_chain_std                                    cool_amin_chain_std
# Free Wi-Fi_chain_std                                  Free Wi-Fi_chain_std
#
#                                           type        p_value  relevant
# feature
# oldest_review_chain_avg                   real  1.191262e-100      True
# is_chain                                binary   3.018017e-71      True
# latitude_chain_std                        real   5.497286e-71      True
# Female Importance_chain_std               real   1.048547e-70      True
# Average Customer Network_chain_std        real   2.271514e-70      True
# longitude_chain_std                       real   2.464140e-70      True
# Male to Female_chain_std                  real   2.857833e-70      True
# Low Network_chain_std                     real   2.928828e-70      True
# friends/review_chain_std                  real   3.832184e-70      True
# first_sent_std_chain_std                  real   4.384923e-70      True
# compliment_profile_std_chain_std          real   5.388729e-70      True
# funny_std_chain_std                       real   6.004257e-70      True
# compliment_profile_mean_chain_std         real   6.021169e-70      True
# gender_std_chain_std                      real   6.619643e-70      True
# cool_std_chain_std                        real   7.751019e-70      True
# friend_count_mean_chain_std               real   8.145635e-70      True
# senti_polarity_std_chain_std              real   8.409271e-70      True
# compliment_photos_mean_chain_std          real   8.815752e-70      True
# photo_count_mean_chain_std                real   8.815752e-70      True
# zstar_all_chain_std                       real   9.209640e-70      True
# useful_std_chain_std                      real   1.050443e-69      True
# average_stars_mean_chain_std              real   1.142356e-69      True
# first_sent_mean_chain_std                 real   1.192588e-69      True
# review_count_usr_std_chain_std            real   1.373602e-69      True
# average_stars_std_chain_std               real   1.493313e-69      True
# photo_count_std_chain_std                 real   2.080472e-69      True
# compliment_photos_std_chain_std           real   2.080472e-69      True
# compliment_list_mean_chain_std            real   2.092644e-69      True
# last_sent_std_chain_std                   real   2.134858e-69      True
# stars_mean_chain_std                      real   2.336749e-69      True
# rating_mean_chain_std                     real   2.336749e-69      True
# last_sent_mean_chain_std                  real   2.366484e-69      True
# First Visit_chain_std                     real   2.415301e-69      True
# Food Aestheticist_chain_std               real   2.440447e-69      True
# compliment_hot_mean_chain_std             real   2.828277e-69      True
# senti_polarity_mean_chain_std             real   3.128168e-69      True
# funny_amax_chain_std                      real   4.430428e-69      True
# compliment_more_std_chain_std             real   5.034319e-69      True
# compliment_cute_mean_chain_std            real   5.042668e-69      True
# funny_mean_chain_std                      real   5.124737e-69      True
# compliment_list_std_chain_std             real   5.193972e-69      True
# friend_count_std_chain_std                real   5.396531e-69      True
# gender_mean_chain_std                     real   5.563975e-69      True
# compliment_more_mean_chain_std            real   6.174956e-69      True
# compliment_profile_sum_chain_std          real   7.545159e-69      True
# compliment_hot_std_chain_std              real   7.784678e-69      True
# compliment_cool_mean_chain_std            real   7.836437e-69      True
# compliment_funny_mean_chain_std           real   7.836437e-69      True
# Female_chain_std                          real   7.865907e-69      True
# High Network_chain_std                    real   8.571483e-69      True
# compliment_cute_std_chain_std             real   1.123604e-68      True
# compliment_writer_mean_chain_std          real   1.296249e-68      True
# Connoisseur_chain_std                     real   1.358379e-68      True
# compliment_writer_std_chain_std           real   1.849612e-68      True
# rating_std_chain_std                      real   1.940955e-68      True
# stars_std_chain_std                       real   1.941754e-68      True
# Male_chain_std                            real   2.335419e-68      True
# useful_amax_chain_std                     real   3.225302e-68      True
# elite_count_std_chain_std                 real   3.820999e-68      True
# cool_mean_chain_std                       real   4.100650e-68      True
# review_count_usr_mean_chain_std           real   4.444246e-68      True
# review_count_usr_max_chain_std            real   6.126932e-68      True
# compliment_cool_std_chain_std             real   7.888556e-68      True
# compliment_funny_std_chain_std            real   7.888556e-68      True
# rating_pub_chain_std                      real   9.227277e-68      True
# cool_amax_chain_std                       real   1.025100e-67      True
# compliment_photos_sum_chain_std           real   1.087826e-67      True
# photo_count_sum_chain_std                 real   1.087826e-67      True
# compliment_plain_mean_chain_std           real   1.425399e-67      True
# compliment_note_mean_chain_std            real   1.539195e-67      True
# restaurant_density_chain_std              real   1.617057e-67      True
# senti_polarity_min_chain_std              real   2.010861e-67      True
# fans_mean_chain_std                       real   2.044008e-67      True
# std_of_stars_chain_std                    real   2.154169e-67      True
# friend_count_max_chain_std                real   2.161089e-67      True
# compliment_cute_sum_chain_std             real   2.926228e-67      True
# Patrons_chain_std                         real   3.123416e-67      True
# photo_count_max_chain_std                 real   3.384689e-67      True
# compliment_hot_sum_chain_std              real   5.832791e-67      True
# compliment_list_sum_chain_std             real   5.920400e-67      True
# compliment_more_sum_chain_std             real   9.255931e-67      True
# fans_std_chain_std                        real   1.082941e-66      True
# restaurant_similar_density_chain_std      real   1.643184e-66      True
# compliment_note_std_chain_std             real   2.043321e-66      True
# compliment_cool_sum_chain_std             real   2.356135e-66      True
# compliment_funny_sum_chain_std            real   2.356135e-66      True
# compliment_plain_std_chain_std            real   3.408598e-66      True
# Total Network_chain_std                   real   3.555196e-66      True
# friend_count_sum_chain_std                real   3.555196e-66      True
# zreview_count_all_chain_std               real   3.699383e-66      True
# compliment_writer_sum_chain_std           real   4.122893e-66      True
# elite_count_mean_chain_std                real   4.280258e-66      True
# first_min_last_sent_chain_std             real   6.805710e-66      True
# senti_polarity_max_chain_std              real   1.750553e-65      True
# funny_sum_chain_std                       real   1.950048e-65      True
# zreview_per_week_all_chain_std            real   2.031500e-65      True
# compliment_plain_sum_chain_std            real   4.204264e-65      True
# compliment_note_sum_chain_std             real   4.563903e-65      True
# useful_mean_chain_std                     real   8.547749e-65      True
# useful_mean                               real   9.599664e-65      True
# fans_sum_chain_std                        real   1.305477e-64      True
# oldest_review_chain_std                   real   1.835674e-64      True
# cool_sum_chain_std                        real   1.903650e-64      True
# stars_linear_coef_chain_std               real   2.936134e-64      True
# review_count_usr_sum_chain_std            real   3.570178e-64      True
# Number of Reviewers_chain_std             real   2.482593e-63      True
# median_of_stars_chain_std                 real   2.508363e-63      True
# gender_sum_chain_std                      real   3.107157e-63      True
# elite_count_sum_chain_std                 real   3.517373e-63      True
# useful_sum_chain_std                      real   4.914533e-63      True
# review_count_loc_chain_std                real   4.966586e-63      True
# average_stars_sum_chain_std               real   5.117702e-63      True
# last_sent_sum_chain_std                   real   6.138004e-63      True
# rating_sum_chain_std                      real   7.363003e-63      True
# stars_sum_chain_std                       real   7.363873e-63      True
# first_sent_sum_chain_std                  real   7.901669e-63      True
# senti_polarity_sum_chain_std              real   2.565664e-62      True
# reactions_per_week_chain_std              real   4.045243e-62      True
# reviews_per_week_chain_std                real   8.551321e-62      True
# review_count_usr_min_chain_std            real   5.486639e-59      True
# oldest_review                             real   3.312318e-57      True
# first_sent_std_chain_avg                  real   5.943770e-57      True
# count_categories_chain_std                real   8.707716e-57      True
# Convenience Level_chain_std               real   2.857749e-56      True
# stars_linear_coef                         real   5.441478e-54      True
# rating_min_chain_avg                      real   1.228991e-51      True
# compliment_profile_sum_chain_avg          real   2.312597e-50      True
# senti_polarity_std_chain_avg              real   3.820896e-49      True
# compliment_profile_std_chain_avg          real   7.105274e-49      True
# senti_polarity_min_chain_avg              real   5.999003e-47      True
# compliment_profile_mean_chain_avg         real   2.513977e-46      True
# rating_max_chain_std                      real   4.017824e-45      True
# compliment_list_sum_chain_avg             real   4.127030e-45      True
# compliment_more_sum_chain_avg             real   7.619968e-45      True
# review_count_usr_min_chain_avg            real   9.335544e-45      True
# compliment_hot_sum_chain_avg              real   6.114837e-44      True
# compliment_photos_sum_chain_avg           real   1.324089e-43      True
# photo_count_sum_chain_avg                 real   1.324089e-43      True
# photo_count_max_chain_avg                 real   2.050780e-43      True
# compliment_list_std_chain_avg             real   1.266932e-42      True
# elite_count_sum_chain_avg                 real   1.470038e-42      True
# compliment_cute_sum_chain_avg             real   2.112454e-42      True
# compliment_funny_sum_chain_avg            real   3.259534e-42      True
# compliment_cool_sum_chain_avg             real   3.259534e-42      True
# review_count_usr_sum_chain_avg            real   3.470012e-42      True
# gender_sum_chain_avg                      real   3.709099e-42      True
# compliment_more_std_chain_avg             real   7.509377e-42      True
# compliment_writer_sum_chain_avg           real   1.111677e-41      True
# compliment_plain_sum_chain_avg            real   2.746253e-41      True
# friend_count_sum_chain_avg                real   2.931509e-41      True
# Total Network_chain_avg                   real   2.931509e-41      True
# review_count_loc_chain_avg                real   4.477553e-41      True
# compliment_list_mean_chain_avg            real   8.547162e-41      True
# Number of Reviewers_chain_avg             real   1.063889e-40      True
# last_sent_std_chain_avg                   real   2.157872e-40      True
# compliment_photos_std_chain_avg           real   2.231018e-40      True
# photo_count_std_chain_avg                 real   2.231018e-40      True
# compliment_note_sum_chain_avg             real   3.470037e-40      True
# compliment_hot_std_chain_avg              real   4.395078e-40      True
# average_stars_sum_chain_avg               real   7.921571e-40      True
# compliment_more_mean_chain_avg            real   1.137177e-39      True
# rating_sum_chain_avg                      real   3.642452e-39      True
# stars_sum_chain_avg                       real   3.642676e-39      True
# restaurant_density                        real   3.821932e-39      True
# compliment_photos_mean_chain_avg          real   5.265324e-39      True
# photo_count_mean_chain_avg                real   5.265324e-39      True
# compliment_cute_std_chain_avg             real   8.075897e-39      True
# compliment_hot_mean_chain_avg             real   1.063443e-38      True
# reactions_per_week                        real   1.258890e-38      True
# senti_polarity_max_chain_avg              real   1.293413e-38      True
# friend_count_max_chain_avg                real   1.934663e-38      True
# Outdoor Seating_chain_std                 real   1.222096e-37      True
# Female Importance_chain_avg               real   1.470476e-37      True
# Male to Female_chain_avg                  real   1.898827e-37      True
# fans_sum_chain_avg                        real   4.524935e-37      True
# restaurant_similar_density                real   9.751851e-37      True
# compliment_writer_std_chain_avg           real   1.208149e-36      True
# Bike Parking_chain_std                    real   1.341999e-36      True
# Food Aestheticist_chain_avg               real   2.661371e-36      True
# compliment_cute_mean_chain_avg            real   3.010906e-36      True
# compliment_cool_std_chain_avg             real   3.828458e-36      True
# compliment_funny_std_chain_avg            real   3.828458e-36      True
# compliment_funny_mean_chain_avg           real   4.434074e-36      True
# compliment_cool_mean_chain_avg            real   4.434074e-36      True
# compliment_plain_mean_chain_avg           real   8.771492e-36      True
# compliment_plain_std_chain_avg            real   4.025670e-35      True
# review_count_usr_max_chain_avg            real   4.748241e-35      True
# review_count_usr_mean_chain_avg           real   2.216955e-34      True
# Average Customer Network_chain_avg        real   4.970912e-34      True
# cool_amax_chain_avg                       real   7.058625e-34      True
# compliment_writer_mean_chain_avg          real   8.863496e-34      True
# friend_count_std_chain_avg                real   9.433232e-34      True
# compliment_note_mean_chain_avg            real   2.223444e-33      True
# funny_sum_chain_avg                       real   3.737666e-33      True
# Patrons_chain_avg                         real   4.549031e-33      True
# compliment_note_std_chain_avg             real   5.388134e-33      True
# rating_min_chain_std                      real   6.048497e-33      True
# funny_amax_chain_avg                      real   2.258512e-32      True
# gender_max_chain_avg                      real   2.678291e-32      True
# review_count_usr_std_chain_avg            real   3.283192e-32      True
# friend_count_mean_chain_avg               real   1.172861e-31      True
# first_sent_sum_chain_avg                  real   2.905626e-31      True
# gender_mean_chain_avg                     real   3.570211e-31      True
# Connoisseur_chain_avg                     real   1.002677e-30      True
# cool_sum_chain_avg                        real   2.304457e-30      True
# Outdoor Seating_chain_avg                 real   2.925965e-30      True
# friend_count_min_chain_std                real   2.234611e-29      True
# senti_polarity_sum_chain_avg              real   6.559475e-29      True
# elite_count_mean_chain_avg                real   1.412969e-28      True
# fans_std_chain_avg                        real   2.487056e-28      True
# average_stars_std_chain_avg               real   1.490623e-27      True
# last_sent_sum_chain_avg                   real   2.082078e-27      True
# reviews_per_week                          real   4.267361e-27      True
# friend_count_min_chain_avg                real   5.544207e-27      True
# fans_mean_chain_avg                       real   1.003434e-26      True
# cool_std_chain_avg                        real   1.319401e-26      True
# useful_std                                real   2.455395e-26      True
# latitude_chain_avg                        real   2.492173e-26      True
# Caters_chain_std                          real   3.983295e-26      True
# funny_std_chain_avg                       real   4.130921e-26      True
# friends/review_chain_avg                  real   6.324151e-26      True
# High Network_chain_avg                    real   1.595304e-24      True
# useful_sum_chain_avg                      real   5.007162e-24      True
# useful_amax_chain_avg                     real   1.357342e-23      True
# Low Network_chain_avg                     real   2.152947e-23      True
# elite_count_std_chain_avg                 real   3.447800e-23      True
# Caters_chain_avg                          real   8.820118e-23      True
# First Visit_chain_avg                     real   2.357274e-22      True
# rating_mean_chain_avg                     real   4.571192e-22      True
# stars_mean_chain_avg                      real   4.571943e-22      True
# rating_pub_chain_avg                      real   6.944668e-22      True
# Female_chain_avg                          real   1.146048e-21      True
# Male_chain_avg                            real   9.388964e-21      True
# longitude_chain_avg                       real   1.155737e-19      True
# funny_mean_chain_avg                      real   2.034027e-19      True
# cool_mean                                 real   2.700067e-18      True
# senti_polarity_mean_chain_avg             real   2.191864e-17      True
# count_categories_chain_avg                real   3.550127e-17      True
# Convenience Level_chain_avg               real   9.733453e-17      True
# median_of_stars_chain_avg                 real   2.342762e-16      True
# std_of_stars_chain_avg                    real   3.533623e-16      True
# last_sent_mean_chain_avg                  real   4.496485e-16      True
# first_sent_std                            real   7.475799e-16      True
# Bike Parking_chain_avg                    real   7.964463e-16      True
# useful_sum                                real   1.490611e-15      True
# cool_mean_chain_avg                       real   5.886016e-15      True
# gender_min_chain_std                      real   6.789274e-15      True
# gender_min_chain_avg                      real   1.111520e-14      True
# stars_std_chain_avg                       real   1.279841e-14      True
# rating_std_chain_avg                      real   1.280047e-14      True
# zreview_per_week_all_chain_avg            real   1.350746e-14      True
# senti_polarity_std                        real   2.598013e-13      True
# useful_std_chain_avg                      real   4.789236e-13      True
# first_sent_mean_chain_avg                 real   6.543757e-13      True
# useful_amax                               real   6.783326e-13      True
# zreview_count_all                         real   1.672525e-12      True
# funny_mean                                real   2.928771e-12      True
# average_stars_mean_chain_avg              real   3.265125e-12      True
# rating_max_chain_avg                      real   7.481901e-12      True
# restaurant_density_chain_avg              real   9.278799e-12      True
# gender_max_chain_std                      real   1.305332e-11      True
# zreview_per_week_all                      real   6.228269e-11      True
# average_stars_mean                        real   8.340136e-10      True
# first_min_last_sent                       real   1.231468e-09      True
# gender_std_chain_avg                      real   1.383660e-09      True
# restaurant_similar_density_chain_avg      real   3.059556e-09      True
# useful_amin_chain_std                     real   3.445101e-09      True
# first_sent_mean                           real   5.383631e-09      True
# zreview_count_all_chain_avg               real   4.541988e-08      True
# count_categories                          real   8.658492e-08      True
# reviews_per_week_chain_avg                real   8.877709e-08      True
# cool_std                                  real   1.485880e-07      True
# Noisy_chain_std                           real   2.149135e-07      True
# cool_sum                                  real   3.869710e-07      True
# fans_mean                                 real   4.066612e-07      True
# Noisy_chain_avg                           real   8.220918e-07      True
# funny_std                                 real   1.243030e-06      True
# reactions_per_week_chain_avg              real   1.599469e-06      True
# useful_amin_chain_avg                     real   1.669179e-06      True
# Bike Parking                            binary   1.861844e-06      True
# compliment_cute_mean                      real   2.851543e-06      True
# fans_std                                  real   3.431680e-06      True
# senti_polarity_min                        real   7.596229e-06      True
# friends/review                            real   1.516005e-05      True
# funny_sum                                 real   1.745852e-05      True
# compliment_cute_std                       real   2.022026e-05      True
# compliment_writer_mean                    real   2.379786e-05      True
# compliment_list_mean                      real   3.035905e-05      True
# friend_count_mean                         real   3.519226e-05      True
# first_sent_sum                            real   4.825700e-05      True
# elite_count_std                           real   5.437782e-05      True
# rating_max                                real   5.821874e-05      True
# Food Aestheticist                         real   7.977694e-05      True
# compliment_note_mean                      real   9.192317e-05      True
# senti_polarity_sum                        real   1.267438e-04      True
# compliment_funny_mean                     real   1.395715e-04      True
# compliment_cool_mean                      real   1.395715e-04      True
# last_sent_std                             real   1.421858e-04      True
# friend_count_std                          real   1.482096e-04      True
# compliment_list_std                       real   1.719195e-04      True
# Average Customer Network                  real   3.021150e-04      True
# compliment_note_std                       real   3.651259e-04      True
# compliment_writer_std                     real   4.212597e-04      True
# funny_amax                                real   4.228229e-04      True
# compliment_hot_mean                       real   4.269820e-04      True
# senti_polarity_mean                       real   4.774679e-04      True
# compliment_more_mean                      real   5.000988e-04      True
# cool_amax                                 real   7.282547e-04      True
# compliment_cute_sum                       real   7.373926e-04      True
# compliment_funny_std                      real   7.476801e-04      True
# compliment_cool_std                       real   7.476801e-04      True
# longitude                                 real   1.057905e-03      True
# fans_sum                                  real   1.287005e-03      True
# compliment_profile_mean                   real   1.377996e-03      True
# compliment_plain_mean                     real   1.653814e-03      True
# compliment_list_sum                       real   2.018452e-03      True
# compliment_hot_std                        real   2.204498e-03      True
# compliment_more_std                       real   3.108496e-03      True
# last_sent_sum                             real   3.193064e-03      True
# Connoisseur                               real   3.202819e-03      True
# stars_linear_coef_chain_avg               real   3.415195e-03      True
# average_stars_std                         real   3.648482e-03      True
# Low Network                               real   4.094360e-03      True
# compliment_photos_mean                    real   4.468816e-03      True
# photo_count_mean                          real   4.468816e-03      True
# friend_count_max                          real   4.475994e-03      True
# useful_amin                               real   4.596898e-03      True
# funny_amin_chain_std                      real   4.683061e-03      True
# compliment_plain_std                      real   4.808087e-03      True
# compliment_note_sum                       real   4.836045e-03      True
# Delivery_chain_avg                        real   4.889729e-03      True
# zstar_all                                 real   5.440067e-03      True
# stars_std                                 real   5.767656e-03      True
# rating_std                                real   5.767721e-03      True
# median_of_stars                           real   6.649498e-03     False
# compliment_writer_sum                     real   7.236124e-03     False
# compliment_profile_std                    real   8.111073e-03     False
# photo_count_std                           real   8.928861e-03     False
# compliment_photos_std                     real   8.928861e-03     False
# funny_amin_chain_avg                      real   9.089628e-03     False
# compliment_cool_sum                       real   9.847553e-03     False
# compliment_funny_sum                      real   9.847553e-03     False
# useful_mean_chain_avg                     real   1.000029e-02     False
# compliment_hot_sum                        real   1.154123e-02     False
# friend_count_sum                          real   1.238076e-02     False
# Total Network                             real   1.238076e-02     False
# Delivery_chain_std                        real   1.317024e-02     False
# review_count_usr_std                      real   1.540105e-02     False
# photo_count_min_chain_std               binary   1.690931e-02     False
# compliment_more_sum                       real   1.897156e-02     False
# compliment_plain_sum                      real   2.040940e-02     False
# photo_count_min_chain_avg                 real   2.271225e-02     False
# zstar_all_chain_avg                       real   2.296008e-02     False
# photo_count_sum                           real   2.520867e-02     False
# compliment_photos_sum                     real   2.520867e-02     False
# Female Importance                         real   2.594653e-02     False
# compliment_profile_sum                    real   2.617594e-02     False
# photo_count_max                           real   2.793440e-02     False
# stars_sum                                 real   2.854015e-02     False
# rating_sum                                real   2.854102e-02     False
# elite_count_mean                          real   3.981674e-02     False
# average_stars_sum                         real   4.658604e-02     False
# Patrons                                   real   4.716334e-02     False
# review_count_usr_max                      real   4.923100e-02     False
# std_of_stars                              real   5.919972e-02     False
# Noisy                                   binary   6.021062e-02     False
# Free Wi-Fi                              binary   7.723307e-02     False
# rating_min                                real   7.927968e-02     False
# Outdoor Seating                         binary   8.156681e-02     False
# stars_mean                                real   1.152096e-01     False
# rating_mean                               real   1.152148e-01     False
# gender_max                              binary   1.252379e-01     False
# review_count_loc                          real   1.445842e-01     False
# elite_count_sum                           real   1.507162e-01     False
# Number of Reviewers                       real   1.549266e-01     False
# First Visit                               real   1.550659e-01     False
# Takes Reservations_chain_std              real   1.603177e-01     False
# review_count_usr_mean                     real   1.675408e-01     False
# Male                                      real   1.784777e-01     False
# gender_sum                                real   1.798969e-01     False
# funny_amin                              binary   1.838048e-01     False
# Takes Reservations_chain_avg              real   1.953151e-01     False
# friend_count_min                          real   1.980307e-01     False
# Convenience Level                         real   2.055243e-01     False
# senti_polarity_max                        real   2.134423e-01     False
# last_sent_mean                            real   2.332222e-01     False
# review_count_usr_sum                      real   2.505884e-01     False
# gender_std                                real   2.656825e-01     False
# Female                                    real   2.701872e-01     False
# Takes Reservations                      binary   3.703201e-01     False
# first_min_last_sent_chain_avg             real   3.753550e-01     False
# Caters                                  binary   4.653173e-01     False
# photo_count_min                         binary   4.818772e-01     False
# High Network                              real   5.202644e-01     False
# cool_amin_chain_avg                       real   5.346836e-01     False
# rating_pub                                real   6.349252e-01     False
# Male to Female                            real   7.526103e-01     False
# latitude                                  real   8.067144e-01     False
# cool_amin                                 real   8.184987e-01     False
# review_count_usr_min                      real   8.750550e-01     False
# gender_mean                               real   9.923597e-01     False
# Delivery                                binary   1.000000e+00     False
# Free Wi-Fi_chain_avg                    binary   1.000000e+00     False
# gender_min                              binary   1.000000e+00     False
# cool_amin_chain_std                     binary   1.000000e+00     False
# Free Wi-Fi_chain_std                  constant            NaN     False

# %%
shape2
# Out:
#                                  Shap  Shap Rank Direction  Gain  Gain Rank
# oldest_review                     100          1         +    54          3
# oldest_review_chain_avg            86          2         +    97          2
# useful_mean                        51          3         +    25          9
# stars_linear_coef                  50          4         +    44          4
# useful_sum                         49          5         -   100          1
# gender_std                         43          6         -     9         50
# restaurant_density                 42          7         +    24         11
# Connoisseur                        39          8         +    21         14
# rating_sum                         38          9         -     7         77
# reviews_per_week                   37         10         -    16         21
# latitude                           33         11         -    19         16
# zreview_count_all                  33         12         -    23         12
# average_stars_mean                 32         13         -    20         15
# zstar_all_chain_std                32         14         -    17         20
# elite_count_mean                   31         15         -    12         37
# first_sent_mean                    31         16         -    14         31
# Male to Female                     30         17         -    10         44
# first_sent_std_chain_avg           29         18         +    18         17
# zreview_per_week_all               29         19         -    39          5
# elite_count_std                    29         20         +    15         24
# zreview_count_all_chain_avg        25         21         +    25         10
# rating_std                         25         22         -    14         33
# reviews_per_week_chain_avg         25         23         +    11         38
# first_sent_std                     24         24         +    15         26
# last_sent_std                      23         25         -    15         23
# funny_std                          22         26         +     8         70
# useful_mean_chain_avg              22         27         +    18         18
# last_sent_sum                      21         28         -     7         81
# average_stars_std                  21         29         +    14         29
# review_count_usr_mean              21         30         -     7         82
# High Network                       20         31         -     9         49
# Food Aestheticist                  20         32         +    14         32
# friends/review                     20         33         -    13         34
# Female                             20         34         +     9         51
# latitude_chain_avg                 20         35         -     8         64
# senti_polarity_mean                19         36         -     8         61
# first_sent_sum                     19         37         -    30          8
# zstar_all_chain_avg                19         38         +    15         27
# zreview_per_week_all_chain_avg     19         39         -    30          6
# last_sent_mean                     18         40         -     7         78
# useful_std                         18         41         -     5         97
# average_stars_std_chain_avg        17         42         -     6         94
# first_min_last_sent_chain_avg      17         43         +     9         52
# senti_polarity_std                 17         44         +    18         19
# longitude                          17         45         +    12         36
# cool_std                           17         46         -     9         58
# elite_count_std_chain_avg          17         47         -    10         46
# restaurant_similar_density         16         48         -     6         92
# senti_polarity_min                 16         49         -    11         42
# first_min_last_sent                16         50         -    15         22
# elite_count_sum                    16         51         +     8         69
# last_sent_mean_chain_avg           16         52         -     7         80
# cool_mean                          15         53         -     7         79
# senti_polarity_min_chain_avg       15         54         +     9         53
# senti_polarity_sum                 15         55         +    11         40
# Connoisseur_chain_avg              14         56         -    15         25
# review_count_usr_mean_chain_avg    14         57         -     6         95
# zstar_all                          14         58         -    15         28
# rating_std_chain_avg               14         59         -    11         41
# cool_std_chain_std                 14         60         +     7         76
# Female Importance                  13         61         +    14         30
# review_count_usr_sum               13         62         +     5         99
# senti_polarity_max_chain_avg       13         63         +     7         74
# Low Network                        12         64         -     9         56
# average_stars_mean_chain_std       12         65         +     7         72
# review_count_usr_max               12         66         +     5         98
# Male to Female_chain_avg           12         67         -     6         91
# friend_count_std                   11         68         +     8         66
# review_count_usr_min               11         69         -     8         63
# Food Aestheticist_chain_avg        11         70         -    23         13
# Number of Reviewers_chain_avg      11         71         +    13         35
# useful_std_chain_avg               10         72         -     7         71
# useful_std_chain_std               10         73         +     9         57
# funny_mean                         10         74         +     6         86
# reactions_per_week                 10         75         +     8         62
# average_stars_sum                  10         76         +    11         39
# longitude_chain_std                 9         77         +    10         48
# senti_polarity_mean_chain_avg       9         78         +     8         67
# review_count_usr_std                9         79         +    10         47
# gender_mean                         9         80         +     8         60
# rating_sum_chain_avg                9         81         +     9         55
# longitude_chain_avg                 9         82         -     6         83
# compliment_plain_std                9         83         +     6         90
# stars_linear_coef_chain_avg         8         84         -    30          7
# friend_count_mean                   8         85         -     5        100
# review_count_usr_std_chain_std      7         86         -    10         45
# rating_mean                         7         87         -     6         84
# gender_std_chain_avg                7         88         -     9         59
# elite_count_mean_chain_avg          6         89         +     6         87
# funny_mean_chain_avg                6         90         -     9         54
# average_stars_sum_chain_avg         5         91         +    10         43
# High Network_chain_avg              5         92         +     8         68
# senti_polarity_std_chain_avg        5         93         -     6         85
# fans_sum                            5         94         -     7         73
# friends/review_chain_avg            5         95         -     6         93
# Number of Reviewers                 5         96         -     7         75
# Patrons_chain_avg                   4         97         -     6         96
# std_of_stars_chain_avg              3         98         -     6         89
# restaurant_density_chain_avg        3         99         -     6         88
# latitude_chain_std                  2        100         +     8         65

# %%
shape3
# Out:
#                                         shap_value Direction         Gain  \
# oldest_review                         10857.549129         +  1598.369262
# oldest_review_chain_avg                9427.620338         +  2844.021270
# useful_mean                            5551.318048         +   749.891530
# stars_linear_coef                      5429.562803         +  1281.892154
# useful_sum                             5389.089699         -  2910.823740
# gender_std                             4761.522918         -   282.575047
# restaurant_density                     4562.308184         +   704.529912
# Connoisseur                            4330.761405         +   634.633448
# rating_sum                             4229.343310         -   211.938458
# reviews_per_week                       4049.851485         -   481.552516
# latitude                               3652.926755         -   566.568856
# compliment_plain_mean                  3633.171469         +          NaN
# zreview_count_all                      3614.698967         -   675.966962
# average_stars_mean                     3543.036126         -   600.243696
# zstar_all_chain_std                    3494.586635         -   519.953890
# elite_count_mean                       3462.528845         -   352.389802
# first_sent_mean                        3403.862081         -   425.275836
# Male to Female                         3322.669813         -   320.009721
# first_sent_std_chain_avg               3233.481576         +   551.787633
# zreview_per_week_all                   3222.254830         -  1155.919067
# elite_count_std                        3191.009706         +   458.131839
# compliment_more_mean                   2825.727827         -          NaN
# zreview_count_all_chain_avg            2817.500884         +   730.399746
# rating_std                             2773.276921         -   421.018206
# reviews_per_week_chain_avg             2747.474297         +   349.037770
# first_sent_std                         2663.498614         +   450.198837
# last_sent_std                          2604.101943         -   460.585955
# fans_std                               2476.905742         -          NaN
# funny_std                              2418.917435         +   239.949165
# useful_mean_chain_avg                  2406.109241         +   543.568493
# last_sent_sum                          2351.729934         -   207.890326
# average_stars_std                      2335.291104         +   434.404349
# review_count_usr_mean                  2305.839132         -   207.371760
# High Network                           2238.115340         -   288.012286
# Food Aestheticist                      2222.190365         +   421.522109
# friends/review                         2219.899389         -   405.202880
# Female                                 2198.597273         +   280.093820
# latitude_chain_avg                     2187.508888         -   256.926856
# senti_polarity_mean                    2102.813695         -   261.769092
# first_sent_sum                         2077.014307         -   881.436804
# zstar_all_chain_avg                    2076.150498         +   449.045956
# zreview_per_week_all_chain_avg         2071.691913         -   885.438864
# cool_std_chain_avg                     2041.559331         -          NaN
# last_sent_mean                         2032.141687         -   210.088641
# cool_sum_chain_std                     1998.435895         +          NaN
# useful_std                             1972.983615         -   173.825172
# std_of_stars                           1971.469032         +          NaN
# average_stars_std_chain_avg            1948.800760         -   190.083884
# first_min_last_sent_chain_avg          1912.922775         +   278.751806
# senti_polarity_std                     1912.211850         +   530.556259
# compliment_writer_std                  1907.345471         +          NaN
# longitude                              1900.827232         +   361.214926
# cool_std                               1862.917704         -   266.069819
# elite_count_std_chain_avg              1853.306487         -   308.978846
# restaurant_similar_density             1829.069525         -   192.829976
# senti_polarity_min                     1827.048264         -   332.692054
# first_min_last_sent                    1797.428403         -   463.976418
# compliment_hot_mean                    1780.091737         -          NaN
# elite_count_sum                        1763.122962         +   244.156960
# last_sent_mean_chain_avg               1751.887298         -   207.908022
# Bike Parking                           1730.827902         -          NaN
# photo_count_mean                       1680.963421         +          NaN
# cool_mean                              1678.360141         -   208.234848
# senti_polarity_min_chain_avg           1657.526769         +   277.227493
# compliment_cool_mean_chain_std         1649.190884         -          NaN
# senti_polarity_sum                     1642.615134         +   341.420000
# Connoisseur_chain_avg                  1613.778996         -   451.770120
# review_count_usr_mean_chain_avg        1578.680914         -   187.163678
# zstar_all                              1572.909345         -   438.231567
# rating_std_chain_avg                   1569.984972         -   340.500993
# cool_std_chain_std                     1545.666877         +   214.569590
# cool_amax                              1513.591224         +          NaN
# Female Importance                      1498.514595         +   429.824834
# review_count_usr_sum                   1484.679737         +   164.291280
# senti_polarity_max_chain_avg           1469.285408         +   217.882800
# compliment_list_mean                   1437.964474         +          NaN
# friend_count_sum                       1427.295488         +          NaN
# compliment_profile_std                 1423.316223         -          NaN
# Low Network                            1410.890482         -   269.205550
# average_stars_mean_chain_std           1349.000222         +   224.197030
# rating_min_chain_avg                   1348.250066         -          NaN
# review_count_usr_max                   1335.465050         +   173.202681
# Male to Female_chain_avg               1312.032475         -   193.351486
# compliment_cute_mean                   1310.702596         +          NaN
# friend_count_std                       1301.886270         +   250.993414
# Male to Female_chain_std               1298.168623         +          NaN
# review_count_usr_min                   1284.283990         -   258.333096
# First Visit                            1234.278018         -          NaN
# compliment_note_sum                    1222.359799         -          NaN
# Food Aestheticist_chain_avg            1217.571212         -   675.832392
# compliment_more_std                    1207.338522         -          NaN
# compliment_note_mean                   1199.897070         -          NaN
# rating_max_chain_std                   1198.339490         +          NaN
# Convenience Level                      1197.557426         -          NaN
# Number of Reviewers_chain_avg          1194.861365         +   405.108374
# useful_std_chain_avg                   1193.019562         -   231.061360
# useful_std_chain_std                   1192.537081         +   267.742770
# first_sent_std_chain_std               1156.932316         +          NaN
# funny_mean                             1156.392746         +   198.608984
# senti_polarity_max                     1155.687675         +          NaN
# photo_count_std                        1155.446162         -          NaN
# Male                                   1132.286043         +          NaN
# useful_amax                            1127.777419         -          NaN
# reactions_per_week                     1125.709721         +   260.585665
# compliment_writer_mean                 1115.065941         +          NaN
# average_stars_sum                      1108.320830         +   344.958085
# first_sent_mean_chain_avg              1094.849906         +          NaN
# cool_sum                               1094.697560         -          NaN
# Average Customer Network_chain_std     1083.504978         +          NaN
# compliment_note_sum_chain_avg          1077.502412         -          NaN
# compliment_profile_mean                1073.088205         -          NaN
# longitude_chain_std                    1056.146783         +   301.378036
# last_sent_sum_chain_avg                1055.061064         +          NaN
# cool_amax_chain_avg                    1047.332976         +          NaN
# senti_polarity_mean_chain_avg          1044.612201         +   250.542517
# review_count_usr_std                   1039.757100         +   303.320020
# compliment_plain_sum                   1030.250986         +          NaN
# gender_mean                            1023.965480         +   261.843233
# friend_count_mean_chain_std            1022.714096         -          NaN
# compliment_cool_std                    1020.868988         +          NaN
# photo_count_sum                         997.825355         -          NaN
# rating_sum_chain_avg                    993.101054         +   270.364280
# longitude_chain_avg                     992.873586         -   203.000673
# compliment_plain_std                    984.941922         +   195.030547
# last_sent_std_chain_avg                 973.579738         +          NaN
# compliment_cool_sum                     960.029650         -          NaN
# First Visit_chain_avg                   955.737819         +          NaN
# compliment_hot_sum                      953.954746         +          NaN
# friend_count_max                        953.194722         -          NaN
# stars_linear_coef_chain_avg             951.868435         -   882.110221
# friend_count_std_chain_avg              939.379086         -          NaN
# review_count_usr_std_chain_avg          937.090192         -          NaN
# friend_count_mean                       927.788308         -   162.452976
# useful_amax_chain_avg                   924.233619         +          NaN
# median_of_stars_chain_std               918.358196         -          NaN
# Average Customer Network                917.814750         -          NaN
# review_count_usr_min_chain_avg          905.771082         -          NaN
# first_min_last_sent_chain_std           899.060981         -          NaN
# fans_mean                               895.946757         +          NaN
# zreview_count_all_chain_std             891.995184         +          NaN
# review_count_usr_std_chain_std          860.423111         -   312.889280
# gender_std_chain_std                    851.303823         +          NaN
# compliment_note_std                     836.073021         -          NaN
# photo_count_max                         835.423708         +          NaN
# compliment_cool_mean                    820.468473         +          NaN
# rating_mean                             817.306090         -   200.598475
# funny_amax                              814.380262         -          NaN
# compliment_list_mean_chain_avg          811.547681         -          NaN
# compliment_cute_sum                     809.596351         -          NaN
# compliment_profile_mean_chain_avg       794.334958         +          NaN
# compliment_list_std                     783.406414         -          NaN
# average_stars_std_chain_std             765.738793         +          NaN
# compliment_list_sum                     765.361420         -          NaN
# gender_std_chain_avg                    764.454087         -   262.077086
# review_count_usr_max_chain_avg          761.327408         +          NaN
# compliment_writer_sum                   758.666814         -          NaN
# elite_count_sum_chain_avg               757.248773         +          NaN
# photo_count_mean_chain_std              752.193339         -          NaN
# compliment_cute_sum_chain_avg           725.362080         +          NaN
# compliment_cute_std                     724.169643         -          NaN
# average_stars_mean_chain_avg            723.596513         +          NaN
# review_count_loc                        716.019532         -          NaN
# fans_mean_chain_avg                     711.166927         -          NaN
# compliment_more_mean_chain_std          703.824493         +          NaN
# elite_count_mean_chain_avg              683.898533         +   196.359622
# review_count_usr_sum_chain_avg          677.501172         +          NaN
# Patrons                                 674.510061         -          NaN
# compliment_hot_std                      672.198085         -          NaN
# funny_mean_chain_avg                    665.150782         -   274.523204
# funny_sum                               657.198483         +          NaN
# compliment_note_std_chain_avg           653.299297         -          NaN
# first_sent_sum_chain_std                653.060873         +          NaN
# friend_count_max_chain_avg              650.686975         +          NaN
# Female Importance_chain_avg             644.999151         +          NaN
# restaurant_similar_density_chain_std    638.082965         -          NaN
# average_stars_sum_chain_avg             637.620370         +   320.165800
# High Network_chain_avg                  634.903225         +   249.734350
# gender_sum                              633.708104         +          NaN
# funny_std_chain_avg                     631.005637         +          NaN
# Female_chain_avg                        630.166984         +          NaN
# senti_polarity_std_chain_avg            629.566608         -   198.943919
# compliment_more_std_chain_avg           625.711086         +          NaN
# compliment_profile_std_chain_avg        611.759263         -          NaN
# funny_amax_chain_avg                    602.557393         -          NaN
# count_categories_chain_avg              600.892632         -          NaN
# funny_sum_chain_avg                     600.657134         +          NaN
# Convenience Level_chain_avg             597.448742         +          NaN
# fans_sum                                597.012731         -   220.069630
# compliment_plain_std_chain_avg          596.691775         +          NaN
# friend_count_sum_chain_avg              588.894841         -          NaN
# friends/review_chain_avg                585.915308         -   191.878629
# compliment_more_mean_chain_avg          583.908702         -          NaN
# Number of Reviewers                     578.382782         -   216.967640
# Male_chain_avg                          573.719671         +          NaN
# compliment_cute_std_chain_avg           573.533990         -          NaN
# reactions_per_week_chain_avg            564.823770         -          NaN
# cool_mean_chain_avg                     561.096526         -          NaN
# compliment_hot_mean_chain_avg           553.829286         +          NaN
# restaurant_density_chain_std            551.985259         +          NaN
# compliment_more_sum                     551.132322         +          NaN
# friend_count_mean_chain_avg             543.876655         -          NaN
# gender_sum_chain_avg                    542.948153         +          NaN
# compliment_writer_mean_chain_avg        539.585605         +          NaN
# review_count_usr_max_chain_std          533.379969         +          NaN
# rating_mean_chain_std                   533.181562         +          NaN
# friends/review_chain_std                530.077897         -          NaN
# count_categories                        521.873740         -          NaN
# Patrons_chain_avg                       518.682428         -   181.901280
# compliment_hot_sum_chain_avg            511.334925         +          NaN
# restaurant_similar_density_chain_avg    509.899712         +          NaN
# useful_sum_chain_std                    500.999217         -          NaN
# elite_count_mean_chain_std              500.922130         +          NaN
# photo_count_max_chain_avg               491.831338         -          NaN
# last_sent_mean_chain_std                490.841484         -          NaN
# Low Network_chain_avg                   486.770270         +          NaN
# photo_count_mean_chain_avg              481.042774         -          NaN
# compliment_cool_std_chain_std           474.188728         +          NaN
# Female_chain_std                        471.252302         +          NaN
# Male_chain_std                          464.573160         +          NaN
# compliment_writer_sum_chain_avg         453.158575         -          NaN
# compliment_profile_sum                  449.566871         -          NaN
# fans_std_chain_avg                      422.055782         +          NaN
# last_sent_std_chain_std                 421.188866         -          NaN
# Female Importance_chain_std             416.372116         +          NaN
# compliment_list_std_chain_avg           407.862736         -          NaN
# useful_sum_chain_avg                    394.860159         +          NaN
# compliment_profile_sum_chain_avg        392.822333         +          NaN
# gender_mean_chain_avg                   388.076855         +          NaN
# compliment_cool_std_chain_avg           384.771868         -          NaN
# std_of_stars_chain_avg                  382.790287         -   195.357810
# First Visit_chain_std                   381.398751         -          NaN
# compliment_writer_std_chain_avg         381.355842         +          NaN
# gender_mean_chain_std                   369.924932         -          NaN
# compliment_plain_sum_chain_avg          367.211517         +          NaN
# compliment_hot_std_chain_avg            351.620217         -          NaN
# Average Customer Network_chain_avg      348.163911         -          NaN
# photo_count_sum_chain_avg               342.994019         -          NaN
# restaurant_density_chain_avg            335.094981         -   195.384970
# senti_polarity_max_chain_std            333.183445         +          NaN
# compliment_note_mean_chain_avg          332.398431         -          NaN
# review_count_loc_chain_avg              319.415415         -          NaN
# reviews_per_week_chain_std              316.562439         +          NaN
# funny_std_chain_std                     315.976202         +          NaN
# senti_polarity_sum_chain_avg            307.730394         +          NaN
# Connoisseur_chain_std                   304.822308         +          NaN
# first_sent_sum_chain_avg                300.383138         +          NaN
# senti_polarity_std_chain_std            299.028207         -          NaN
# photo_count_std_chain_avg               297.323491         -          NaN
# zreview_per_week_all_chain_std          287.191401         -          NaN
# review_count_loc_chain_std              281.992410         +          NaN
# cool_amax_chain_std                     279.050690         +          NaN
# count_categories_chain_std              274.209008         -          NaN
# Bike Parking_chain_avg                  272.442709         +          NaN
# compliment_profile_mean_chain_std       268.298583         -          NaN
# compliment_cool_sum_chain_avg           265.693676         -          NaN
# compliment_cute_mean_chain_std          253.228004         -          NaN
# latitude_chain_std                      252.681446         +   252.857697
# photo_count_max_chain_std               249.875563         +          NaN
# useful_mean_chain_std                   247.065276         -          NaN
# compliment_plain_sum_chain_std          234.245701         +          NaN
# senti_polarity_sum_chain_std            232.492534         +          NaN
# Patrons_chain_std                       227.127446         +          NaN
# senti_polarity_min_chain_std            224.799543         +          NaN
# Outdoor Seating                         219.756443         +          NaN
# Bike Parking_chain_std                  218.760284         -          NaN
# compliment_plain_mean_chain_avg         218.130384         -          NaN
# fans_sum_chain_avg                      210.848031         +          NaN
# funny_mean_chain_std                    205.525551         -          NaN
# last_sent_sum_chain_std                 200.623153         +          NaN
# compliment_list_sum_chain_avg           198.086404         +          NaN
# fans_sum_chain_std                      194.789487         +          NaN
# reactions_per_week_chain_std            192.511042         +          NaN
# cool_sum_chain_avg                      186.315989         +          NaN
# rating_mean_chain_avg                   185.363037         -          NaN
# compliment_more_sum_chain_avg           180.109943         -          NaN
# compliment_note_std_chain_std           179.946306         -          NaN
# cool_mean_chain_std                     175.357072         -          NaN
# funny_amax_chain_std                    174.331597         -          NaN
# compliment_cute_mean_chain_avg          173.374398         -          NaN
# review_count_usr_min_chain_std          167.410256         +          NaN
# senti_polarity_mean_chain_std           158.817440         -          NaN
# elite_count_std_chain_std               158.392604         +          NaN
# compliment_more_sum_chain_std           155.539186         +          NaN
# median_of_stars                         149.623767         +          NaN
# elite_count_sum_chain_std               149.472920         -          NaN
# rating_min                              149.029068         -          NaN
# average_stars_sum_chain_std             144.674173         -          NaN
# fans_mean_chain_std                     144.568951         +          NaN
# compliment_cool_mean_chain_avg          141.651023         +          NaN
# Low Network_chain_std                   140.482842         +          NaN
# friend_count_max_chain_std              139.952945         -          NaN
# Number of Reviewers_chain_std           132.693334         -          NaN
# useful_amax_chain_std                   131.719441         +          NaN
# std_of_stars_chain_std                  131.716050         +          NaN
# stars_linear_coef_chain_std             127.391859         +          NaN
# fans_std_chain_std                      126.951295         -          NaN
# rating_max_chain_avg                    122.910704         -          NaN
# friend_count_min_chain_std              121.718822         -          NaN
# friend_count_std_chain_std              120.674734         -          NaN
# compliment_note_mean_chain_std          115.787958         +          NaN
# compliment_cool_sum_chain_std           114.190745         -          NaN
# review_count_usr_mean_chain_std         114.041800         +          NaN
# funny_sum_chain_std                     109.080178         -          NaN
# compliment_list_sum_chain_std           108.356610         +          NaN
# photo_count_std_chain_std               103.839297         +          NaN
# photo_count_sum_chain_std               100.364969         +          NaN
# median_of_stars_chain_avg                98.948743         +          NaN
# friend_count_sum_chain_std               95.382363         +          NaN
# Food Aestheticist_chain_std              94.805446         +          NaN
# Caters                                   84.092307         +          NaN
# Caters_chain_avg                         83.650913         +          NaN
# compliment_profile_std_chain_std         79.767305         -          NaN
# rating_pub_chain_std                     72.627878         -          NaN
# oldest_review_chain_std                  71.972563         -          NaN
# compliment_list_mean_chain_std           71.480174         +          NaN
# compliment_plain_mean_chain_std          67.436146         +          NaN
# compliment_writer_sum_chain_std          66.746822         -          NaN
# friend_count_min_chain_avg               66.669438         +          NaN
# compliment_plain_std_chain_std           65.633996         +          NaN
# rating_std_chain_std                     61.332893         +          NaN
# High Network_chain_std                   59.757461         -          NaN
# compliment_cute_std_chain_std            58.255486         -          NaN
# review_count_usr_sum_chain_std           56.337261         -          NaN
# compliment_note_sum_chain_std            56.101440         -          NaN
# Convenience Level_chain_std              55.805485         -          NaN
# compliment_more_std_chain_std            52.973268         +          NaN
# friend_count_min                         52.528531         +          NaN
# Outdoor Seating_chain_avg                50.441434         +          NaN
# rating_sum_chain_std                     46.785054         +          NaN
# first_sent_mean_chain_std                44.351533         +          NaN
# compliment_list_std_chain_std            42.756419         -          NaN
# compliment_writer_mean_chain_std         42.461924         +          NaN
# compliment_hot_sum_chain_std             39.169600         -          NaN
# rating_pub                               38.097965         -          NaN
# gender_sum_chain_std                     37.969091         -          NaN
# compliment_cute_sum_chain_std            36.922184         +          NaN
# compliment_hot_std_chain_std             35.934638         -          NaN
# compliment_hot_mean_chain_std            35.326957         +          NaN
# compliment_profile_sum_chain_std         30.594769         +          NaN
# stars_std_chain_avg                      29.532080         +          NaN
# compliment_writer_std_chain_std          24.787624         -          NaN
# useful_amin_chain_avg                    23.261251         -          NaN
# rating_min_chain_std                     17.592188         +          NaN
# rating_pub_chain_avg                     15.801142         -          NaN
# stars_std_chain_std                       0.000000         +          NaN
# Total Network                             0.000000         +          NaN
# compliment_photos_mean_chain_std          0.000000         +          NaN
# compliment_photos_std_chain_std           0.000000         +          NaN
# stars_sum_chain_avg                       0.000000         +          NaN
# cool_amin_chain_avg                       0.000000         +          NaN
# rating_max                                0.000000         +          NaN
# compliment_funny_sum                      0.000000         +          NaN
# funny_amin_chain_avg                      0.000000         +          NaN
# compliment_funny_mean                     0.000000         +          NaN
# compliment_funny_std                      0.000000         +          NaN
# compliment_photos_sum                     0.000000         +          NaN
# compliment_photos_mean                    0.000000         +          NaN
# compliment_photos_std                     0.000000         +          NaN
# Free Wi-Fi                                0.000000         +          NaN
# compliment_funny_sum_chain_avg            0.000000         +          NaN
# Takes Reservations                        0.000000         +          NaN
# Total Network_chain_std                   0.000000         +          NaN
# Delivery                                  0.000000         +          NaN
# photo_count_min_chain_avg                 0.000000         +          NaN
# Free Wi-Fi_chain_std                      0.000000         +          NaN
# Takes Reservations_chain_std              0.000000         +          NaN
# Outdoor Seating_chain_std                 0.000000         +          NaN
# Delivery_chain_std                        0.000000         +          NaN
# Caters_chain_std                          0.000000         +          NaN
# Noisy                                     0.000000         +          NaN
# Noisy_chain_std                           0.000000         +          NaN
# gender_max_chain_avg                      0.000000         +          NaN
# gender_min_chain_avg                      0.000000         +          NaN
# compliment_photos_sum_chain_std           0.000000         +          NaN
# compliment_funny_mean_chain_avg           0.000000         +          NaN
# stars_mean_chain_std                      0.000000         +          NaN
# Delivery_chain_avg                        0.000000         +          NaN
# stars_sum_chain_std                       0.000000         +          NaN
# gender_max                                0.000000         +          NaN
# photo_count_min                           0.000000         +          NaN
# cool_amin_chain_std                       0.000000         +          NaN
# useful_amin                               0.000000         +          NaN
# funny_amin_chain_std                      0.000000         +          NaN
# useful_amin_chain_std                     0.000000         +          NaN
# funny_amin                                0.000000         +          NaN
# photo_count_min_chain_std                 0.000000         +          NaN
# gender_max_chain_std                      0.000000         +          NaN
# gender_min_chain_std                      0.000000         +          NaN
# cool_amin                                 0.000000         +          NaN
# Noisy_chain_avg                           0.000000         +          NaN
# Takes Reservations_chain_avg              0.000000         +          NaN
# compliment_funny_std_chain_avg            0.000000         +          NaN
# Free Wi-Fi_chain_avg                      0.000000         +          NaN
# Total Network_chain_avg                   0.000000         +          NaN
# is_chain                                  0.000000         +          NaN
# stars_sum                                 0.000000         +          NaN
# stars_mean                                0.000000         +          NaN
# stars_std                                 0.000000         +          NaN
# compliment_photos_std_chain_avg           0.000000         +          NaN
# compliment_photos_mean_chain_avg          0.000000         +          NaN
# gender_min                                0.000000         +          NaN
# compliment_photos_sum_chain_avg           0.000000         +          NaN
# compliment_funny_sum_chain_std            0.000000         +          NaN
# compliment_funny_mean_chain_std           0.000000         +          NaN
# compliment_funny_std_chain_std            0.000000         +          NaN
# stars_mean_chain_avg                      0.000000         +          NaN
#
#                                       Gain Rank  Average Rank  imp
# oldest_review                               3.0      7.500000  324
# oldest_review_chain_avg                     2.0      3.833333  175
# useful_mean                                 9.0     16.166667  296
# stars_linear_coef                           4.0     11.000000  239
# useful_sum                                  1.0      3.666667  173
# gender_std                                 50.0     49.166667  260
# restaurant_density                         11.0     13.833333  221
# Connoisseur                                14.0     23.500000  264
# rating_sum                                 77.0     52.166667  158
# reviews_per_week                           21.0     25.666667  164
# latitude                                   16.0     18.500000  244
# compliment_plain_mean                       NaN           NaN  138
# zreview_count_all                          12.0     17.333333  217
# average_stars_mean                         15.0     28.000000  359
# zstar_all_chain_std                        20.0     21.333333   54
# elite_count_mean                           37.0     48.333333  296
# first_sent_mean                            31.0     52.166667  278
# Male to Female                             44.0     51.166667  170
# first_sent_std_chain_avg                   17.0     28.833333  166
# zreview_per_week_all                        5.0     10.333333  221
# elite_count_std                            24.0     44.166667  254
# compliment_more_mean                        NaN           NaN  152
# zreview_count_all_chain_avg                10.0     12.000000  149
# rating_std                                 33.0     38.000000  231
# reviews_per_week_chain_avg                 38.0     49.333333  151
# first_sent_std                             26.0     30.666667  365
# last_sent_std                              23.0     39.500000  365
# fans_std                                    NaN           NaN  178
# funny_std                                  70.0     70.166667  218
# useful_mean_chain_avg                      18.0     21.166667  114
# last_sent_sum                              81.0     63.166667  214
# average_stars_std                          29.0     47.333333  346
# review_count_usr_mean                      82.0     55.166667  195
# High Network                               49.0     68.000000  205
# Food Aestheticist                          32.0     41.333333  228
# friends/review                             34.0     39.666667  290
# Female                                     51.0     50.166667  225
# latitude_chain_avg                         64.0     57.000000  135
# senti_polarity_mean                        61.0     46.666667  183
# first_sent_sum                              8.0     27.833333  212
# zstar_all_chain_avg                        27.0     34.000000  120
# zreview_per_week_all_chain_avg              6.0     32.166667  216
# cool_std_chain_avg                          NaN           NaN  103
# last_sent_mean                             78.0     84.666667  281
# cool_sum_chain_std                          NaN           NaN   32
# useful_std                                 97.0     71.500000  275
# std_of_stars                                NaN           NaN  130
# average_stars_std_chain_avg                94.0     76.166667   97
# first_min_last_sent_chain_avg              52.0     70.500000  153
# senti_polarity_std                         19.0     32.000000  211
# compliment_writer_std                       NaN           NaN  123
# longitude                                  36.0     46.833333  150
# cool_std                                   58.0     66.333333  212
# elite_count_std_chain_avg                  46.0     36.333333  109
# restaurant_similar_density                 92.0     75.833333   92
# senti_polarity_min                         42.0     62.166667  215
# first_min_last_sent                        22.0     55.333333  316
# compliment_hot_mean                         NaN           NaN   96
# elite_count_sum                            69.0     61.166667  101
# last_sent_mean_chain_avg                   80.0     75.500000   90
# Bike Parking                                NaN           NaN   51
# photo_count_mean                            NaN           NaN  113
# cool_mean                                  79.0     79.166667  169
# senti_polarity_min_chain_avg               53.0     52.500000  104
# compliment_cool_mean_chain_std              NaN           NaN   15
# senti_polarity_sum                         40.0     30.333333  142
# Connoisseur_chain_avg                      25.0     37.000000   79
# review_count_usr_mean_chain_avg            95.0     82.833333   73
# zstar_all                                  28.0     28.166667  102
# rating_std_chain_avg                       41.0     53.333333   78
# cool_std_chain_std                         76.0     43.833333   15
# cool_amax                                   NaN           NaN   60
# Female Importance                          30.0     60.166667  292
# review_count_usr_sum                       99.0     68.000000  112
# senti_polarity_max_chain_avg               74.0     62.333333   87
# compliment_list_mean                        NaN           NaN   92
# friend_count_sum                            NaN           NaN  166
# compliment_profile_std                      NaN           NaN  106
# Low Network                                56.0     47.666667  193
# average_stars_mean_chain_std               72.0     35.833333   11
# rating_min_chain_avg                        NaN           NaN   34
# review_count_usr_max                       98.0     73.000000  152
# Male to Female_chain_avg                   91.0     79.000000   78
# compliment_cute_mean                        NaN           NaN  129
# friend_count_std                           66.0     72.166667  164
# Male to Female_chain_std                    NaN           NaN   22
# review_count_usr_min                       63.0     33.166667   90
# First Visit                                 NaN           NaN  110
# compliment_note_sum                         NaN           NaN   99
# Food Aestheticist_chain_avg                13.0     29.333333   83
# compliment_more_std                         NaN           NaN   91
# compliment_note_mean                        NaN           NaN   89
# rating_max_chain_std                        NaN           NaN   11
# Convenience Level                           NaN           NaN   52
# Number of Reviewers_chain_avg              35.0     66.666667   38
# useful_std_chain_avg                       71.0     63.000000   84
# useful_std_chain_std                       57.0     34.333333   26
# first_sent_std_chain_std                    NaN           NaN   20
# funny_mean                                 86.0     87.333333  192
# senti_polarity_max                          NaN           NaN  202
# photo_count_std                             NaN           NaN  119
# Male                                        NaN           NaN  134
# useful_amax                                 NaN           NaN   80
# reactions_per_week                         62.0     71.000000  122
# compliment_writer_mean                      NaN           NaN   91
# average_stars_sum                          39.0     52.833333  153
# first_sent_mean_chain_avg                   NaN           NaN   84
# cool_sum                                    NaN           NaN   88
# Average Customer Network_chain_std          NaN           NaN   10
# compliment_note_sum_chain_avg               NaN           NaN   35
# compliment_profile_mean                     NaN           NaN  130
# longitude_chain_std                        48.0     38.000000   36
# last_sent_sum_chain_avg                     NaN           NaN   40
# cool_amax_chain_avg                         NaN           NaN   45
# senti_polarity_mean_chain_avg              67.0     43.166667   96
# review_count_usr_std                       47.0     69.666667  145
# compliment_plain_sum                        NaN           NaN   78
# gender_mean                                60.0     79.333333  142
# friend_count_mean_chain_std                 NaN           NaN   18
# compliment_cool_std                         NaN           NaN   73
# photo_count_sum                             NaN           NaN   93
# rating_sum_chain_avg                       55.0     46.333333   30
# longitude_chain_avg                        83.0     55.166667   93
# compliment_plain_std                       90.0     74.666667  115
# last_sent_std_chain_avg                     NaN           NaN   87
# compliment_cool_sum                         NaN           NaN   60
# First Visit_chain_avg                       NaN           NaN   40
# compliment_hot_sum                          NaN           NaN   69
# friend_count_max                            NaN           NaN  143
# stars_linear_coef_chain_avg                 7.0     13.333333   83
# friend_count_std_chain_avg                  NaN           NaN   63
# review_count_usr_std_chain_avg              NaN           NaN   36
# friend_count_mean                         100.0     94.333333  138
# useful_amax_chain_avg                       NaN           NaN   82
# median_of_stars_chain_std                   NaN           NaN   15
# Average Customer Network                    NaN           NaN  115
# review_count_usr_min_chain_avg              NaN           NaN   89
# first_min_last_sent_chain_std               NaN           NaN   38
# fans_mean                                   NaN           NaN  116
# zreview_count_all_chain_std                 NaN           NaN   19
# review_count_usr_std_chain_std             45.0     30.166667   27
# gender_std_chain_std                        NaN           NaN   20
# compliment_note_std                         NaN           NaN   93
# photo_count_max                             NaN           NaN   65
# compliment_cool_mean                        NaN           NaN   66
# rating_mean                                84.0     79.833333   94
# funny_amax                                  NaN           NaN   47
# compliment_list_mean_chain_avg              NaN           NaN   49
# compliment_cute_sum                         NaN           NaN   35
# compliment_profile_mean_chain_avg           NaN           NaN   37
# compliment_list_std                         NaN           NaN   76
# average_stars_std_chain_std                 NaN           NaN   26
# compliment_list_sum                         NaN           NaN   60
# gender_std_chain_avg                       59.0     73.833333  117
# review_count_usr_max_chain_avg              NaN           NaN   41
# compliment_writer_sum                       NaN           NaN   76
# elite_count_sum_chain_avg                   NaN           NaN   62
# photo_count_mean_chain_std                  NaN           NaN    8
# compliment_cute_sum_chain_avg               NaN           NaN   26
# compliment_cute_std                         NaN           NaN   93
# average_stars_mean_chain_avg                NaN           NaN   96
# review_count_loc                            NaN           NaN   31
# fans_mean_chain_avg                         NaN           NaN   54
# compliment_more_mean_chain_std              NaN           NaN   20
# elite_count_mean_chain_avg                 87.0     72.000000   84
# review_count_usr_sum_chain_avg              NaN           NaN   29
# Patrons                                     NaN           NaN   78
# compliment_hot_std                          NaN           NaN   75
# funny_mean_chain_avg                       54.0     56.500000  107
# funny_sum                                   NaN           NaN   87
# compliment_note_std_chain_avg               NaN           NaN   34
# first_sent_sum_chain_std                    NaN           NaN   16
# friend_count_max_chain_avg                  NaN           NaN   68
# Female Importance_chain_avg                 NaN           NaN   89
# restaurant_similar_density_chain_std        NaN           NaN    9
# average_stars_sum_chain_avg                43.0     71.166667   20
# High Network_chain_avg                     68.0     60.166667   70
# gender_sum                                  NaN           NaN   75
# funny_std_chain_avg                         NaN           NaN   69
# Female_chain_avg                            NaN           NaN   71
# senti_polarity_std_chain_avg               85.0     78.666667   88
# compliment_more_std_chain_avg               NaN           NaN   31
# compliment_profile_std_chain_avg            NaN           NaN   50
# funny_amax_chain_avg                        NaN           NaN   64
# count_categories_chain_avg                  NaN           NaN   70
# funny_sum_chain_avg                         NaN           NaN   49
# Convenience Level_chain_avg                 NaN           NaN   39
# fans_sum                                   73.0     69.833333   65
# compliment_plain_std_chain_avg              NaN           NaN   41
# friend_count_sum_chain_avg                  NaN           NaN   35
# friends/review_chain_avg                   93.0     88.666667   80
# compliment_more_mean_chain_avg              NaN           NaN   30
# Number of Reviewers                        75.0     75.333333   44
# Male_chain_avg                              NaN           NaN   45
# compliment_cute_std_chain_avg               NaN           NaN   21
# reactions_per_week_chain_avg                NaN           NaN   76
# cool_mean_chain_avg                         NaN           NaN   60
# compliment_hot_mean_chain_avg               NaN           NaN   19
# restaurant_density_chain_std                NaN           NaN   13
# compliment_more_sum                         NaN           NaN   62
# friend_count_mean_chain_avg                 NaN           NaN   53
# gender_sum_chain_avg                        NaN           NaN   46
# compliment_writer_mean_chain_avg            NaN           NaN   40
# review_count_usr_max_chain_std              NaN           NaN   18
# rating_mean_chain_std                       NaN           NaN   25
# friends/review_chain_std                    NaN           NaN   11
# count_categories                            NaN           NaN   49
# Patrons_chain_avg                          96.0     85.000000   58
# compliment_hot_sum_chain_avg                NaN           NaN   22
# restaurant_similar_density_chain_avg        NaN           NaN   84
# useful_sum_chain_std                        NaN           NaN   31
# elite_count_mean_chain_std                  NaN           NaN   27
# photo_count_max_chain_avg                   NaN           NaN   27
# last_sent_mean_chain_std                    NaN           NaN   17
# Low Network_chain_avg                       NaN           NaN   45
# photo_count_mean_chain_avg                  NaN           NaN   33
# compliment_cool_std_chain_std               NaN           NaN   23
# Female_chain_std                            NaN           NaN   16
# Male_chain_std                              NaN           NaN   13
# compliment_writer_sum_chain_avg             NaN           NaN   27
# compliment_profile_sum                      NaN           NaN   45
# fans_std_chain_avg                          NaN           NaN   42
# last_sent_std_chain_std                     NaN           NaN   22
# Female Importance_chain_std                 NaN           NaN   13
# compliment_list_std_chain_avg               NaN           NaN   28
# useful_sum_chain_avg                        NaN           NaN   37
# compliment_profile_sum_chain_avg            NaN           NaN   34
# gender_mean_chain_avg                       NaN           NaN   61
# compliment_cool_std_chain_avg               NaN           NaN   40
# std_of_stars_chain_avg                     89.0     76.000000   63
# First Visit_chain_std                       NaN           NaN   16
# compliment_writer_std_chain_avg             NaN           NaN   22
# gender_mean_chain_std                       NaN           NaN   17
# compliment_plain_sum_chain_avg              NaN           NaN   26
# compliment_hot_std_chain_avg                NaN           NaN   14
# Average Customer Network_chain_avg          NaN           NaN   51
# photo_count_sum_chain_avg                   NaN           NaN   38
# restaurant_density_chain_avg               88.0     73.666667   69
# senti_polarity_max_chain_std                NaN           NaN    9
# compliment_note_mean_chain_avg              NaN           NaN   19
# review_count_loc_chain_avg                  NaN           NaN   15
# reviews_per_week_chain_std                  NaN           NaN   17
# funny_std_chain_std                         NaN           NaN   14
# senti_polarity_sum_chain_avg                NaN           NaN   27
# Connoisseur_chain_std                       NaN           NaN   15
# first_sent_sum_chain_avg                    NaN           NaN   36
# senti_polarity_std_chain_std                NaN           NaN   10
# photo_count_std_chain_avg                   NaN           NaN   19
# zreview_per_week_all_chain_std              NaN           NaN   16
# review_count_loc_chain_std                  NaN           NaN    4
# cool_amax_chain_std                         NaN           NaN    5
# count_categories_chain_std                  NaN           NaN   25
# Bike Parking_chain_avg                      NaN           NaN   28
# compliment_profile_mean_chain_std           NaN           NaN    2
# compliment_cool_sum_chain_avg               NaN           NaN   22
# compliment_cute_mean_chain_std              NaN           NaN    5
# latitude_chain_std                         65.0     37.833333   16
# photo_count_max_chain_std                   NaN           NaN    9
# useful_mean_chain_std                       NaN           NaN   10
# compliment_plain_sum_chain_std              NaN           NaN    7
# senti_polarity_sum_chain_std                NaN           NaN    4
# Patrons_chain_std                           NaN           NaN   18
# senti_polarity_min_chain_std                NaN           NaN   13
# Outdoor Seating                             NaN           NaN   20
# Bike Parking_chain_std                      NaN           NaN   14
# compliment_plain_mean_chain_avg             NaN           NaN   23
# fans_sum_chain_avg                          NaN           NaN   17
# funny_mean_chain_std                        NaN           NaN   16
# last_sent_sum_chain_std                     NaN           NaN    9
# compliment_list_sum_chain_avg               NaN           NaN   17
# fans_sum_chain_std                          NaN           NaN    7
# reactions_per_week_chain_std                NaN           NaN    9
# cool_sum_chain_avg                          NaN           NaN   22
# rating_mean_chain_avg                       NaN           NaN   16
# compliment_more_sum_chain_avg               NaN           NaN   15
# compliment_note_std_chain_std               NaN           NaN    6
# cool_mean_chain_std                         NaN           NaN    4
# funny_amax_chain_std                        NaN           NaN    6
# compliment_cute_mean_chain_avg              NaN           NaN   15
# review_count_usr_min_chain_std              NaN           NaN    6
# senti_polarity_mean_chain_std               NaN           NaN    6
# elite_count_std_chain_std                   NaN           NaN   11
# compliment_more_sum_chain_std               NaN           NaN    3
# median_of_stars                             NaN           NaN    7
# elite_count_sum_chain_std                   NaN           NaN    5
# rating_min                                  NaN           NaN    4
# average_stars_sum_chain_std                 NaN           NaN    3
# fans_mean_chain_std                         NaN           NaN    3
# compliment_cool_mean_chain_avg              NaN           NaN   17
# Low Network_chain_std                       NaN           NaN   10
# friend_count_max_chain_std                  NaN           NaN   11
# Number of Reviewers_chain_std               NaN           NaN    5
# useful_amax_chain_std                       NaN           NaN    4
# std_of_stars_chain_std                      NaN           NaN    8
# stars_linear_coef_chain_std                 NaN           NaN    5
# fans_std_chain_std                          NaN           NaN    5
# rating_max_chain_avg                        NaN           NaN    5
# friend_count_min_chain_std                  NaN           NaN    7
# friend_count_std_chain_std                  NaN           NaN    6
# compliment_note_mean_chain_std              NaN           NaN    2
# compliment_cool_sum_chain_std               NaN           NaN    7
# review_count_usr_mean_chain_std             NaN           NaN    4
# funny_sum_chain_std                         NaN           NaN    4
# compliment_list_sum_chain_std               NaN           NaN    6
# photo_count_std_chain_std                   NaN           NaN    4
# photo_count_sum_chain_std                   NaN           NaN    5
# median_of_stars_chain_avg                   NaN           NaN    6
# friend_count_sum_chain_std                  NaN           NaN    2
# Food Aestheticist_chain_std                 NaN           NaN    4
# Caters                                      NaN           NaN   11
# Caters_chain_avg                            NaN           NaN    4
# compliment_profile_std_chain_std            NaN           NaN    2
# rating_pub_chain_std                        NaN           NaN    3
# oldest_review_chain_std                     NaN           NaN    5
# compliment_list_mean_chain_std              NaN           NaN    1
# compliment_plain_mean_chain_std             NaN           NaN    3
# compliment_writer_sum_chain_std             NaN           NaN    5
# friend_count_min_chain_avg                  NaN           NaN    3
# compliment_plain_std_chain_std              NaN           NaN    2
# rating_std_chain_std                        NaN           NaN    2
# High Network_chain_std                      NaN           NaN    5
# compliment_cute_std_chain_std               NaN           NaN    1
# review_count_usr_sum_chain_std              NaN           NaN    2
# compliment_note_sum_chain_std               NaN           NaN    4
# Convenience Level_chain_std                 NaN           NaN    6
# compliment_more_std_chain_std               NaN           NaN    4
# friend_count_min                            NaN           NaN   16
# Outdoor Seating_chain_avg                   NaN           NaN    3
# rating_sum_chain_std                        NaN           NaN    2
# first_sent_mean_chain_std                   NaN           NaN    2
# compliment_list_std_chain_std               NaN           NaN    1
# compliment_writer_mean_chain_std            NaN           NaN    2
# compliment_hot_sum_chain_std                NaN           NaN    2
# rating_pub                                  NaN           NaN    2
# gender_sum_chain_std                        NaN           NaN    3
# compliment_cute_sum_chain_std               NaN           NaN    3
# compliment_hot_std_chain_std                NaN           NaN    1
# compliment_hot_mean_chain_std               NaN           NaN    3
# compliment_profile_sum_chain_std            NaN           NaN    1
# stars_std_chain_avg                         NaN           NaN    1
# compliment_writer_std_chain_std             NaN           NaN    4
# useful_amin_chain_avg                       NaN           NaN    1
# rating_min_chain_std                        NaN           NaN    1
# rating_pub_chain_avg                        NaN           NaN    1
# stars_std_chain_std                         NaN           NaN    0
# Total Network                               NaN           NaN    0
# compliment_photos_mean_chain_std            NaN           NaN    0
# compliment_photos_std_chain_std             NaN           NaN    0
# stars_sum_chain_avg                         NaN           NaN    0
# cool_amin_chain_avg                         NaN           NaN    0
# rating_max                                  NaN           NaN    0
# compliment_funny_sum                        NaN           NaN    0
# funny_amin_chain_avg                        NaN           NaN    0
# compliment_funny_mean                       NaN           NaN    0
# compliment_funny_std                        NaN           NaN    0
# compliment_photos_sum                       NaN           NaN    0
# compliment_photos_mean                      NaN           NaN    0
# compliment_photos_std                       NaN           NaN    0
# Free Wi-Fi                                  NaN           NaN    0
# compliment_funny_sum_chain_avg              NaN           NaN    0
# Takes Reservations                          NaN           NaN    0
# Total Network_chain_std                     NaN           NaN    0
# Delivery                                    NaN           NaN    0
# photo_count_min_chain_avg                   NaN           NaN    0
# Free Wi-Fi_chain_std                        NaN           NaN    0
# Takes Reservations_chain_std                NaN           NaN    0
# Outdoor Seating_chain_std                   NaN           NaN    0
# Delivery_chain_std                          NaN           NaN    0
# Caters_chain_std                            NaN           NaN    0
# Noisy                                       NaN           NaN    0
# Noisy_chain_std                             NaN           NaN    0
# gender_max_chain_avg                        NaN           NaN    0
# gender_min_chain_avg                        NaN           NaN    0
# compliment_photos_sum_chain_std             NaN           NaN    0
# compliment_funny_mean_chain_avg             NaN           NaN    0
# stars_mean_chain_std                        NaN           NaN    0
# Delivery_chain_avg                          NaN           NaN    0
# stars_sum_chain_std                         NaN           NaN    0
# gender_max                                  NaN           NaN    0
# photo_count_min                             NaN           NaN    0
# cool_amin_chain_std                         NaN           NaN    0
# useful_amin                                 NaN           NaN    0
# funny_amin_chain_std                        NaN           NaN    0
# useful_amin_chain_std                       NaN           NaN    0
# funny_amin                                  NaN           NaN    0
# photo_count_min_chain_std                   NaN           NaN    0
# gender_max_chain_std                        NaN           NaN    0
# gender_min_chain_std                        NaN           NaN    0
# cool_amin                                   NaN           NaN    0
# Noisy_chain_avg                             NaN           NaN    0
# Takes Reservations_chain_avg                NaN           NaN    0
# compliment_funny_std_chain_avg              NaN           NaN    0
# Free Wi-Fi_chain_avg                        NaN           NaN    0
# Total Network_chain_avg                     NaN           NaN    0
# is_chain                                    NaN           NaN    0
# stars_sum                                   NaN           NaN    0
# stars_mean                                  NaN           NaN    0
# stars_std                                   NaN           NaN    0
# compliment_photos_std_chain_avg             NaN           NaN    0
# compliment_photos_mean_chain_avg            NaN           NaN    0
# gender_min                                  NaN           NaN    0
# compliment_photos_sum_chain_avg             NaN           NaN    0
# compliment_funny_sum_chain_std              NaN           NaN    0
# compliment_funny_mean_chain_std             NaN           NaN    0
# compliment_funny_std_chain_std              NaN           NaN    0
# stars_mean_chain_avg                        NaN           NaN    0

# %%
shap = pd.DataFrame(shap_values[0:,:-1], columns = list(X.columns)).abs().sum().to_frame().sort_values(0,ascending=False)
# Out:
#                                                  0
# oldest_review                         10857.549129
# oldest_review_chain_avg                9427.620338
# useful_mean                            5551.318048
# stars_linear_coef                      5429.562803
# useful_sum                             5389.089699
# gender_std                             4761.522918
# restaurant_density                     4562.308184
# Connoisseur                            4330.761405
# rating_sum                             4229.343310
# reviews_per_week                       4049.851485
# latitude                               3652.926755
# compliment_plain_mean                  3633.171469
# zreview_count_all                      3614.698967
# average_stars_mean                     3543.036126
# zstar_all_chain_std                    3494.586635
# elite_count_mean                       3462.528845
# first_sent_mean                        3403.862081
# Male to Female                         3322.669813
# first_sent_std_chain_avg               3233.481576
# zreview_per_week_all                   3222.254830
# elite_count_std                        3191.009706
# compliment_more_mean                   2825.727827
# zreview_count_all_chain_avg            2817.500884
# rating_std                             2773.276921
# reviews_per_week_chain_avg             2747.474297
# first_sent_std                         2663.498614
# last_sent_std                          2604.101943
# fans_std                               2476.905742
# funny_std                              2418.917435
# useful_mean_chain_avg                  2406.109241
# last_sent_sum                          2351.729934
# average_stars_std                      2335.291104
# review_count_usr_mean                  2305.839132
# High Network                           2238.115340
# Food Aestheticist                      2222.190365
# friends/review                         2219.899389
# Female                                 2198.597273
# latitude_chain_avg                     2187.508888
# senti_polarity_mean                    2102.813695
# first_sent_sum                         2077.014307
# zstar_all_chain_avg                    2076.150498
# zreview_per_week_all_chain_avg         2071.691913
# cool_std_chain_avg                     2041.559331
# last_sent_mean                         2032.141687
# cool_sum_chain_std                     1998.435895
# useful_std                             1972.983615
# std_of_stars                           1971.469032
# average_stars_std_chain_avg            1948.800760
# first_min_last_sent_chain_avg          1912.922775
# senti_polarity_std                     1912.211850
# compliment_writer_std                  1907.345471
# longitude                              1900.827232
# cool_std                               1862.917704
# elite_count_std_chain_avg              1853.306487
# restaurant_similar_density             1829.069525
# senti_polarity_min                     1827.048264
# first_min_last_sent                    1797.428403
# compliment_hot_mean                    1780.091737
# elite_count_sum                        1763.122962
# last_sent_mean_chain_avg               1751.887298
# Bike Parking                           1730.827902
# photo_count_mean                       1680.963421
# cool_mean                              1678.360141
# senti_polarity_min_chain_avg           1657.526769
# compliment_cool_mean_chain_std         1649.190884
# senti_polarity_sum                     1642.615134
# Connoisseur_chain_avg                  1613.778996
# review_count_usr_mean_chain_avg        1578.680914
# zstar_all                              1572.909345
# rating_std_chain_avg                   1569.984972
# cool_std_chain_std                     1545.666877
# cool_amax                              1513.591224
# Female Importance                      1498.514595
# review_count_usr_sum                   1484.679737
# senti_polarity_max_chain_avg           1469.285408
# compliment_list_mean                   1437.964474
# friend_count_sum                       1427.295488
# compliment_profile_std                 1423.316223
# Low Network                            1410.890482
# average_stars_mean_chain_std           1349.000222
# rating_min_chain_avg                   1348.250066
# review_count_usr_max                   1335.465050
# Male to Female_chain_avg               1312.032475
# compliment_cute_mean                   1310.702596
# friend_count_std                       1301.886270
# Male to Female_chain_std               1298.168623
# review_count_usr_min                   1284.283990
# First Visit                            1234.278018
# compliment_note_sum                    1222.359799
# Food Aestheticist_chain_avg            1217.571212
# compliment_more_std                    1207.338522
# compliment_note_mean                   1199.897070
# rating_max_chain_std                   1198.339490
# Convenience Level                      1197.557426
# Number of Reviewers_chain_avg          1194.861365
# useful_std_chain_avg                   1193.019562
# useful_std_chain_std                   1192.537081
# first_sent_std_chain_std               1156.932316
# funny_mean                             1156.392746
# senti_polarity_max                     1155.687675
# photo_count_std                        1155.446162
# Male                                   1132.286043
# useful_amax                            1127.777419
# reactions_per_week                     1125.709721
# compliment_writer_mean                 1115.065941
# average_stars_sum                      1108.320830
# first_sent_mean_chain_avg              1094.849906
# cool_sum                               1094.697560
# Average Customer Network_chain_std     1083.504978
# compliment_note_sum_chain_avg          1077.502412
# compliment_profile_mean                1073.088205
# longitude_chain_std                    1056.146783
# last_sent_sum_chain_avg                1055.061064
# cool_amax_chain_avg                    1047.332976
# senti_polarity_mean_chain_avg          1044.612201
# review_count_usr_std                   1039.757100
# compliment_plain_sum                   1030.250986
# gender_mean                            1023.965480
# friend_count_mean_chain_std            1022.714096
# compliment_cool_std                    1020.868988
# photo_count_sum                         997.825355
# rating_sum_chain_avg                    993.101054
# longitude_chain_avg                     992.873586
# compliment_plain_std                    984.941922
# last_sent_std_chain_avg                 973.579738
# compliment_cool_sum                     960.029650
# First Visit_chain_avg                   955.737819
# compliment_hot_sum                      953.954746
# friend_count_max                        953.194722
# stars_linear_coef_chain_avg             951.868435
# friend_count_std_chain_avg              939.379086
# review_count_usr_std_chain_avg          937.090192
# friend_count_mean                       927.788308
# useful_amax_chain_avg                   924.233619
# median_of_stars_chain_std               918.358196
# Average Customer Network                917.814750
# review_count_usr_min_chain_avg          905.771082
# first_min_last_sent_chain_std           899.060981
# fans_mean                               895.946757
# zreview_count_all_chain_std             891.995184
# review_count_usr_std_chain_std          860.423111
# gender_std_chain_std                    851.303823
# compliment_note_std                     836.073021
# photo_count_max                         835.423708
# compliment_cool_mean                    820.468473
# rating_mean                             817.306090
# funny_amax                              814.380262
# compliment_list_mean_chain_avg          811.547681
# compliment_cute_sum                     809.596351
# compliment_profile_mean_chain_avg       794.334958
# compliment_list_std                     783.406414
# average_stars_std_chain_std             765.738793
# compliment_list_sum                     765.361420
# gender_std_chain_avg                    764.454087
# review_count_usr_max_chain_avg          761.327408
# compliment_writer_sum                   758.666814
# elite_count_sum_chain_avg               757.248773
# photo_count_mean_chain_std              752.193339
# compliment_cute_sum_chain_avg           725.362080
# compliment_cute_std                     724.169643
# average_stars_mean_chain_avg            723.596513
# review_count_loc                        716.019532
# fans_mean_chain_avg                     711.166927
# compliment_more_mean_chain_std          703.824493
# elite_count_mean_chain_avg              683.898533
# review_count_usr_sum_chain_avg          677.501172
# Patrons                                 674.510061
# compliment_hot_std                      672.198085
# funny_mean_chain_avg                    665.150782
# funny_sum                               657.198483
# compliment_note_std_chain_avg           653.299297
# first_sent_sum_chain_std                653.060873
# friend_count_max_chain_avg              650.686975
# Female Importance_chain_avg             644.999151
# restaurant_similar_density_chain_std    638.082965
# average_stars_sum_chain_avg             637.620370
# High Network_chain_avg                  634.903225
# gender_sum                              633.708104
# funny_std_chain_avg                     631.005637
# Female_chain_avg                        630.166984
# senti_polarity_std_chain_avg            629.566608
# compliment_more_std_chain_avg           625.711086
# compliment_profile_std_chain_avg        611.759263
# funny_amax_chain_avg                    602.557393
# count_categories_chain_avg              600.892632
# funny_sum_chain_avg                     600.657134
# Convenience Level_chain_avg             597.448742
# fans_sum                                597.012731
# compliment_plain_std_chain_avg          596.691775
# friend_count_sum_chain_avg              588.894841
# friends/review_chain_avg                585.915308
# compliment_more_mean_chain_avg          583.908702
# Number of Reviewers                     578.382782
# Male_chain_avg                          573.719671
# compliment_cute_std_chain_avg           573.533990
# reactions_per_week_chain_avg            564.823770
# cool_mean_chain_avg                     561.096526
# compliment_hot_mean_chain_avg           553.829286
# restaurant_density_chain_std            551.985259
# compliment_more_sum                     551.132322
# friend_count_mean_chain_avg             543.876655
# gender_sum_chain_avg                    542.948153
# compliment_writer_mean_chain_avg        539.585605
# review_count_usr_max_chain_std          533.379969
# rating_mean_chain_std                   533.181562
# friends/review_chain_std                530.077897
# count_categories                        521.873740
# Patrons_chain_avg                       518.682428
# compliment_hot_sum_chain_avg            511.334925
# restaurant_similar_density_chain_avg    509.899712
# useful_sum_chain_std                    500.999217
# elite_count_mean_chain_std              500.922130
# photo_count_max_chain_avg               491.831338
# last_sent_mean_chain_std                490.841484
# Low Network_chain_avg                   486.770270
# photo_count_mean_chain_avg              481.042774
# compliment_cool_std_chain_std           474.188728
# Female_chain_std                        471.252302
# Male_chain_std                          464.573160
# compliment_writer_sum_chain_avg         453.158575
# compliment_profile_sum                  449.566871
# fans_std_chain_avg                      422.055782
# last_sent_std_chain_std                 421.188866
# Female Importance_chain_std             416.372116
# compliment_list_std_chain_avg           407.862736
# useful_sum_chain_avg                    394.860159
# compliment_profile_sum_chain_avg        392.822333
# gender_mean_chain_avg                   388.076855
# compliment_cool_std_chain_avg           384.771868
# std_of_stars_chain_avg                  382.790287
# First Visit_chain_std                   381.398751
# compliment_writer_std_chain_avg         381.355842
# gender_mean_chain_std                   369.924932
# compliment_plain_sum_chain_avg          367.211517
# compliment_hot_std_chain_avg            351.620217
# Average Customer Network_chain_avg      348.163911
# photo_count_sum_chain_avg               342.994019
# restaurant_density_chain_avg            335.094981
# senti_polarity_max_chain_std            333.183445
# compliment_note_mean_chain_avg          332.398431
# review_count_loc_chain_avg              319.415415
# reviews_per_week_chain_std              316.562439
# funny_std_chain_std                     315.976202
# senti_polarity_sum_chain_avg            307.730394
# Connoisseur_chain_std                   304.822308
# first_sent_sum_chain_avg                300.383138
# senti_polarity_std_chain_std            299.028207
# photo_count_std_chain_avg               297.323491
# zreview_per_week_all_chain_std          287.191401
# review_count_loc_chain_std              281.992410
# cool_amax_chain_std                     279.050690
# count_categories_chain_std              274.209008
# Bike Parking_chain_avg                  272.442709
# compliment_profile_mean_chain_std       268.298583
# compliment_cool_sum_chain_avg           265.693676
# compliment_cute_mean_chain_std          253.228004
# latitude_chain_std                      252.681446
# photo_count_max_chain_std               249.875563
# useful_mean_chain_std                   247.065276
# compliment_plain_sum_chain_std          234.245701
# senti_polarity_sum_chain_std            232.492534
# Patrons_chain_std                       227.127446
# senti_polarity_min_chain_std            224.799543
# Outdoor Seating                         219.756443
# Bike Parking_chain_std                  218.760284
# compliment_plain_mean_chain_avg         218.130384
# fans_sum_chain_avg                      210.848031
# funny_mean_chain_std                    205.525551
# last_sent_sum_chain_std                 200.623153
# compliment_list_sum_chain_avg           198.086404
# fans_sum_chain_std                      194.789487
# reactions_per_week_chain_std            192.511042
# cool_sum_chain_avg                      186.315989
# rating_mean_chain_avg                   185.363037
# compliment_more_sum_chain_avg           180.109943
# compliment_note_std_chain_std           179.946306
# cool_mean_chain_std                     175.357072
# funny_amax_chain_std                    174.331597
# compliment_cute_mean_chain_avg          173.374398
# review_count_usr_min_chain_std          167.410256
# senti_polarity_mean_chain_std           158.817440
# elite_count_std_chain_std               158.392604
# compliment_more_sum_chain_std           155.539186
# median_of_stars                         149.623767
# elite_count_sum_chain_std               149.472920
# rating_min                              149.029068
# average_stars_sum_chain_std             144.674173
# fans_mean_chain_std                     144.568951
# compliment_cool_mean_chain_avg          141.651023
# Low Network_chain_std                   140.482842
# friend_count_max_chain_std              139.952945
# Number of Reviewers_chain_std           132.693334
# useful_amax_chain_std                   131.719441
# std_of_stars_chain_std                  131.716050
# stars_linear_coef_chain_std             127.391859
# fans_std_chain_std                      126.951295
# rating_max_chain_avg                    122.910704
# friend_count_min_chain_std              121.718822
# friend_count_std_chain_std              120.674734
# compliment_note_mean_chain_std          115.787958
# compliment_cool_sum_chain_std           114.190745
# review_count_usr_mean_chain_std         114.041800
# funny_sum_chain_std                     109.080178
# compliment_list_sum_chain_std           108.356610
# photo_count_std_chain_std               103.839297
# photo_count_sum_chain_std               100.364969
# median_of_stars_chain_avg                98.948743
# friend_count_sum_chain_std               95.382363
# Food Aestheticist_chain_std              94.805446
# Caters                                   84.092307
# Caters_chain_avg                         83.650913
# compliment_profile_std_chain_std         79.767305
# rating_pub_chain_std                     72.627878
# oldest_review_chain_std                  71.972563
# compliment_list_mean_chain_std           71.480174
# compliment_plain_mean_chain_std          67.436146
# compliment_writer_sum_chain_std          66.746822
# friend_count_min_chain_avg               66.669438
# compliment_plain_std_chain_std           65.633996
# rating_std_chain_std                     61.332893
# High Network_chain_std                   59.757461
# compliment_cute_std_chain_std            58.255486
# review_count_usr_sum_chain_std           56.337261
# compliment_note_sum_chain_std            56.101440
# Convenience Level_chain_std              55.805485
# compliment_more_std_chain_std            52.973268
# friend_count_min                         52.528531
# Outdoor Seating_chain_avg                50.441434
# rating_sum_chain_std                     46.785054
# first_sent_mean_chain_std                44.351533
# compliment_list_std_chain_std            42.756419
# compliment_writer_mean_chain_std         42.461924
# compliment_hot_sum_chain_std             39.169600
# rating_pub                               38.097965
# gender_sum_chain_std                     37.969091
# compliment_cute_sum_chain_std            36.922184
# compliment_hot_std_chain_std             35.934638
# compliment_hot_mean_chain_std            35.326957
# compliment_profile_sum_chain_std         30.594769
# stars_std_chain_avg                      29.532080
# compliment_writer_std_chain_std          24.787624
# useful_amin_chain_avg                    23.261251
# rating_min_chain_std                     17.592188
# rating_pub_chain_avg                     15.801142
# stars_std_chain_std                       0.000000
# Total Network                             0.000000
# compliment_photos_mean_chain_std          0.000000
# compliment_photos_std_chain_std           0.000000
# stars_sum_chain_avg                       0.000000
# cool_amin_chain_avg                       0.000000
# rating_max                                0.000000
# compliment_funny_sum                      0.000000
# funny_amin_chain_avg                      0.000000
# compliment_funny_mean                     0.000000
# compliment_funny_std                      0.000000
# compliment_photos_sum                     0.000000
# compliment_photos_mean                    0.000000
# compliment_photos_std                     0.000000
# Free Wi-Fi                                0.000000
# compliment_funny_sum_chain_avg            0.000000
# Takes Reservations                        0.000000
# Total Network_chain_std                   0.000000
# Delivery                                  0.000000
# photo_count_min_chain_avg                 0.000000
# Free Wi-Fi_chain_std                      0.000000
# Takes Reservations_chain_std              0.000000
# Outdoor Seating_chain_std                 0.000000
# Delivery_chain_std                        0.000000
# Caters_chain_std                          0.000000
# Noisy                                     0.000000
# Noisy_chain_std                           0.000000
# gender_max_chain_avg                      0.000000
# gender_min_chain_avg                      0.000000
# compliment_photos_sum_chain_std           0.000000
# compliment_funny_mean_chain_avg           0.000000
# stars_mean_chain_std                      0.000000
# Delivery_chain_avg                        0.000000
# stars_sum_chain_std                       0.000000
# gender_max                                0.000000
# photo_count_min                           0.000000
# cool_amin_chain_std                       0.000000
# useful_amin                               0.000000
# funny_amin_chain_std                      0.000000
# useful_amin_chain_std                     0.000000
# funny_amin                                0.000000
# photo_count_min_chain_std                 0.000000
# gender_max_chain_std                      0.000000
# gender_min_chain_std                      0.000000
# cool_amin                                 0.000000
# Noisy_chain_avg                           0.000000
# Takes Reservations_chain_avg              0.000000
# compliment_funny_std_chain_avg            0.000000
# Free Wi-Fi_chain_avg                      0.000000
# Total Network_chain_avg                   0.000000
# is_chain                                  0.000000
# stars_sum                                 0.000000
# stars_mean                                0.000000
# stars_std                                 0.000000
# compliment_photos_std_chain_avg           0.000000
# compliment_photos_mean_chain_avg          0.000000
# gender_min                                0.000000
# compliment_photos_sum_chain_avg           0.000000
# compliment_funny_sum_chain_std            0.000000
# compliment_funny_mean_chain_std           0.000000
# compliment_funny_std_chain_std            0.000000
# stars_mean_chain_avg                      0.000000

# %%
X["latitude"].head()
# Out:
# 5323    43.707978
# 5327    43.653221
# 5326    41.412350
# 5325    45.517876
# 5324    40.543238
# Name: latitude, dtype: float64

# %%
import matplotlib as mpl

mpl.rcParams['figure.figsize'] = (10,10)

# %%
shap.summary_plot(shap_values, X)

# %%
shap.summary_plot(shap_values, X)

# %%
shap.summary_plot(shap_values, X)

# %%
shap.dependence_plot(name, shap_values, X, display_features=X)

# %%
for name in X_train.iloc[:,:13].columns:
    shap.dependence_plot(name, shap_values, X, display_features=X)

# %%
import xgboost as xgb

gbm = xgb.XGBClassifier(max_depth=7, n_estimators=1000, learning_rate=0.05).fit(X_train,y_train)

# %%
import xgbfir

xgbfir.saveXgbFI(gbm,feature_names=list(X.columns), OutputXlsxFile='feats_inter_sans.xlsx')

# %%
pd.DataFrame(shap_values[0:,:-1], columns = list(X.columns)).sum().to_frame().sort_values(0,ascending=False)
# Out:
#                                0
# days_std_chain_avg   1611.637224
# days_std             1339.377914
# diffs_max            1152.594965
# oldest_review        1023.657339
# diffs_sum             496.071660
# useful_mean           171.015290
# restaurant_density     66.274961
# diffs_mean           -456.770338
# days_mean            -742.349588
# diffs_sum_chain_avg -1610.956385

# %%
### You had to take abs volaue so wel done. 

abs_shap = pd.DataFrame(shap_values[0:,:-1], columns = list(X.columns)).abs().sum().to_frame().sort_values(0,ascending=False)

lit = []
for r in list(abs_shap.index.values[:10]):
    t = X.columns.get_loc(r)
    lit.append(t)
    print(t)

lit

X.head()

shap.force_plot(shap_values[:100,np.r_[10,30]], X.iloc[:100,np.r_[10,30]], link="logit")

# %%
shap.force_plot(shap_values[:100,:], X.iloc[:100,:], link="logit")
# Out:
# <div id='i1TFFVIUNAMXHSZG6UIL8'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security.
# </div></div>
#  <script>
#    if (window.IML) IML.ReactDom.render(
#     IML.React.createElement(IML.AdditiveForceArrayVisualizer, {"outNames": ["output value"], "baseValue": 2.809777991541346, "link": "logit", "featureNames": ["days_mean", "diffs_sum", "days_std", "diffs_mean", "diffs_max", "days_std_chain_avg", "diffs_sum_chain_avg", "useful_mean", "restaurant_density", "oldest_review"], "explanations": [{"outValue": 2.7400271541782297, "simIndex": 79.0, "features": {"0": {"effect": -0.7707974744371151, "value": 2204.4}, "1": {"effect": -0.165878912214466, "value": 1956.0}, "2": {"effect": 0.323817201620702, "value": 970.8806826793907}, "3": {"effect": 1.1637261448556804, "value": 489.0}, "4": {"effect": -0.5331490239794662, "value": 1255.0}, "5": {"effect": -0.16692845758890504, "value": 695.0764956218812}, "6": {"effect": 0.13404159665634005, "value": 1582.25}, "7": {"effect": 0.06504345812080517, "value": 1.2}, "8": {"effect": -0.14780017866944678, "value": 22.0}, "9": {"effect": 0.028174808272755352, "value": 279.42857142857144}}}, {"outValue": 1.5686700220319862, "simIndex": 59.0, "features": {"0": {"effect": -1.2745380164891937, "value": 2358.4615384615386}, "1": {"effect": -0.3208277658789953, "value": 1615.0}, "2": {"effect": -0.12181223772074502, "value": 827.8281439389674}, "3": {"effect": 0.22928959463039672, "value": 134.58333333333334}, "4": {"effect": -0.04369617300954367, "value": 349.0}, "5": {"effect": 0.1799106546458925, "value": 827.8281439389674}, "6": {"effect": 0.11738309063252231, "value": 1615.0}, "7": {"effect": -0.10449477927988494, "value": 1.2307692307692308}, "8": {"effect": 0.09665037482513777, "value": 12.0}, "9": {"effect": 0.001027288135053691, "value": 230.7142857142857}}}, {"outValue": 5.020011118384285, "simIndex": 1.0, "features": {"0": {"effect": 1.1538018159480767, "value": 1397.833333333333}, "1": {"effect": -0.12239088121791765, "value": 1263.0}, "2": {"effect": -0.18454089821235098, "value": 655.3116561352061}, "3": {"effect": 0.3447255600624939, "value": 252.6}, "4": {"effect": -0.1720387010560248, "value": 776.0}, "5": {"effect": 0.39731293568443915, "value": 836.6051528880774}, "6": {"effect": 0.37804516350371503, "value": 2146.7476635514013}, "7": {"effect": 0.2371296170238689, "value": 0.0}, "8": {"effect": 0.23959841525917855, "value": 8.0}, "9": {"effect": -0.0614099001525397, "value": 180.42857142857144}}}, {"outValue": 2.2115593512869705, "simIndex": 60.0, "features": {"0": {"effect": -0.8820888644338246, "value": 2102.7619047619046}, "1": {"effect": 0.10460392757349128, "value": 2685.0}, "2": {"effect": 0.024002847561464546, "value": 849.7303633954657}, "3": {"effect": 0.2392572087456016, "value": 134.25}, "4": {"effect": -0.21049761788835028, "value": 529.0}, "5": {"effect": 0.1865847939244014, "value": 875.1651828729902}, "6": {"effect": 0.05264100597087246, "value": 1716.2}, "7": {"effect": -0.11441552700491536, "value": 1.0}, "8": {"effect": -0.03088904838160446, "value": 120.06583351930372}, "9": {"effect": 0.03258263367848828, "value": 274.6643553203469}}}, {"outValue": 2.6256739088038974, "simIndex": 68.0, "features": {"0": {"effect": -0.03825076614405103, "value": 1814.25}, "1": {"effect": -0.02329677106550707, "value": 1929.0}, "2": {"effect": -0.16957758410279172, "value": 768.0857107712062}, "3": {"effect": 0.09379249634910147, "value": 175.36363636363637}, "4": {"effect": -0.14922491180490796, "value": 462.0}, "5": {"effect": -0.03139975136222358, "value": 797.1334733681059}, "6": {"effect": 0.198263526205696, "value": 1925.3103448275863}, "7": {"effect": -0.03372730157649592, "value": 0.8333333333333334}, "8": {"effect": -0.05752453740890167, "value": 31.0}, "9": {"effect": 0.026841518172632903, "value": 275.57142857142856}}}, {"outValue": 0.23855984162323063, "simIndex": 55.0, "features": {"0": {"effect": -1.2979182281444976, "value": 2180.1041666666665}, "1": {"effect": -0.09084342095632979, "value": 2330.0}, "2": {"effect": -0.11693359459245939, "value": 776.6242893386612}, "3": {"effect": -0.37083118716895613, "value": 49.57 ...

# %%
shap.force_plot(shap_values[100,:], X.iloc[100,:], link="logit")
# Out:
# <div id='iUIZ77CHJM6N2SIC6MU8E'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security.
# </div></div>
#  <script>
#    if (window.IML) IML.ReactDom.render(
#     IML.React.createElement(IML.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 2.809777991541346, "outValue": 1.5124584969733716, "link": "logit", "featureNames": ["days_mean", "diffs_sum", "days_std", "diffs_mean", "diffs_max", "days_std_chain_avg", "diffs_sum_chain_avg", "useful_mean", "restaurant_density", "oldest_review"], "features": {"0": {"effect": -1.452248544662814, "value": 2402.2903225806454}, "1": {"effect": 0.3471969606653061, "value": 3033.0}, "2": {"effect": -0.09122586805275527, "value": 777.4044933215646}, "3": {"effect": 0.6812025546532806, "value": 101.1}, "4": {"effect": -0.19239928415404617, "value": 460.0}, "5": {"effect": -0.1969525792781135, "value": 0.0}, "6": {"effect": -0.2747648055086846, "value": 0.0}, "7": {"effect": -0.1486703306721935, "value": 0.7096774193548387}, "8": {"effect": -0.00841239771620191, "value": 120.06583351930372}, "9": {"effect": 0.03895480015824799, "value": 274.6643553203469}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iUIZ77CHJM6N2SIC6MU8E')
#   );
# </script>

# %%
shap.force_plot(shap_values, X)
# Out:
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/shap/plots.py:592: UserWarning: shap.force_plot is slow many thousands of rows, try subsampling your data.
#   warnings.warn("shap.force_plot is slow many thousands of rows, try subsampling your data.")

# %%
lgbm.fit(X_train, y_train, eval_set=[(X_train, y_train)],eval_metric='AUC',
        early_stopping_rounds=5)

y_pred = lgbm.predict(X_test)
y_pred_proba = lgbm.predict_proba(X_test)
accuracy_score(y_test, y_pred)



import matplotlib.pyplot as plt
import scikitplot as skplt

skplt.metrics.plot_roc_curve(y_test, y_pred_proba)
plt.show()

ga = pd.DataFrame()

ga["name"] = X.columns

ga["imp"] = lgbm.feature_importances_
print(accuracy_score(y_test, y_pred))
pd.set_option("display.max_rows",None)

# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from sklearn.metrics import confusion_matrix,precision_recall_curve,auc,roc_auc_score,roc_curve,recall_score,classification_report,accuracy_score

#X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33)

train = 0.67
range_size = int(len(X)*train)
X_train, X_test, y_train, y_test = X.iloc[:range_size,:], X.iloc[range_size:,:], Y.iloc[:range_size], Y.iloc[range_size:]

# This is what I expect a human to get 
Y.sum()/(Y.count())

from lightgbm import LGBMClassifier


lgbm = LGBMClassifier(boosting_type='gbdt', objective='binary',
                       num_class=1,early_stopping = 50,
                       is_enable_sparse='true',tree_learner='data',num_leaves=31,num_iteration=10000,min_data_in_leaf=100,max_depth=14,
                       learning_rate=0.1, n_estimators=1000, max_bin=255, subsample_for_bin=500, 
                       min_split_gain=5, min_child_weight=5, min_child_samples=5, subsample=0.995, 
                       subsample_freq=1, colsample_bytree=1, reg_alpha=0, 
                       reg_lambda=0, seed=0, nthread=-1, silent=True,)

lgbm.fit(X_train, y_train, eval_set=[(X_train, y_train)],eval_metric='AUC',
        early_stopping_rounds=5)

y_pred = lgbm.predict(X_test)
y_pred_proba = lgbm.predict_proba(X_test)
accuracy_score(y_test, y_pred)



import matplotlib.pyplot as plt
import scikitplot as skplt

skplt.metrics.plot_roc_curve(y_test, y_pred_proba)
plt.show()

ga = pd.DataFrame()

ga["name"] = X.columns

ga["imp"] = lgbm.feature_importances_
print(accuracy_score(y_test, y_pred))
pd.set_option("display.max_rows",None)
# Out:
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/lightgbm/engine.py:99: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/lightgbm/engine.py:104: UserWarning: Found `early_stopping` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	training's auc: 0.754216
# Training until validation scores don't improve for 50 rounds.
# [2]	training's auc: 0.774986
# [3]	training's auc: 0.780887
# [4]	training's auc: 0.791206
# [5]	training's auc: 0.803704
# [6]	training's auc: 0.806146
# [7]	training's auc: 0.808055
# [8]	training's auc: 0.810488
# [9]	training's auc: 0.812801
# [10]	training's auc: 0.817025
# [11]	training's auc: 0.818193
# [12]	training's auc: 0.819614
# [13]	training's auc: 0.824379
# [14]	training's auc: 0.825665
# [15]	training's auc: 0.828518
# [16]	training's auc: 0.83052
# [17]	training's auc: 0.833184
# [18]	training's auc: 0.835004
# [19]	training's auc: 0.837711
# [20]	training's auc: 0.839446
# [21]	training's auc: 0.841693
# [22]	training's auc: 0.845827
# [23]	training's auc: 0.848617
# [24]	training's auc: 0.851357
# [25]	training's auc: 0.854738
# [26]	training's auc: 0.856883
# [27]	training's auc: 0.858518
# [28]	training's auc: 0.860441
# [29]	training's auc: 0.862856
# [30]	training's auc: 0.8649
# [31]	training's auc: 0.866397
# [32]	training's auc: 0.867623
# [33]	training's auc: 0.869566
# [34]	training's auc: 0.871074
# [35]	training's auc: 0.872435
# [36]	training's auc: 0.874101
# [37]	training's auc: 0.875325
# [38]	training's auc: 0.876828
# [39]	training's auc: 0.878664
# [40]	training's auc: 0.880861
# [41]	training's auc: 0.882831
# [42]	training's auc: 0.883808
# [43]	training's auc: 0.884973
# [44]	training's auc: 0.886788
# [45]	training's auc: 0.887536
# [46]	training's auc: 0.889178
# [47]	training's auc: 0.889934
# [48]	training's auc: 0.89092
# [49]	training's auc: 0.891866
# [50]	training's auc: 0.893165
# [51]	training's auc: 0.89364
# [52]	training's auc: 0.894384
# [53]	training's auc: 0.8947
# [54]	training's auc: 0.895327
# [55]	training's auc: 0.895817
# [56]	training's auc: 0.896512
# [57]	training's auc: 0.897015
# [58]	training's auc: 0.897377
# [59]	training's auc: 0.89751
# [60]	training's auc: 0.897614
# [61]	training's auc: 0.89757
# [62]	training's auc: 0.897693
# [63]	training's auc: 0.897676
# [64]	training's auc: 0.898119
# [65]	training's auc: 0.898204
# [66]	training's auc: 0.898253
# [67]	training's auc: 0.898212
# [68]	training's auc: 0.898206
# [69]	training's auc: 0.898206
# [70]	training's auc: 0.898206
# [71]	training's auc: 0.898206
# [72]	training's auc: 0.898206
# [73]	training's auc: 0.898206
# [74]	training's auc: 0.898206
# [75]	training's auc: 0.898206
# [76]	training's auc: 0.898206
# [77]	training's auc: 0.898206
# [78]	training's auc: 0.898206
# [79]	training's auc: 0.898206
# [80]	training's auc: 0.898206
# [81]	training's auc: 0.898206
# [82]	training's auc: 0.898206
# [83]	training's auc: 0.898206
# [84]	training's auc: 0.898206
# [85]	training's auc: 0.898206
# [86]	training's auc: 0.898206
# [87]	training's auc: 0.898206
# [88]	training's auc: 0.898206
# [89]	training's auc: 0.898206
# [90]	training's auc: 0.898206
# [91]	training's auc: 0.898206
# [92]	training's auc: 0.898206
# [93]	training's auc: 0.898206
# [94]	training's auc: 0.898206
# [95]	training's auc: 0.898206
# [96]	training's auc: 0.898206
# [97]	training's auc: 0.898206
# [98]	training's auc: 0.898206
# [99]	training's auc: 0.898206
# [100]	training's auc: 0.898206
# [101]	training's auc: 0.898206
# [102]	training's auc: 0.898206
# [103]	training's auc: 0.898206
# [104]	training's auc: 0.898206
# [105]	training's auc: 0.898206
# [106]	training's auc: 0.898206
# [107]	training's auc: 0.898206
# [108]	training's auc: 0.898206
# [109]	training's auc: 0.898206
# [110]	training's auc: 0.898206
# [111]	training's auc: 0.898206
# [112]	training's auc: 0.898206
# [113]	training's auc: 0.898206
# [114]	training's auc: 0.898206
# [115]	training's auc: 0.898206
# [116]	training's auc: 0.898206
# Early stopping, best iteration is:
# [66]	training's auc: 0.898253
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: The spectral and spectral_r colormap was deprecated in version 2.0. Use nipy_spectral and nipy_spectral_r instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# 0.9705558613098514

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9297031354236157

# %%
ga.sort_values("imp",ascending=False)
# Out:
#                                      name  imp
# 118                             days_mean  252
# 119                              days_std  142
# 7                               diffs_sum  107
# 8                              diffs_mean   74
# 44                            useful_mean   42
# 64                      stars_linear_coef   41
# 125                           Connoisseur   35
# 261                   days_mean_chain_avg   34
# 262                    days_std_chain_avg   30
# 5                               diffs_std   29
# 28                  review_count_usr_mean   25
# 9                               diffs_max   25
# 151                   diffs_sum_chain_avg   22
# 66                     restaurant_density   22
# 69                   zreview_per_week_all   21
# 143                   first_min_last_sent   20
# 56                               latitude   19
# 10                             gender_std   19
# 2                              rating_sum   19
# 29                   review_count_usr_max   18
# 200                    latitude_chain_avg   18
# 61                          oldest_review   18
# 0                              rating_std   18
# 68                      zreview_count_all   17
# 205               oldest_review_chain_avg   17
# 26                   review_count_usr_min   16
# 142                        friends/review   15
# 120                        Male to Female   15
# 212           zreview_count_all_chain_avg   15
# 32                     senti_polarity_sum   14
# 268                 Connoisseur_chain_avg   14
# 79                     average_stars_mean   13
# 60                       reviews_per_week   12
# 269           Food Aestheticist_chain_avg   12
# 213        zreview_per_week_all_chain_avg   12
# 170        review_count_usr_min_chain_avg   11
# 38                          last_sent_std   11
# 130              Average Customer Network   11
# 57                              longitude   11
# 37                         first_sent_std   11
# 70                              zstar_all   10
# 43                             useful_sum   10
# 126                     Food Aestheticist   10
# 175          senti_polarity_min_chain_avg    9
# 124                           Low Network    8
# 208           stars_linear_coef_chain_avg    8
# 265                      Female_chain_avg    7
# 133                     Convenience Level    7
# 355           zreview_count_all_chain_std    7
# 145                  rating_min_chain_avg    7
# 80                      average_stars_std    7
# 39                         first_sent_sum    7
# 241         compliment_note_std_chain_avg    6
# 384         compliment_note_std_chain_std    6
# 181              first_sent_std_chain_avg    6
# 123                          High Network    6
# 13                            gender_mean    6
# 30                     senti_polarity_std    6
# 188                 useful_mean_chain_avg    5
# 67             restaurant_similar_density    5
# 25                   review_count_usr_std    5
# 117                              days_sum    5
# 18                      friend_count_mean    5
# 31                     senti_polarity_min    5
# 204            reviews_per_week_chain_avg    4
# 173        review_count_usr_max_chain_avg    4
# 144                  rating_std_chain_avg    4
# 275         Number of Reviewers_chain_avg    4
# 152                  diffs_mean_chain_avg    4
# 286         first_min_last_sent_chain_avg    4
# 162           friend_count_mean_chain_avg    4
# 96                    compliment_note_sum    4
# 128                           First Visit    4
# 146                  rating_sum_chain_avg    4
# 40                          last_sent_sum    4
# 319          senti_polarity_sum_chain_std    4
# 178          senti_polarity_max_chain_avg    4
# 115                      elite_count_mean    4
# 406              Male to Female_chain_std    4
# 150                   diffs_min_chain_avg    3
# 141                      review_count_loc    3
# 194                  funny_amax_chain_avg    3
# 333                   funny_std_chain_std    3
# 6                               diffs_min    3
# 27                   review_count_usr_sum    3
# 184               last_sent_sum_chain_avg    3
# 41                             useful_std    3
# 416    Average Customer Network_chain_std    3
# 139                          Bike Parking    3
# 51                               cool_std    3
# 344                   longitude_chain_std    3
# 404                   days_mean_chain_std    3
# 328                  useful_std_chain_std    3
# 36                         last_sent_mean    3
# 78                      average_stars_sum    3
# 209          reactions_per_week_chain_avg    2
# 132                   Number of Reviewers    2
# 257             elite_count_sum_chain_avg    2
# 322             first_sent_mean_chain_std    2
# 259             elite_count_std_chain_avg    2
# 201                   longitude_chain_avg    2
# 147                 rating_mean_chain_avg    2
# 293                   diffs_min_chain_std    2
# 166             photo_count_sum_chain_avg    2
# 220                    fans_std_chain_avg    2
# 169        review_count_usr_std_chain_avg    2
# 297                  gender_std_chain_std    2
# 176          senti_polarity_sum_chain_avg    2
# 180              last_sent_mean_chain_avg    2
# 302            friend_count_std_chain_std    2
# 222          average_stars_mean_chain_avg    2
# 183              first_sent_sum_chain_avg    2
# 189                 useful_amax_chain_avg    2
# 343                    latitude_chain_std    2
# 357                   zstar_all_chain_std    2
# 276           Convenience Level_chain_avg    2
# 425                Bike Parking_chain_std    2
# 415           Female Importance_chain_std    2
# 34                     senti_polarity_max    2
# 390         compliment_cool_std_chain_std    2
# 63                        median_of_stars    2
# 428              friends/review_chain_std    2
# 345                  rating_pub_chain_std    1
# 54                              cool_mean    1
# 199                   cool_amax_chain_avg    1
# 330                  useful_sum_chain_std    1
# 161            friend_count_sum_chain_avg    1
# 331                 useful_mean_chain_std    1
# 366           average_stars_std_chain_std    1
# 62                           std_of_stars    1
# 171        review_count_usr_sum_chain_avg    1
# 336                  funny_mean_chain_std    1
# 338                    cool_std_chain_std    1
# 412           Food Aestheticist_chain_std    1
# 164             photo_count_std_chain_avg    1
# 65                     reactions_per_week    1
# 177         senti_polarity_mean_chain_avg    1
# 53                               cool_sum    1
# 324              first_sent_std_chain_std    1
# 326              first_sent_sum_chain_std    1
# 304            friend_count_sum_chain_std    1
# 279             Outdoor Seating_chain_avg    1
# 266                High Network_chain_avg    1
# 12                             gender_sum    1
# 284            review_count_loc_chain_avg    1
# 289                  rating_sum_chain_std    1
# 290                 rating_mean_chain_std    1
# 299                  gender_sum_chain_std    1
# 309             photo_count_sum_chain_std    1
# 413                     Patrons_chain_std    1
# 223           average_stars_std_chain_avg    1
# 221           average_stars_sum_chain_avg    1
# 33                    senti_polarity_mean    1
# 219                   fans_mean_chain_avg    1
# 35                        first_sent_mean    1
# 45                            useful_amax    1
# 348               oldest_review_chain_std    1
# 347            reviews_per_week_chain_std    1
# 195                    cool_std_chain_avg    1
# 365          average_stars_mean_chain_std    1
# 156                  gender_sum_chain_avg    1
# 94                   compliment_list_mean    1
# 149                   diffs_std_chain_avg    1
# 373      compliment_profile_sum_chain_std    1
# 375      compliment_profile_std_chain_std    1
# 308             photo_count_min_chain_std    0
# 374     compliment_profile_mean_chain_std    0
# 300                 gender_mean_chain_std    0
# 419           Convenience Level_chain_std    0
# 301                  gender_max_chain_std    0
# 418         Number of Reviewers_chain_std    0
# 303            friend_count_min_chain_std    0
# 305           friend_count_mean_chain_std    0
# 306            friend_count_max_chain_std    0
# 307             photo_count_std_chain_std    0
# 349                std_of_stars_chain_std    0
# 420                  Free Wi-Fi_chain_std    0
# 363                    fans_std_chain_std    0
# 310            photo_count_mean_chain_std    0
# 311             photo_count_max_chain_std    0
# 312        review_count_usr_std_chain_std    0
# 313        review_count_usr_min_chain_std    0
# 314        review_count_usr_sum_chain_std    0
# 315       review_count_usr_mean_chain_std    0
# 316        review_count_usr_max_chain_std    0
# 317          senti_polarity_std_chain_std    0
# 376         compliment_cute_sum_chain_std    0
# 417               Total Network_chain_std    0
# 362                   fans_mean_chain_std    0
# 298                  gender_min_chain_std    0
# 294                   diffs_sum_chain_std    0
# 296                   diffs_max_chain_std    0
# 371        compliment_more_mean_chain_std    0
# 277                  Free Wi-Fi_chain_avg    0
# 278          Takes Reservations_chain_avg    0
# 368         compliment_hot_mean_chain_std    0
# 280                    Delivery_chain_avg    0
# 369          compliment_hot_std_chain_std    0
# 427            review_count_loc_chain_std    0
# 281                      Caters_chain_avg    0
# 370         compliment_more_sum_chain_std    0
# 426                       Noisy_chain_std    0
# 282                Bike Parking_chain_avg    0
# 283                       Noisy_chain_avg    0
# 364           average_stars_sum_chain_std    0
# 295                  diffs_mean_chain_std    0
# 424                      Caters_chain_std    0
# 285              friends/review_chain_avg    0
# 423                    Delivery_chain_std    0
# 422             Outdoor Seating_chain_std    0
# 287                  rating_std_chain_std    0
# 288                  rating_min_chain_std    0
# 372         compliment_more_std_chain_std    0
# 291                  rating_max_chain_std    0
# 292                   diffs_std_chain_std    0
# 421          Takes Reservations_chain_std    0
# 361                    fans_sum_chain_std    0
# 377        compliment_cute_mean_chain_std    0
# 378         compliment_cute_std_chain_std    0
# 318          senti_polarity_min_chain_std    0
# 350             median_of_stars_chain_std    0
# 389        compliment_cool_mean_chain_std    0
# 337                  funny_amax_chain_std    0
# 354  restaurant_similar_density_chain_std    0
# 391        compliment_funny_sum_chain_std    0
# 339                   cool_amin_chain_std    0
# 405                    days_std_chain_std    0
# 403                    days_sum_chain_std    0
# 340                    cool_sum_chain_std    0
# 402             elite_count_std_chain_std    0
# 392       compliment_funny_mean_chain_std    0
# 401            elite_count_mean_chain_std    0
# 400             elite_count_sum_chain_std    0
# 341                   cool_mean_chain_std    0
# 399       compliment_photos_std_chain_std    0
# 342                   cool_amax_chain_std    0
# 353          restaurant_density_chain_std    0
# 398      compliment_photos_mean_chain_std    0
# 397       compliment_photos_sum_chain_std    0
# 396       compliment_writer_std_chain_std    0
# 395      compliment_writer_mean_chain_std    0
# 394       compliment_writer_sum_chain_std    0
# 352          reactions_per_week_chain_std    0
# 351           stars_linear_coef_chain_std    0
# 346            count_categories_chain_std    0
# 393        compliment_funny_std_chain_std    0
# 388         compliment_cool_sum_chain_std    0
# 407                        Male_chain_std    0
# 335                   funny_sum_chain_std    0
# 381         compliment_list_std_chain_std    0
# 320         senti_polarity_mean_chain_std    0
# 321          senti_polarity_max_chain_std    0
# 379         compliment_list_sum_chain_std    0
# 360                   stars_std_chain_std    0
# 359                  stars_mean_chain_std    0
# 323              last_sent_mean_chain_std    0
# 358                   stars_sum_chain_std    0
# 414                 First Visit_chain_std    0
# 380        compliment_list_mean_chain_std    0
# 325               last_sent_std_chain_std    0
# 356        zreview_per_week_all_chain_std    0
# 411                 Connoisseur_chain_std    0
# 334                  funny_amin_chain_std    0
# 327               last_sent_sum_chain_std    0
# 410                 Low Network_chain_std    0
# 409                High Network_chain_std    0
# 382         compliment_note_sum_chain_std    0
# 383        compliment_note_mean_chain_std    0
# 329                 useful_amin_chain_std    0
# 385        compliment_plain_sum_chain_std    0
# 386       compliment_plain_mean_chain_std    0
# 387        compliment_plain_std_chain_std    0
# 332                 useful_amax_chain_std    0
# 408                      Female_chain_std    0
# 367          compliment_hot_sum_chain_std    0
# 215                   stars_sum_chain_avg    0
# 274               Total Network_chain_avg    0
# 100                 compliment_plain_mean    0
# 107                  compliment_funny_std    0
# 106                 compliment_funny_mean    0
# 105                  compliment_funny_sum    0
# 104                   compliment_cool_std    0
# 103                  compliment_cool_mean    0
# 102                   compliment_cool_sum    0
# 101                  compliment_plain_std    0
# 99                   compliment_plain_sum    0
# 88                compliment_profile_mean    0
# 98                    compliment_note_std    0
# 97                   compliment_note_mean    0
# 95                    compliment_list_std    0
# 93                    compliment_list_sum    0
# 92                    compliment_cute_std    0
# 91                   compliment_cute_mean    0
# 90                    compliment_cute_sum    0
# 108                 compliment_writer_sum    0
# 109                compliment_writer_mean    0
# 110                 compliment_writer_std    0
# 111                 compliment_photos_sum    0
# 140                                 Noisy    0
# 138                                Caters    0
# 137                              Delivery    0
# 136                       Outdoor Seating    0
# 135                    Takes Reservations    0
# 134                            Free Wi-Fi    0
# 131                         Total Network    0
# 129                     Female Importance    0
# 127                               Patrons    0
# 122                                Female    0
# 121                                  Male    0
# 116                       elite_count_std    0
# 114                       elite_count_sum    0
# 113                 compliment_photos_std    0
# 112                compliment_photos_mean    0
# 89                 compliment_profile_std    0
# 87                 compliment_profile_sum    0
# 273    Average Customer Network_chain_avg    0
# 20                        photo_count_std    0
# 47                             funny_amin    0
# 46                              funny_std    0
# 42                            useful_amin    0
# 24                        photo_count_max    0
# 23                       photo_count_mean    0
# 22                        photo_count_sum    0
# 21                        photo_count_min    0
# 19                       friend_count_max    0
# 86                    compliment_more_std    0
# 17                       friend_count_sum    0
# 16                       friend_count_min    0
# 15                       friend_count_std    0
# 14                             gender_max    0
# 11                             gender_min    0
# 4                              rating_max    0
# 3                             rating_mean    0
# 48                              funny_sum    0
# 49                             funny_mean    0
# 50                             funny_amax    0
# 52                              cool_amin    0
# 85                   compliment_more_mean    0
# 84                    compliment_more_sum    0
# 83                     compliment_hot_std    0
# 82                    compliment_hot_mean    0
# 81                     compliment_hot_sum    0
# 77                               fans_std    0
# 76                              fans_mean    0
# 75                               fans_sum    0
# 74                              stars_std    0
# 73                             stars_mean    0
# 72                              stars_sum    0
# 71                               is_chain    0
# 59                       count_categories    0
# 58                             rating_pub    0
# 55                              cool_amax    0
# 148                  rating_max_chain_avg    0
# 153                   diffs_max_chain_avg    0
# 154                  gender_std_chain_avg    0
# 237        compliment_list_mean_chain_avg    0
# 245         compliment_cool_sum_chain_avg    0
# 244        compliment_plain_std_chain_avg    0
# 243       compliment_plain_mean_chain_avg    0
# 242        compliment_plain_sum_chain_avg    0
# 240        compliment_note_mean_chain_avg    0
# 239         compliment_note_sum_chain_avg    0
# 238         compliment_list_std_chain_avg    0
# 236         compliment_list_sum_chain_avg    0
# 155                  gender_min_chain_avg    0
# 235         compliment_cute_std_chain_avg    0
# 234        compliment_cute_mean_chain_avg    0
# 233         compliment_cute_sum_chain_avg    0
# 232      compliment_profile_std_chain_avg    0
# 231     compliment_profile_mean_chain_avg    0
# 230      compliment_profile_sum_chain_avg    0
# 229         compliment_more_std_chain_avg    0
# 246        compliment_cool_mean_chain_avg    0
# 247         compliment_cool_std_chain_avg    0
# 248        compliment_funny_sum_chain_avg    0
# 249       compliment_funny_mean_chain_avg    0
# 272           Female Importance_chain_avg    0
# 271                 First Visit_chain_avg    0
# 270                     Patrons_chain_avg    0
# 267                 Low Network_chain_avg    0
# 264                        Male_chain_avg    0
# 263              Male to Female_chain_avg    0
# 260                    days_sum_chain_avg    0
# 258            elite_count_mean_chain_avg    0
# 256       compliment_photos_std_chain_avg    0
# 255      compliment_photos_mean_chain_avg    0
# 254       compliment_photos_sum_chain_avg    0
# 253       compliment_writer_std_chain_avg    0
# 252      compliment_writer_mean_chain_avg    0
# 251       compliment_writer_sum_chain_avg    0
# 250        compliment_funny_std_chain_avg    0
# 228        compliment_more_mean_chain_avg    0
# 227         compliment_more_sum_chain_avg    0
# 226          compliment_hot_std_chain_avg    0
# 191                  funny_amin_chain_avg    0
# 187                  useful_sum_chain_avg    0
# 186                 useful_amin_chain_avg    0
# 185                  useful_std_chain_avg    0
# 182               last_sent_std_chain_avg    0
# 179             first_sent_mean_chain_avg    0
# 174          senti_polarity_std_chain_avg    0
# 172       review_count_usr_mean_chain_avg    0
# 168             photo_count_max_chain_avg    0
# 167            photo_count_mean_chain_avg    0
# 165             photo_count_min_chain_avg    0
# 163            friend_count_max_chain_avg    0
# 160            friend_count_min_chain_avg    0
# 159            friend_count_std_chain_avg    0
# 158                  gender_max_chain_avg    0
# 157                 gender_mean_chain_avg    0
# 190                   funny_std_chain_avg    0
# 192                   funny_sum_chain_avg    0
# 225         compliment_hot_mean_chain_avg    0
# 193                  funny_mean_chain_avg    0
# 224          compliment_hot_sum_chain_avg    0
# 218                    fans_sum_chain_avg    0
# 217                   stars_std_chain_avg    0
# 216                  stars_mean_chain_avg    0
# 1                              rating_min    0
# 214                   zstar_all_chain_avg    0
# 211  restaurant_similar_density_chain_avg    0
# 210          restaurant_density_chain_avg    0
# 207             median_of_stars_chain_avg    0
# 206                std_of_stars_chain_avg    0
# 203            count_categories_chain_avg    0
# 202                  rating_pub_chain_avg    0
# 198                   cool_mean_chain_avg    0
# 197                    cool_sum_chain_avg    0
# 196                   cool_amin_chain_avg    0
# 429         first_min_last_sent_chain_std    0

# %%
shap_values = shap.TreeExplainer(model).shap_values(X)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-368-f151fdb9deb3> in <module>()
# ----> 1 shap_values = shap.TreeExplainer(model).shap_values(X)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/shap/explainers/tree.py in __init__(self, model, **kwargs)
#      38             self.trees = model
#      39         else:
# ---> 40             raise Exception("Model type not yet supported by TreeExplainer: " + str(type(model)))
#      41
#      42     def shap_values(self, X, **kwargs):
#
# Exception: Model type not yet supported by TreeExplainer: <class 'catboost.core.CatBoostClassifier'>

# %%
import shap

# load JS visualization code to notebook
shap.initjs() 
# visualize the first prediction's explaination
shap.force_plot(shap_values[1,:], X.iloc[1,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(9),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),y={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=y},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(18);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(185);n.d(e,"descending",function(){return a.a});var u=n(103);n.d(e,"deviation",function(){return u.a});var c=n(104);n.d(e,"extent",function(){return c.a});var s=n(186);n.d(e,"histogram",function(){return s.a});var l=n(197);n.d(e,"thresholdFreedmanDiaconis",function(){return l.a});var f=n(198);n.d(e,"thresholdScott",function(){return f.a});var p=n(107);n.d(e,"thresholdSturges",function(){return p.a});var h=n(188);n.d(e,"max",function(){return h.a});var d=n(189);n.d(e,"mean",function(){return d.a});var v=n(190);n.d(e,"median",function(){return v.a});var g=n(191);n.d(e,"merge",function(){return g.a});var y=n(105);n.d(e,"min",function(){return y.a});var m=n(192);n.d(e,"pairs",function(){return m.a});var _=n(193);n.d(e,"permute",function(){return ...
# <div id='i3MWO9V1BTMJT12PLY1LY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security.
# </div></div>
#  <script>
#    if (window.IML) IML.ReactDom.render(
#     IML.React.createElement(IML.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 3.3608240260699747, "outValue": 0.08314579492403196, "link": "identity", "featureNames": ["rating_std", "rating_min", "rating_sum", "rating_mean", "rating_max", "gender_std", "gender_min", "gender_sum", "gender_mean", "gender_max", "friend_count_std", "friend_count_min", "friend_count_sum", "friend_count_mean", "friend_count_max", "photo_count_std", "photo_count_min", "photo_count_sum", "photo_count_mean", "photo_count_max", "review_count_usr_std", "review_count_usr_min", "review_count_usr_sum", "review_count_usr_mean", "review_count_usr_max", "senti_polarity_std", "senti_polarity_min", "senti_polarity_sum", "senti_polarity_mean", "senti_polarity_max", "first_sent_mean", "last_sent_mean", "first_sent_std", "last_sent_std", "first_sent_sum", "last_sent_sum", "useful_std", "useful_amin", "useful_sum", "useful_mean", "useful_amax", "funny_std", "funny_amin", "funny_sum", "funny_mean", "funny_amax", "cool_std", "cool_amin", "cool_sum", "cool_mean", "cool_amax", "latitude", "longitude", "rating_pub", "count_categories", "reviews_per_week", "oldest_review", "std_of_stars", "median_of_stars", "stars_linear_coef", "reactions_per_week", "restaurant_density", "restaurant_similar_density", "zreview_count_all", "zreview_per_week_all", "zstar_all", "is_chain", "stars_sum", "stars_mean", "stars_std", "fans_sum", "fans_mean", "fans_std", "average_stars_sum", "average_stars_mean", "average_stars_std", "compliment_hot_sum", "compliment_hot_mean", "compliment_hot_std", "compliment_more_sum", "compliment_more_mean", "compliment_more_std", "compliment_profile_sum", "compliment_profile_mean", "compliment_profile_std", "compliment_cute_sum", "compliment_cute_mean", "compliment_cute_std", "compliment_list_sum", "compliment_list_mean", "compliment_list_std", "compliment_note_sum", "compliment_note_mean", "compliment_note_std", "compliment_plain_sum", "compliment_plain_mean", "compliment_plain_std", "compliment_cool_sum", "compliment_cool_mean", "compliment_cool_std", "compliment_funny_sum", "compliment_funny_mean", "compliment_funny_std", "compliment_writer_sum", "compliment_writer_mean", "compliment_writer_std", "compliment_photos_sum", "compliment_photos_mean", "compliment_photos_std", "elite_count_sum", "elite_count_mean", "elite_count_std", "Male to Female", "Male", "Female", "High Network", "Low Network", "Connoisseur", "Food Aestheticist", "Patrons", "First Visit", "Female Importance", "Average Customer Network", "Total Network", "Number of Reviewers", "Convenience Level", "Free Wi-Fi", "Takes Reservations", "Outdoor Seating", "Delivery", "Caters", "Bike Parking", "Noisy", "review_count_loc", "friends/review", "first_min_last_sent", "rating_std_chain_avg", "rating_min_chain_avg", "rating_sum_chain_avg", "rating_mean_chain_avg", "rating_max_chain_avg", "gender_std_chain_avg", "gender_min_chain_avg", "gender_sum_chain_avg", "gender_mean_chain_avg", "gender_max_chain_avg", "friend_count_std_chain_avg", "friend_count_min_chain_avg", "friend_count_sum_chain_avg", "friend_count_mean_chain_avg", "friend_count_max_chain_avg", "photo_count_std_chain_avg", "photo_count_min_chain_avg", "photo_count_sum_chain_avg", "photo_count_mean_chain_avg", "photo_count_max_chain_avg", "review_count_usr_std_chain_avg", "review_count_usr_min_chain_avg", "review_count_usr_sum_chain_avg", "review_count_usr_mean_chain_avg", "review_count_usr_max_chain_avg", "senti_polarity_std_chain_avg", "senti_polarity_min_chain_avg", "senti_polarity_sum_chain_avg", "senti_polarity_mean_chain_avg", "senti_polarity_max_chain_avg", "first_sent_mean_chain_avg", "last_sent_mean_chain_avg", "first_sent_std_chain_avg", "last_sent_std_chain_avg", "first_sent_sum_chain_avg", "last_sent_sum_chain_avg", "useful_std_chain_avg", "useful_amin_chain_avg", "useful_sum_chain_avg", "useful_mean_chain_avg", "useful_amax_chain_avg", "funny_std_chain_avg", "funny_amin_chain_avg", "funny_sum_chain_avg", "funn ...

# %%
ga.sort_values("imp",ascending=False)
# Out:
#                                      name  imp
# 118                             days_mean  220
# 119                              days_std  133
# 7                               diffs_sum   87
# 8                              diffs_mean   62
# 125                           Connoisseur   53
# 261                   days_mean_chain_avg   47
# 44                            useful_mean   47
# 64                      stars_linear_coef   41
# 9                               diffs_max   31
# 262                    days_std_chain_avg   29
# 151                   diffs_sum_chain_avg   24
# 5                               diffs_std   23
# 126                     Food Aestheticist   22
# 26                   review_count_usr_min   20
# 32                     senti_polarity_sum   20
# 68                      zreview_count_all   19
# 0                              rating_std   19
# 61                          oldest_review   18
# 268                 Connoisseur_chain_avg   16
# 66                     restaurant_density   16
# 143                   first_min_last_sent   15
# 208           stars_linear_coef_chain_avg   15
# 56                               latitude   14
# 39                         first_sent_sum   14
# 269           Food Aestheticist_chain_avg   13
# 79                     average_stars_mean   12
# 38                          last_sent_std   12
# 70                              zstar_all   12
# 355           zreview_count_all_chain_std   11
# 43                             useful_sum   11
# 92                    compliment_cute_std   10
# 170        review_count_usr_min_chain_avg   10
# 78                      average_stars_sum   10
# 69                   zreview_per_week_all   10
# 2                              rating_sum   10
# 35                        first_sent_mean   10
# 293                   diffs_min_chain_std   10
# 28                  review_count_usr_mean    9
# 152                  diffs_mean_chain_avg    9
# 286         first_min_last_sent_chain_avg    9
# 29                   review_count_usr_max    9
# 133                     Convenience Level    8
# 188                 useful_mean_chain_avg    8
# 117                              days_sum    8
# 33                    senti_polarity_mean    7
# 124                           Low Network    7
# 103                  compliment_cool_mean    6
# 206                std_of_stars_chain_avg    6
# 199                   cool_amax_chain_avg    6
# 200                    latitude_chain_avg    6
# 201                   longitude_chain_avg    6
# 176          senti_polarity_sum_chain_avg    6
# 406              Male to Female_chain_std    6
# 212           zreview_count_all_chain_avg    6
# 57                              longitude    6
# 175          senti_polarity_min_chain_avg    6
# 425                Bike Parking_chain_std    6
# 173        review_count_usr_max_chain_avg    6
# 6                               diffs_min    6
# 37                         first_sent_std    6
# 333                   funny_std_chain_std    5
# 205               oldest_review_chain_avg    5
# 30                     senti_polarity_std    4
# 145                  rating_min_chain_avg    4
# 241         compliment_note_std_chain_avg    4
# 214                   zstar_all_chain_avg    4
# 213        zreview_per_week_all_chain_avg    4
# 149                   diffs_std_chain_avg    4
# 128                           First Visit    4
# 178          senti_polarity_max_chain_avg    4
# 338                    cool_std_chain_std    4
# 123                          High Network    4
# 169        review_count_usr_std_chain_avg    4
# 189                 useful_amax_chain_avg    4
# 60                       reviews_per_week    4
# 257             elite_count_sum_chain_avg    4
# 95                    compliment_list_std    3
# 259             elite_count_std_chain_avg    3
# 121                                  Male    3
# 181              first_sent_std_chain_avg    3
# 144                  rating_std_chain_avg    3
# 404                   days_mean_chain_std    3
# 55                              cool_amax    3
# 80                      average_stars_std    3
# 27                   review_count_usr_sum    3
# 365          average_stars_mean_chain_std    3
# 260                    days_sum_chain_avg    2
# 41                             useful_std    2
# 162           friend_count_mean_chain_avg    2
# 62                           std_of_stars    2
# 24                        photo_count_max    2
# 163            friend_count_max_chain_avg    2
# 184               last_sent_sum_chain_avg    2
# 271                 First Visit_chain_avg    2
# 309             photo_count_sum_chain_std    2
# 275         Number of Reviewers_chain_avg    2
# 340                    cool_sum_chain_std    2
# 171        review_count_usr_sum_chain_avg    2
# 63                        median_of_stars    2
# 159            friend_count_std_chain_avg    2
# 65                     reactions_per_week    2
# 267                 Low Network_chain_avg    2
# 12                             gender_sum    2
# 139                          Bike Parking    2
# 221           average_stars_sum_chain_avg    2
# 337                  funny_amax_chain_std    2
# 67             restaurant_similar_density    2
# 219                   fans_mean_chain_avg    2
# 34                     senti_polarity_max    2
# 25                   review_count_usr_std    2
# 153                   diffs_max_chain_avg    2
# 302            friend_count_std_chain_std    2
# 150                   diffs_min_chain_avg    1
# 416    Average Customer Network_chain_std    1
# 336                  funny_mean_chain_std    1
# 325               last_sent_std_chain_std    1
# 320         senti_polarity_mean_chain_std    1
# 157                 gender_mean_chain_avg    1
# 314        review_count_usr_sum_chain_std    1
# 312        review_count_usr_std_chain_std    1
# 180              last_sent_mean_chain_avg    1
# 415           Female Importance_chain_std    1
# 297                  gender_std_chain_std    1
# 390         compliment_cool_std_chain_std    1
# 220                    fans_std_chain_avg    1
# 265                      Female_chain_avg    1
# 266                High Network_chain_avg    1
# 384         compliment_note_std_chain_std    1
# 209          reactions_per_week_chain_avg    1
# 357                   zstar_all_chain_std    1
# 207             median_of_stars_chain_avg    1
# 356        zreview_per_week_all_chain_std    1
# 348               oldest_review_chain_std    1
# 198                   cool_mean_chain_avg    1
# 197                    cool_sum_chain_avg    1
# 193                  funny_mean_chain_avg    1
# 345                  rating_pub_chain_std    1
# 183              first_sent_sum_chain_avg    1
# 284            review_count_loc_chain_avg    1
# 294                   diffs_sum_chain_std    1
# 247         compliment_cool_std_chain_avg    1
# 429         first_min_last_sent_chain_std    1
# 31                     senti_polarity_min    1
# 49                             funny_mean    1
# 36                         last_sent_mean    1
# 94                   compliment_list_mean    1
# 22                        photo_count_sum    1
# 15                       friend_count_std    1
# 142                        friends/review    0
# 40                          last_sent_sum    0
# 23                       photo_count_mean    0
# 335                   funny_sum_chain_std    0
# 334                  funny_amin_chain_std    0
# 332                 useful_amax_chain_std    0
# 331                 useful_mean_chain_std    0
# 330                  useful_sum_chain_std    0
# 329                 useful_amin_chain_std    0
# 328                  useful_std_chain_std    0
# 327               last_sent_sum_chain_std    0
# 326              first_sent_sum_chain_std    0
# 339                   cool_amin_chain_std    0
# 342                   cool_amax_chain_std    0
# 341                   cool_mean_chain_std    0
# 350             median_of_stars_chain_std    0
# 18                      friend_count_mean    0
# 19                       friend_count_max    0
# 354  restaurant_similar_density_chain_std    0
# 353          restaurant_density_chain_std    0
# 352          reactions_per_week_chain_std    0
# 351           stars_linear_coef_chain_std    0
# 349                std_of_stars_chain_std    0
# 324              first_sent_std_chain_std    0
# 20                        photo_count_std    0
# 347            reviews_per_week_chain_std    0
# 346            count_categories_chain_std    0
# 21                        photo_count_min    0
# 344                   longitude_chain_std    0
# 343                    latitude_chain_std    0
# 42                            useful_amin    0
# 323              last_sent_mean_chain_std    0
# 358                   stars_sum_chain_std    0
# 296                   diffs_max_chain_std    0
# 303            friend_count_min_chain_std    0
# 301                  gender_max_chain_std    0
# 300                 gender_mean_chain_std    0
# 299                  gender_sum_chain_std    0
# 298                  gender_min_chain_std    0
# 50                             funny_amax    0
# 295                  diffs_mean_chain_std    0
# 305           friend_count_mean_chain_std    0
# 51                               cool_std    0
# 52                              cool_amin    0
# 292                   diffs_std_chain_std    0
# 291                  rating_max_chain_std    0
# 290                 rating_mean_chain_std    0
# 289                  rating_sum_chain_std    0
# 304            friend_count_sum_chain_std    0
# 306            friend_count_max_chain_std    0
# 322             first_sent_mean_chain_std    0
# 315       review_count_usr_mean_chain_std    0
# 321          senti_polarity_max_chain_std    0
# 45                            useful_amax    0
# 319          senti_polarity_sum_chain_std    0
# 318          senti_polarity_min_chain_std    0
# 317          senti_polarity_std_chain_std    0
# 316        review_count_usr_max_chain_std    0
# 46                              funny_std    0
# 307             photo_count_std_chain_std    0
# 313        review_count_usr_min_chain_std    0
# 47                             funny_amin    0
# 311             photo_count_max_chain_std    0
# 310            photo_count_mean_chain_std    0
# 48                              funny_sum    0
# 308             photo_count_min_chain_std    0
# 17                       friend_count_sum    0
# 359                  stars_mean_chain_std    0
# 287                  rating_std_chain_std    0
# 13                            gender_mean    0
# 410                 Low Network_chain_std    0
# 409                High Network_chain_std    0
# 408                      Female_chain_std    0
# 407                        Male_chain_std    0
# 11                             gender_min    0
# 405                    days_std_chain_std    0
# 403                    days_sum_chain_std    0
# 412           Food Aestheticist_chain_std    0
# 402             elite_count_std_chain_std    0
# 401            elite_count_mean_chain_std    0
# 400             elite_count_sum_chain_std    0
# 399       compliment_photos_std_chain_std    0
# 398      compliment_photos_mean_chain_std    0
# 397       compliment_photos_sum_chain_std    0
# 411                 Connoisseur_chain_std    0
# 413                     Patrons_chain_std    0
# 360                   stars_std_chain_std    0
# 422             Outdoor Seating_chain_std    0
# 428              friends/review_chain_std    0
# 427            review_count_loc_chain_std    0
# 426                       Noisy_chain_std    0
# 3                             rating_mean    0
# 424                      Caters_chain_std    0
# 423                    Delivery_chain_std    0
# 421          Takes Reservations_chain_std    0
# 414                 First Visit_chain_std    0
# 420                  Free Wi-Fi_chain_std    0
# 419           Convenience Level_chain_std    0
# 418         Number of Reviewers_chain_std    0
# 417               Total Network_chain_std    0
# 4                              rating_max    0
# 10                             gender_std    0
# 396       compliment_writer_std_chain_std    0
# 395      compliment_writer_mean_chain_std    0
# 394       compliment_writer_sum_chain_std    0
# 368         compliment_hot_mean_chain_std    0
# 374     compliment_profile_mean_chain_std    0
# 373      compliment_profile_sum_chain_std    0
# 372         compliment_more_std_chain_std    0
# 371        compliment_more_mean_chain_std    0
# 370         compliment_more_sum_chain_std    0
# 369          compliment_hot_std_chain_std    0
# 367          compliment_hot_sum_chain_std    0
# 393        compliment_funny_std_chain_std    0
# 366           average_stars_std_chain_std    0
# 16                       friend_count_min    0
# 364           average_stars_sum_chain_std    0
# 363                    fans_std_chain_std    0
# 362                   fans_mean_chain_std    0
# 361                    fans_sum_chain_std    0
# 375      compliment_profile_std_chain_std    0
# 376         compliment_cute_sum_chain_std    0
# 377        compliment_cute_mean_chain_std    0
# 378         compliment_cute_std_chain_std    0
# 379         compliment_list_sum_chain_std    0
# 380        compliment_list_mean_chain_std    0
# 381         compliment_list_std_chain_std    0
# 382         compliment_note_sum_chain_std    0
# 383        compliment_note_mean_chain_std    0
# 385        compliment_plain_sum_chain_std    0
# 386       compliment_plain_mean_chain_std    0
# 387        compliment_plain_std_chain_std    0
# 388         compliment_cool_sum_chain_std    0
# 389        compliment_cool_mean_chain_std    0
# 14                             gender_max    0
# 391        compliment_funny_sum_chain_std    0
# 392       compliment_funny_mean_chain_std    0
# 288                  rating_min_chain_std    0
# 53                               cool_sum    0
# 141                      review_count_loc    0
# 187                  useful_sum_chain_avg    0
# 105                  compliment_funny_sum    0
# 192                   funny_sum_chain_avg    0
# 191                  funny_amin_chain_avg    0
# 190                   funny_std_chain_avg    0
# 106                 compliment_funny_mean    0
# 107                  compliment_funny_std    0
# 186                 useful_amin_chain_avg    0
# 195                    cool_std_chain_avg    0
# 185                  useful_std_chain_avg    0
# 108                 compliment_writer_sum    0
# 109                compliment_writer_mean    0
# 182               last_sent_std_chain_avg    0
# 110                 compliment_writer_std    0
# 111                 compliment_photos_sum    0
# 194                  funny_amax_chain_avg    0
# 196                   cool_amin_chain_avg    0
# 112                compliment_photos_mean    0
# 98                    compliment_note_std    0
# 91                   compliment_cute_mean    0
# 211  restaurant_similar_density_chain_avg    0
# 210          restaurant_density_chain_avg    0
# 93                    compliment_list_sum    0
# 96                    compliment_note_sum    0
# 97                   compliment_note_mean    0
# 204            reviews_per_week_chain_avg    0
# 104                   compliment_cool_std    0
# 203            count_categories_chain_avg    0
# 202                  rating_pub_chain_avg    0
# 99                   compliment_plain_sum    0
# 100                 compliment_plain_mean    0
# 101                  compliment_plain_std    0
# 102                   compliment_cool_sum    0
# 179             first_sent_mean_chain_avg    0
# 177         senti_polarity_mean_chain_avg    0
# 89                 compliment_profile_std    0
# 135                    Takes Reservations    0
# 131                         Total Network    0
# 156                  gender_sum_chain_avg    0
# 155                  gender_min_chain_avg    0
# 154                  gender_std_chain_avg    0
# 132                   Number of Reviewers    0
# 134                            Free Wi-Fi    0
# 136                       Outdoor Seating    0
# 130              Average Customer Network    0
# 137                              Delivery    0
# 148                  rating_max_chain_avg    0
# 147                 rating_mean_chain_avg    0
# 146                  rating_sum_chain_avg    0
# 138                                Caters    0
# 140                                 Noisy    0
# 158                  gender_max_chain_avg    0
# 160            friend_count_min_chain_avg    0
# 113                 compliment_photos_std    0
# 122                                Female    0
# 114                       elite_count_sum    0
# 174          senti_polarity_std_chain_avg    0
# 115                      elite_count_mean    0
# 172       review_count_usr_mean_chain_avg    0
# 116                       elite_count_std    0
# 120                        Male to Female    0
# 168             photo_count_max_chain_avg    0
# 161            friend_count_sum_chain_avg    0
# 167            photo_count_mean_chain_avg    0
# 166             photo_count_sum_chain_avg    0
# 165             photo_count_min_chain_avg    0
# 164             photo_count_std_chain_avg    0
# 127                               Patrons    0
# 129                     Female Importance    0
# 90                    compliment_cute_sum    0
# 1                              rating_min    0
# 285              friends/review_chain_avg    0
# 81                     compliment_hot_sum    0
# 74                              stars_std    0
# 75                               fans_sum    0
# 264                        Male_chain_avg    0
# 263              Male to Female_chain_avg    0
# 76                              fans_mean    0
# 77                               fans_std    0
# 82                    compliment_hot_mean    0
# 72                              stars_sum    0
# 258            elite_count_mean_chain_avg    0
# 83                     compliment_hot_std    0
# 256       compliment_photos_std_chain_avg    0
# 255      compliment_photos_mean_chain_avg    0
# 254       compliment_photos_sum_chain_avg    0
# 253       compliment_writer_std_chain_avg    0
# 73                             stars_mean    0
# 71                               is_chain    0
# 251       compliment_writer_sum_chain_avg    0
# 278          Takes Reservations_chain_avg    0
# 54                              cool_mean    0
# 283                       Noisy_chain_avg    0
# 282                Bike Parking_chain_avg    0
# 281                      Caters_chain_avg    0
# 280                    Delivery_chain_avg    0
# 279             Outdoor Seating_chain_avg    0
# 277                  Free Wi-Fi_chain_avg    0
# 270                     Patrons_chain_avg    0
# 276           Convenience Level_chain_avg    0
# 58                             rating_pub    0
# 274               Total Network_chain_avg    0
# 273    Average Customer Network_chain_avg    0
# 272           Female Importance_chain_avg    0
# 59                       count_categories    0
# 252      compliment_writer_mean_chain_avg    0
# 250        compliment_funny_std_chain_avg    0
# 216                  stars_mean_chain_avg    0
# 224          compliment_hot_sum_chain_avg    0
# 230      compliment_profile_sum_chain_avg    0
# 229         compliment_more_std_chain_avg    0
# 228        compliment_more_mean_chain_avg    0
# 227         compliment_more_sum_chain_avg    0
# 226          compliment_hot_std_chain_avg    0
# 225         compliment_hot_mean_chain_avg    0
# 223           average_stars_std_chain_avg    0
# 232      compliment_profile_std_chain_avg    0
# 222          average_stars_mean_chain_avg    0
# 86                    compliment_more_std    0
# 87                 compliment_profile_sum    0
# 88                compliment_profile_mean    0
# 218                    fans_sum_chain_avg    0
# 217                   stars_std_chain_avg    0
# 231     compliment_profile_mean_chain_avg    0
# 233         compliment_cute_sum_chain_avg    0
# 249       compliment_funny_mean_chain_avg    0
# 242        compliment_plain_sum_chain_avg    0
# 248        compliment_funny_sum_chain_avg    0
# 84                    compliment_more_sum    0
# 246        compliment_cool_mean_chain_avg    0
# 245         compliment_cool_sum_chain_avg    0
# 244        compliment_plain_std_chain_avg    0
# 243       compliment_plain_mean_chain_avg    0
# 85                   compliment_more_mean    0
# 234        compliment_cute_mean_chain_avg    0
# 240        compliment_note_mean_chain_avg    0
# 239         compliment_note_sum_chain_avg    0
# 238         compliment_list_std_chain_avg    0
# 237        compliment_list_mean_chain_avg    0
# 236         compliment_list_sum_chain_avg    0
# 235         compliment_cute_std_chain_avg    0
# 215                   stars_sum_chain_avg    0

# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from sklearn.metrics import confusion_matrix,precision_recall_curve,auc,roc_auc_score,roc_curve,recall_score,classification_report,accuracy_score

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33)

# This is what I expect a human to get 
Y.sum()/(Y.count())

from lightgbm import LGBMClassifier
lgbm = LGBMClassifier(boosting_type='gbdt', objective='binary',
                       num_class=1,early_stopping = 50,
                       is_enable_sparse='true',tree_learner='data',num_leaves=31,num_iteration=10000,min_data_in_leaf=100,max_depth=14,
                       learning_rate=0.1, n_estimators=1000, max_bin=255, subsample_for_bin=500, 
                       min_split_gain=5, min_child_weight=5, min_child_samples=5, subsample=0.995, 
                       subsample_freq=1, colsample_bytree=1, reg_alpha=0, 
                       reg_lambda=0, seed=0, nthread=-1, silent=True,)

lgbm.fit(X_train, y_train, eval_set=[(X_train, y_train)],eval_metric='AUC',
        early_stopping_rounds=5)

y_pred = lgbm.predict(X_test)
y_pred_proba = lgbm.predict_proba(X_test)
accuracy_score(y_test, y_pred)



import matplotlib.pyplot as plt
import scikitplot as skplt

skplt.metrics.plot_roc_curve(y_test, y_pred_proba)
plt.show()

ga = pd.DataFrame()

ga["name"] = X.columns

ga["imp"] = lgbm.feature_importances_
print(accuracy_score(y_test, y_pred))
pd.set_option("display.max_rows",None)
# Out:
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/lightgbm/engine.py:99: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/lightgbm/engine.py:104: UserWarning: Found `early_stopping` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	training's auc: 0.888298
# Training until validation scores don't improve for 50 rounds.
# [2]	training's auc: 0.898451
# [3]	training's auc: 0.907781
# [4]	training's auc: 0.912264
# [5]	training's auc: 0.91412
# [6]	training's auc: 0.91515
# [7]	training's auc: 0.917894
# [8]	training's auc: 0.919701
# [9]	training's auc: 0.920493
# [10]	training's auc: 0.922876
# [11]	training's auc: 0.923903
# [12]	training's auc: 0.925697
# [13]	training's auc: 0.926121
# [14]	training's auc: 0.927413
# [15]	training's auc: 0.928462
# [16]	training's auc: 0.929499
# [17]	training's auc: 0.930444
# [18]	training's auc: 0.93134
# [19]	training's auc: 0.931998
# [20]	training's auc: 0.932615
# [21]	training's auc: 0.933894
# [22]	training's auc: 0.934693
# [23]	training's auc: 0.935925
# [24]	training's auc: 0.936601
# [25]	training's auc: 0.93736
# [26]	training's auc: 0.93857
# [27]	training's auc: 0.93935
# [28]	training's auc: 0.940207
# [29]	training's auc: 0.940998
# [30]	training's auc: 0.94152
# [31]	training's auc: 0.942378
# [32]	training's auc: 0.943394
# [33]	training's auc: 0.94393
# [34]	training's auc: 0.944616
# [35]	training's auc: 0.945284
# [36]	training's auc: 0.945933
# [37]	training's auc: 0.946676
# [38]	training's auc: 0.947289
# [39]	training's auc: 0.947832
# [40]	training's auc: 0.94836
# [41]	training's auc: 0.948871
# [42]	training's auc: 0.949503
# [43]	training's auc: 0.95003
# [44]	training's auc: 0.950469
# [45]	training's auc: 0.951076
# [46]	training's auc: 0.951671
# [47]	training's auc: 0.952103
# [48]	training's auc: 0.952573
# [49]	training's auc: 0.952922
# [50]	training's auc: 0.953464
# [51]	training's auc: 0.953647
# [52]	training's auc: 0.953896
# [53]	training's auc: 0.95423
# [54]	training's auc: 0.954454
# [55]	training's auc: 0.954598
# [56]	training's auc: 0.954854
# [57]	training's auc: 0.955112
# [58]	training's auc: 0.955285
# [59]	training's auc: 0.955584
# [60]	training's auc: 0.95587
# [61]	training's auc: 0.955947
# [62]	training's auc: 0.956197
# [63]	training's auc: 0.956331
# [64]	training's auc: 0.956426
# [65]	training's auc: 0.956553
# [66]	training's auc: 0.956732
# [67]	training's auc: 0.956942
# [68]	training's auc: 0.957021
# [69]	training's auc: 0.957069
# [70]	training's auc: 0.957078
# [71]	training's auc: 0.957115
# [72]	training's auc: 0.957101
# [73]	training's auc: 0.957109
# [74]	training's auc: 0.957142
# [75]	training's auc: 0.957164
# [76]	training's auc: 0.957198
# [77]	training's auc: 0.957216
# [78]	training's auc: 0.957223
# [79]	training's auc: 0.95723
# [80]	training's auc: 0.95726
# [81]	training's auc: 0.957266
# [82]	training's auc: 0.957266
# [83]	training's auc: 0.957266
# [84]	training's auc: 0.957266
# [85]	training's auc: 0.957266
# [86]	training's auc: 0.957266
# [87]	training's auc: 0.957266
# [88]	training's auc: 0.957266
# [89]	training's auc: 0.957266
# [90]	training's auc: 0.957266
# [91]	training's auc: 0.957266
# [92]	training's auc: 0.957266
# [93]	training's auc: 0.957266
# [94]	training's auc: 0.957266
# [95]	training's auc: 0.957266
# [96]	training's auc: 0.957266
# [97]	training's auc: 0.957266
# [98]	training's auc: 0.957266
# [99]	training's auc: 0.957266
# [100]	training's auc: 0.957266
# [101]	training's auc: 0.957266
# [102]	training's auc: 0.957266
# [103]	training's auc: 0.957266
# [104]	training's auc: 0.957266
# [105]	training's auc: 0.957266
# [106]	training's auc: 0.957266
# [107]	training's auc: 0.957266
# [108]	training's auc: 0.957266
# [109]	training's auc: 0.957266
# [110]	training's auc: 0.957266
# [111]	training's auc: 0.957266
# [112]	training's auc: 0.957266
# [113]	training's auc: 0.957266
# [114]	training's auc: 0.957266
# [115]	training's auc: 0.957266
# [116]	training's auc: 0.957266
# [117]	training's auc: 0.957266
# [118]	training's auc: 0.957266
# [119]	training's auc: 0.957266
# [120]	training's auc: 0.957266
# [121]	training's auc: 0.957266
# [122]	training's auc: 0.957266
# [123]	training's auc: 0.957266
# [124]	training's auc: 0.957266
# [125]	training's auc: 0.957266
# [126]	training's auc: 0.957266
# [127]	training's auc: 0.957266
# [128]	training's auc: 0.957266
# [129]	training's auc: 0.957266
# [130]	training's auc: 0.957266
# [131]	training's auc: 0.957266
# Early stopping, best iteration is:
# [81]	training's auc: 0.957266
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: The spectral and spectral_r colormap was deprecated in version 2.0. Use nipy_spectral and nipy_spectral_r instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# 0.9052926606700561

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8236866119150046

# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from sklearn.metrics import confusion_matrix,precision_recall_curve,auc,roc_auc_score,roc_curve,recall_score,classification_report,accuracy_score

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33)

# This is what I expect a human to get 
Y.sum()/(Y.count())

from lightgbm import LGBMClassifier
lgbm = LGBMClassifier(boosting_type='gbdt', objective='binary',
                       num_class=1,early_stopping = 50,
                       is_enable_sparse='true',tree_learner='data',num_leaves=31,num_iteration=10000,min_data_in_leaf=100,max_depth=14,
                       learning_rate=0.1, n_estimators=1000, max_bin=255, subsample_for_bin=500, 
                       min_split_gain=5, min_child_weight=5, min_child_samples=5, subsample=0.995, 
                       subsample_freq=1, colsample_bytree=1, reg_alpha=0, 
                       reg_lambda=0, seed=0, nthread=-1, silent=True,)

lgbm.fit(X_train, y_train, eval_set=[(X_train, y_train)],eval_metric='AUC',
        early_stopping_rounds=5)

y_pred = lgbm.predict(X_test)
y_pred_proba = lgbm.predict_proba(X_test)
accuracy_score(y_test, y_pred)



import matplotlib.pyplot as plt
import scikitplot as skplt

skplt.metrics.plot_roc_curve(y_test, y_pred_proba)
plt.show()

ga = pd.DataFrame()

ga["name"] = X.columns

ga["imp"] = lgbm.feature_importances_

pd.set_option("display.max_rows",None)


ga.sort_values("imp",ascending=False)
# Out:
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/lightgbm/engine.py:99: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/lightgbm/engine.py:104: UserWarning: Found `early_stopping` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	training's auc: 0.882534
# Training until validation scores don't improve for 50 rounds.
# [2]	training's auc: 0.894094
# [3]	training's auc: 0.898894
# [4]	training's auc: 0.902307
# [5]	training's auc: 0.903327
# [6]	training's auc: 0.905976
# [7]	training's auc: 0.908149
# [8]	training's auc: 0.909991
# [9]	training's auc: 0.911715
# [10]	training's auc: 0.912686
# [11]	training's auc: 0.914835
# [12]	training's auc: 0.916285
# [13]	training's auc: 0.917519
# [14]	training's auc: 0.918646
# [15]	training's auc: 0.919958
# [16]	training's auc: 0.921151
# [17]	training's auc: 0.922174
# [18]	training's auc: 0.922863
# [19]	training's auc: 0.923779
# [20]	training's auc: 0.924697
# [21]	training's auc: 0.925918
# [22]	training's auc: 0.926888
# [23]	training's auc: 0.927459
# [24]	training's auc: 0.928288
# [25]	training's auc: 0.929247
# [26]	training's auc: 0.929884
# [27]	training's auc: 0.931003
# [28]	training's auc: 0.931879
# [29]	training's auc: 0.932641
# [30]	training's auc: 0.933569
# [31]	training's auc: 0.934495
# [32]	training's auc: 0.935178
# [33]	training's auc: 0.93593
# [34]	training's auc: 0.936678
# [35]	training's auc: 0.937417
# [36]	training's auc: 0.937928
# [37]	training's auc: 0.938435
# [38]	training's auc: 0.939098
# [39]	training's auc: 0.939665
# [40]	training's auc: 0.940352
# [41]	training's auc: 0.94095
# [42]	training's auc: 0.941431
# [43]	training's auc: 0.941852
# [44]	training's auc: 0.942373
# [45]	training's auc: 0.942862
# [46]	training's auc: 0.943344
# [47]	training's auc: 0.943751
# [48]	training's auc: 0.944289
# [49]	training's auc: 0.944762
# [50]	training's auc: 0.94507
# [51]	training's auc: 0.945557
# [52]	training's auc: 0.945971
# [53]	training's auc: 0.946356
# [54]	training's auc: 0.946727
# [55]	training's auc: 0.947138
# [56]	training's auc: 0.947413
# [57]	training's auc: 0.94774
# [58]	training's auc: 0.947851
# [59]	training's auc: 0.948098
# [60]	training's auc: 0.948271
# [61]	training's auc: 0.948498
# [62]	training's auc: 0.948605
# [63]	training's auc: 0.948704
# [64]	training's auc: 0.948781
# [65]	training's auc: 0.94885
# [66]	training's auc: 0.948868
# [67]	training's auc: 0.948934
# [68]	training's auc: 0.948962
# [69]	training's auc: 0.949024
# [70]	training's auc: 0.949044
# [71]	training's auc: 0.94906
# [72]	training's auc: 0.949068
# [73]	training's auc: 0.949086
# [74]	training's auc: 0.949086
# [75]	training's auc: 0.949086
# [76]	training's auc: 0.949086
# [77]	training's auc: 0.949086
# [78]	training's auc: 0.949086
# [79]	training's auc: 0.949086
# [80]	training's auc: 0.949086
# [81]	training's auc: 0.949086
# [82]	training's auc: 0.949086
# [83]	training's auc: 0.949086
# [84]	training's auc: 0.949086
# [85]	training's auc: 0.949086
# [86]	training's auc: 0.949086
# [87]	training's auc: 0.949086
# [88]	training's auc: 0.949086
# [89]	training's auc: 0.949086
# [90]	training's auc: 0.949086
# [91]	training's auc: 0.949086
# [92]	training's auc: 0.949086
# [93]	training's auc: 0.949086
# [94]	training's auc: 0.949086
# [95]	training's auc: 0.949086
# [96]	training's auc: 0.949086
# [97]	training's auc: 0.949086
# [98]	training's auc: 0.949086
# [99]	training's auc: 0.949086
# [100]	training's auc: 0.949086
# [101]	training's auc: 0.949086
# [102]	training's auc: 0.949086
# [103]	training's auc: 0.949086
# [104]	training's auc: 0.949086
# [105]	training's auc: 0.949086
# [106]	training's auc: 0.949086
# [107]	training's auc: 0.949086
# [108]	training's auc: 0.949086
# [109]	training's auc: 0.949086
# [110]	training's auc: 0.949086
# [111]	training's auc: 0.949086
# [112]	training's auc: 0.949086
# [113]	training's auc: 0.949086
# [114]	training's auc: 0.949086
# [115]	training's auc: 0.949086
# [116]	training's auc: 0.949086
# [117]	training's auc: 0.949086
# [118]	training's auc: 0.949086
# [119]	training's auc: 0.949086
# [120]	training's auc: 0.949086
# [121]	training's auc: 0.949086
# [122]	training's auc: 0.949086
# [123]	training's auc: 0.949086
# Early stopping, best iteration is:
# [73]	training's auc: 0.949086
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: The spectral and spectral_r colormap was deprecated in version 2.0. Use nipy_spectral and nipy_spectral_r instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
#                                      name  imp
# 113                             days_mean  264
# 114                              days_std  211
# 56                          oldest_review  138
# 21                   review_count_usr_min   52
# 39                            useful_mean   43
# 23                  review_count_usr_mean   40
# 59                      stars_linear_coef   34
# 112                              days_sum   34
# 74                     average_stars_mean   34
# 195               oldest_review_chain_avg   34
# 251                   days_mean_chain_avg   34
# 137                        friends/review   33
# 252                    days_std_chain_avg   31
# 128                     Convenience Level   28
# 27                     senti_polarity_sum   26
# 55                       reviews_per_week   25
# 35                          last_sent_sum   25
# 120                           Connoisseur   23
# 203        zreview_per_week_all_chain_avg   22
# 160        review_count_usr_min_chain_avg   21
# 121                     Food Aestheticist   20
# 63                      zreview_count_all   19
# 119                           Low Network   17
# 111                       elite_count_std   17
# 24                   review_count_usr_max   16
# 28                    senti_polarity_mean   16
# 32                         first_sent_std   15
# 49                              cool_mean   15
# 194            reviews_per_week_chain_avg   15
# 52                              longitude   14
# 118                          High Network   13
# 30                        first_sent_mean   12
# 61                     restaurant_density   12
# 22                   review_count_usr_sum   11
# 46                               cool_std   11
# 202           zreview_count_all_chain_avg   11
# 0                              rating_std   11
# 38                             useful_sum   10
# 99                    compliment_cool_std   10
# 64                   zreview_per_week_all   10
# 259           Food Aestheticist_chain_avg   10
# 20                   review_count_usr_std    9
# 34                         first_sent_sum    9
# 323                    cool_std_chain_std    8
# 7                              gender_sum    8
# 266           Convenience Level_chain_avg    8
# 263    Average Customer Network_chain_avg    8
# 256                High Network_chain_avg    8
# 8                             gender_mean    7
# 329                   longitude_chain_std    7
# 369         compliment_note_std_chain_std    7
# 41                              funny_std    7
# 51                               latitude    7
# 410                Bike Parking_chain_std    7
# 198           stars_linear_coef_chain_avg    6
# 2                              rating_sum    6
# 54                       count_categories    6
# 150            friend_count_min_chain_avg    6
# 338          restaurant_density_chain_std    6
# 29                     senti_polarity_max    5
# 116                                  Male    5
# 78                     compliment_hot_std    5
# 75                      average_stars_std    5
# 73                      average_stars_sum    5
# 36                             useful_std    5
# 177                  useful_sum_chain_avg    5
# 190                    latitude_chain_avg    5
# 187                    cool_sum_chain_avg    5
# 178                 useful_mean_chain_avg    5
# 43                              funny_sum    4
# 82                 compliment_profile_sum    4
# 262           Female Importance_chain_avg    4
# 260                     Patrons_chain_avg    4
# 140                  rating_min_chain_avg    4
# 391              Male to Female_chain_std    4
# 161        review_count_usr_sum_chain_avg    4
# 25                     senti_polarity_std    4
# 247             elite_count_sum_chain_avg    4
# 5                              gender_std    3
# 94                   compliment_plain_sum    3
# 258                 Connoisseur_chain_avg    3
# 339  restaurant_similar_density_chain_std    3
# 349           average_stars_sum_chain_std    3
# 65                              zstar_all    3
# 232        compliment_plain_sum_chain_avg    3
# 124                     Female Importance    3
# 191                   longitude_chain_avg    3
# 174               last_sent_sum_chain_avg    3
# 398                     Patrons_chain_std    3
# 301        review_count_usr_max_chain_std    3
# 173              first_sent_sum_chain_avg    3
# 136                      review_count_loc    3
# 134                          Bike Parking    2
# 250                    days_sum_chain_avg    2
# 249             elite_count_std_chain_avg    2
# 109                       elite_count_sum    2
# 144                  gender_std_chain_avg    2
# 139                  rating_std_chain_avg    2
# 141                  rating_sum_chain_avg    2
# 110                      elite_count_mean    2
# 117                                Female    2
# 151            friend_count_sum_chain_avg    2
# 171              first_sent_std_chain_avg    2
# 127                   Number of Reviewers    2
# 165          senti_polarity_min_chain_avg    2
# 326                   cool_mean_chain_std    2
# 350          average_stars_mean_chain_std    2
# 26                     senti_polarity_min    2
# 72                               fans_std    2
# 31                         last_sent_mean    2
# 15                        photo_count_std    2
# 288            friend_count_min_chain_std    2
# 70                               fans_sum    2
# 33                          last_sent_std    2
# 166          senti_polarity_sum_chain_avg    2
# 313                  useful_std_chain_std    2
# 58                        median_of_stars    2
# 90                    compliment_list_std    2
# 257                 Low Network_chain_avg    2
# 53                             rating_pub    2
# 98                   compliment_cool_mean    2
# 385             elite_count_sum_chain_std    2
# 341        zreview_per_week_all_chain_std    1
# 193            count_categories_chain_avg    1
# 189                   cool_amax_chain_avg    1
# 188                   cool_mean_chain_avg    1
# 374        compliment_cool_mean_chain_std    1
# 254                        Male_chain_avg    1
# 389                   days_mean_chain_std    1
# 185                    cool_std_chain_avg    1
# 340           zreview_count_all_chain_std    1
# 182                   funny_sum_chain_avg    1
# 179                 useful_amax_chain_avg    1
# 390                    days_std_chain_std    1
# 393                      Female_chain_std    1
# 400           Female Importance_chain_std    1
# 403         Number of Reviewers_chain_std    1
# 407             Outdoor Seating_chain_std    1
# 412            review_count_loc_chain_std    1
# 168          senti_polarity_max_chain_avg    1
# 184                  funny_amax_chain_avg    1
# 199          reactions_per_week_chain_avg    1
# 316                 useful_mean_chain_std    1
# 255                      Female_chain_avg    1
# 241       compliment_writer_sum_chain_avg    1
# 269             Outdoor Seating_chain_avg    1
# 275              friends/review_chain_avg    1
# 276         first_min_last_sent_chain_avg    1
# 278                  rating_min_chain_std    1
# 282                  gender_std_chain_std    1
# 298        review_count_usr_min_chain_std    1
# 302          senti_polarity_std_chain_std    1
# 303          senti_polarity_min_chain_std    1
# 231         compliment_note_std_chain_avg    1
# 230        compliment_note_mean_chain_avg    1
# 305         senti_polarity_mean_chain_std    1
# 221     compliment_profile_mean_chain_avg    1
# 213           average_stars_std_chain_avg    1
# 306          senti_polarity_max_chain_std    1
# 211           average_stars_sum_chain_avg    1
# 208                    fans_sum_chain_avg    1
# 204                   zstar_all_chain_avg    1
# 307             first_sent_mean_chain_std    1
# 311              first_sent_sum_chain_std    1
# 312               last_sent_sum_chain_std    1
# 285                 gender_mean_chain_std    1
# 414         first_min_last_sent_chain_std    1
# 80                   compliment_more_mean    1
# 57                           std_of_stars    1
# 149            friend_count_std_chain_avg    1
# 60                     reactions_per_week    1
# 142                 rating_mean_chain_avg    1
# 12                       friend_count_sum    1
# 138                   first_min_last_sent    1
# 13                      friend_count_mean    1
# 50                              cool_amax    1
# 153            friend_count_max_chain_avg    1
# 89                   compliment_list_mean    1
# 92                   compliment_note_mean    1
# 93                    compliment_note_std    1
# 97                    compliment_cool_sum    1
# 103                 compliment_writer_sum    1
# 104                compliment_writer_mean    1
# 152           friend_count_mean_chain_avg    1
# 87                    compliment_cute_std    1
# 159        review_count_usr_std_chain_avg    1
# 3                             rating_mean    1
# 162       review_count_usr_mean_chain_avg    1
# 163        review_count_usr_max_chain_avg    1
# 164          senti_polarity_std_chain_avg    1
# 332            reviews_per_week_chain_std    0
# 333               oldest_review_chain_std    0
# 77                    compliment_hot_mean    0
# 334                std_of_stars_chain_std    0
# 335             median_of_stars_chain_std    0
# 336           stars_linear_coef_chain_std    0
# 337          reactions_per_week_chain_std    0
# 47                              cool_amin    0
# 45                             funny_amax    0
# 79                    compliment_more_sum    0
# 330                  rating_pub_chain_std    0
# 44                             funny_mean    0
# 42                             funny_amin    0
# 342                   zstar_all_chain_std    0
# 343                   stars_sum_chain_std    0
# 344                  stars_mean_chain_std    0
# 345                   stars_std_chain_std    0
# 346                    fans_sum_chain_std    0
# 347                   fans_mean_chain_std    0
# 348                    fans_std_chain_std    0
# 40                            useful_amax    0
# 331            count_categories_chain_std    0
# 67                              stars_sum    0
# 66                               is_chain    0
# 69                              stars_std    0
# 310               last_sent_std_chain_std    0
# 309              first_sent_std_chain_std    0
# 62             restaurant_similar_density    0
# 314                 useful_amin_chain_std    0
# 315                  useful_sum_chain_std    0
# 308              last_sent_mean_chain_std    0
# 317                 useful_amax_chain_std    0
# 318                   funny_std_chain_std    0
# 68                             stars_mean    0
# 319                  funny_amin_chain_std    0
# 71                              fans_mean    0
# 48                               cool_sum    0
# 320                   funny_sum_chain_std    0
# 321                  funny_mean_chain_std    0
# 351           average_stars_std_chain_std    0
# 322                  funny_amax_chain_std    0
# 304          senti_polarity_sum_chain_std    0
# 324                   cool_amin_chain_std    0
# 325                    cool_sum_chain_std    0
# 76                     compliment_hot_sum    0
# 327                   cool_amax_chain_std    0
# 328                    latitude_chain_std    0
# 37                            useful_amin    0
# 167         senti_polarity_mean_chain_avg    0
# 352          compliment_hot_sum_chain_std    0
# 353         compliment_hot_mean_chain_std    0
# 384       compliment_photos_std_chain_std    0
# 17                        photo_count_sum    0
# 386            elite_count_mean_chain_std    0
# 387             elite_count_std_chain_std    0
# 388                    days_sum_chain_std    0
# 16                        photo_count_min    0
# 14                       friend_count_max    0
# 392                        Male_chain_std    0
# 394                High Network_chain_std    0
# 395                 Low Network_chain_std    0
# 396                 Connoisseur_chain_std    0
# 397           Food Aestheticist_chain_std    0
# 11                       friend_count_min    0
# 399                 First Visit_chain_std    0
# 10                       friend_count_std    0
# 401    Average Customer Network_chain_std    0
# 402               Total Network_chain_std    0
# 9                              gender_max    0
# 404           Convenience Level_chain_std    0
# 405                  Free Wi-Fi_chain_std    0
# 406          Takes Reservations_chain_std    0
# 6                              gender_min    0
# 408                    Delivery_chain_std    0
# 409                      Caters_chain_std    0
# 4                              rating_max    0
# 411                       Noisy_chain_std    0
# 413              friends/review_chain_std    0
# 383      compliment_photos_mean_chain_std    0
# 382       compliment_photos_sum_chain_std    0
# 381       compliment_writer_std_chain_std    0
# 366         compliment_list_std_chain_std    0
# 354          compliment_hot_std_chain_std    0
# 355         compliment_more_sum_chain_std    0
# 356        compliment_more_mean_chain_std    0
# 300       review_count_usr_mean_chain_std    0
# 358      compliment_profile_sum_chain_std    0
# 359     compliment_profile_mean_chain_std    0
# 360      compliment_profile_std_chain_std    0
# 361         compliment_cute_sum_chain_std    0
# 362        compliment_cute_mean_chain_std    0
# 363         compliment_cute_std_chain_std    0
# 364         compliment_list_sum_chain_std    0
# 365        compliment_list_mean_chain_std    0
# 367         compliment_note_sum_chain_std    0
# 380      compliment_writer_mean_chain_std    0
# 368        compliment_note_mean_chain_std    0
# 19                        photo_count_max    0
# 370        compliment_plain_sum_chain_std    0
# 371       compliment_plain_mean_chain_std    0
# 372        compliment_plain_std_chain_std    0
# 373         compliment_cool_sum_chain_std    0
# 18                       photo_count_mean    0
# 375         compliment_cool_std_chain_std    0
# 376        compliment_funny_sum_chain_std    0
# 377       compliment_funny_mean_chain_std    0
# 378        compliment_funny_std_chain_std    0
# 379       compliment_writer_sum_chain_std    0
# 357         compliment_more_std_chain_std    0
# 291            friend_count_max_chain_std    0
# 299        review_count_usr_sum_chain_std    0
# 131                       Outdoor Seating    0
# 206                  stars_mean_chain_avg    0
# 1                              rating_min    0
# 130                    Takes Reservations    0
# 209                   fans_mean_chain_avg    0
# 210                    fans_std_chain_avg    0
# 129                            Free Wi-Fi    0
# 212          average_stars_mean_chain_avg    0
# 126                         Total Network    0
# 214          compliment_hot_sum_chain_avg    0
# 215         compliment_hot_mean_chain_avg    0
# 216          compliment_hot_std_chain_avg    0
# 217         compliment_more_sum_chain_avg    0
# 218        compliment_more_mean_chain_avg    0
# 219         compliment_more_std_chain_avg    0
# 220      compliment_profile_sum_chain_avg    0
# 125              Average Customer Network    0
# 222      compliment_profile_std_chain_avg    0
# 223         compliment_cute_sum_chain_avg    0
# 224        compliment_cute_mean_chain_avg    0
# 225         compliment_cute_std_chain_avg    0
# 226         compliment_list_sum_chain_avg    0
# 227        compliment_list_mean_chain_avg    0
# 228         compliment_list_std_chain_avg    0
# 229         compliment_note_sum_chain_avg    0
# 123                           First Visit    0
# 205                   stars_sum_chain_avg    0
# 132                              Delivery    0
# 115                        Male to Female    0
# 133                                Caters    0
# 169             first_sent_mean_chain_avg    0
# 170              last_sent_mean_chain_avg    0
# 172               last_sent_std_chain_avg    0
# 175                  useful_std_chain_avg    0
# 176                 useful_amin_chain_avg    0
# 158             photo_count_max_chain_avg    0
# 157            photo_count_mean_chain_avg    0
# 156             photo_count_sum_chain_avg    0
# 180                   funny_std_chain_avg    0
# 181                  funny_amin_chain_avg    0
# 155             photo_count_min_chain_avg    0
# 183                  funny_mean_chain_avg    0
# 154             photo_count_std_chain_avg    0
# 186                   cool_amin_chain_avg    0
# 148                  gender_max_chain_avg    0
# 147                 gender_mean_chain_avg    0
# 146                  gender_sum_chain_avg    0
# 192                  rating_pub_chain_avg    0
# 145                  gender_min_chain_avg    0
# 143                  rating_max_chain_avg    0
# 196                std_of_stars_chain_avg    0
# 197             median_of_stars_chain_avg    0
# 135                                 Noisy    0
# 200          restaurant_density_chain_avg    0
# 201  restaurant_similar_density_chain_avg    0
# 122                               Patrons    0
# 233       compliment_plain_mean_chain_avg    0
# 297        review_count_usr_std_chain_std    0
# 268          Takes Reservations_chain_avg    0
# 270                    Delivery_chain_avg    0
# 271                      Caters_chain_avg    0
# 272                Bike Parking_chain_avg    0
# 273                       Noisy_chain_avg    0
# 274            review_count_loc_chain_avg    0
# 86                   compliment_cute_mean    0
# 277                  rating_std_chain_std    0
# 85                    compliment_cute_sum    0
# 279                  rating_sum_chain_std    0
# 280                 rating_mean_chain_std    0
# 281                  rating_max_chain_std    0
# 84                 compliment_profile_std    0
# 283                  gender_min_chain_std    0
# 284                  gender_sum_chain_std    0
# 83                compliment_profile_mean    0
# 286                  gender_max_chain_std    0
# 287            friend_count_std_chain_std    0
# 81                    compliment_more_std    0
# 289            friend_count_sum_chain_std    0
# 290           friend_count_mean_chain_std    0
# 292             photo_count_std_chain_std    0
# 293             photo_count_min_chain_std    0
# 294             photo_count_sum_chain_std    0
# 295            photo_count_mean_chain_std    0
# 296             photo_count_max_chain_std    0
# 88                    compliment_list_sum    0
# 267                  Free Wi-Fi_chain_avg    0
# 234        compliment_plain_std_chain_avg    0
# 265         Number of Reviewers_chain_avg    0
# 235         compliment_cool_sum_chain_avg    0
# 236        compliment_cool_mean_chain_avg    0
# 237         compliment_cool_std_chain_avg    0
# 238        compliment_funny_sum_chain_avg    0
# 239       compliment_funny_mean_chain_avg    0
# 240        compliment_funny_std_chain_avg    0
# 108                 compliment_photos_std    0
# 242      compliment_writer_mean_chain_avg    0
# 243       compliment_writer_std_chain_avg    0
# 244       compliment_photos_sum_chain_avg    0
# 245      compliment_photos_mean_chain_avg    0
# 246       compliment_photos_std_chain_avg    0
# 107                compliment_photos_mean    0
# 248            elite_count_mean_chain_avg    0
# 106                 compliment_photos_sum    0
# 105                 compliment_writer_std    0
# 253              Male to Female_chain_avg    0
# 102                  compliment_funny_std    0
# 101                 compliment_funny_mean    0
# 100                  compliment_funny_sum    0
# 96                   compliment_plain_std    0
# 95                  compliment_plain_mean    0
# 261                 First Visit_chain_avg    0
# 91                    compliment_note_sum    0
# 264               Total Network_chain_avg    0
# 207                   stars_std_chain_avg    0

# %%
ga.sort_values("imp",ascending=False)
# Out:
#                                      name  imp
# 118                             days_mean  306
# 7                               diffs_sum  233
# 119                              days_std  150
# 8                              diffs_mean  102
# 28                  review_count_usr_mean   42
# 9                               diffs_max   35
# 133                     Convenience Level   33
# 26                   review_count_usr_min   31
# 142                        friends/review   30
# 262                    days_std_chain_avg   27
# 44                            useful_mean   26
# 64                      stars_linear_coef   26
# 32                     senti_polarity_sum   25
# 66                     restaurant_density   23
# 124                           Low Network   22
# 56                               latitude   22
# 51                               cool_std   22
# 125                           Connoisseur   21
# 5                               diffs_std   20
# 126                     Food Aestheticist   17
# 268                 Connoisseur_chain_avg   16
# 61                          oldest_review   16
# 57                              longitude   15
# 68                      zreview_count_all   15
# 151                   diffs_sum_chain_avg   15
# 139                          Bike Parking   14
# 35                        first_sent_mean   14
# 33                    senti_polarity_mean   14
# 0                              rating_std   14
# 170        review_count_usr_min_chain_avg   13
# 212           zreview_count_all_chain_avg   13
# 79                     average_stars_mean   13
# 261                   days_mean_chain_avg   13
# 123                          High Network   12
# 129                     Female Importance   12
# 143                   first_min_last_sent   11
# 117                              days_sum   11
# 297                  gender_std_chain_std   10
# 95                    compliment_list_std    9
# 10                             gender_std    9
# 163            friend_count_max_chain_avg    8
# 213        zreview_per_week_all_chain_avg    8
# 69                   zreview_per_week_all    8
# 41                             useful_std    8
# 208           stars_linear_coef_chain_avg    7
# 60                       reviews_per_week    7
# 269           Food Aestheticist_chain_avg    7
# 38                          last_sent_std    7
# 43                             useful_sum    6
# 204            reviews_per_week_chain_avg    5
# 160            friend_count_min_chain_avg    5
# 425                Bike Parking_chain_std    5
# 201                   longitude_chain_avg    5
# 413                     Patrons_chain_std    5
# 184               last_sent_sum_chain_avg    5
# 23                       photo_count_mean    5
# 30                     senti_polarity_std    5
# 265                      Female_chain_avg    5
# 270                     Patrons_chain_avg    5
# 153                   diffs_max_chain_avg    5
# 200                    latitude_chain_avg    5
# 266                High Network_chain_avg    5
# 145                  rating_min_chain_avg    5
# 3                             rating_mean    4
# 309             photo_count_sum_chain_std    4
# 85                   compliment_more_mean    4
# 2                              rating_sum    4
# 29                   review_count_usr_max    4
# 311             photo_count_max_chain_std    4
# 330                  useful_sum_chain_std    4
# 31                     senti_polarity_min    4
# 25                   review_count_usr_std    4
# 34                     senti_polarity_max    4
# 39                         first_sent_sum    4
# 205               oldest_review_chain_avg    4
# 20                        photo_count_std    4
# 18                      friend_count_mean    4
# 404                   days_mean_chain_std    4
# 241         compliment_note_std_chain_avg    3
# 209          reactions_per_week_chain_avg    3
# 152                  diffs_mean_chain_avg    3
# 176          senti_polarity_sum_chain_avg    3
# 146                  rating_sum_chain_avg    3
# 100                 compliment_plain_mean    3
# 98                    compliment_note_std    3
# 238         compliment_list_std_chain_avg    3
# 96                    compliment_note_sum    3
# 187                  useful_sum_chain_avg    3
# 172       review_count_usr_mean_chain_avg    3
# 354  restaurant_similar_density_chain_std    3
# 88                compliment_profile_mean    3
# 40                          last_sent_sum    3
# 63                        median_of_stars    3
# 400             elite_count_sum_chain_std    3
# 286         first_min_last_sent_chain_avg    3
# 324              first_sent_std_chain_std    3
# 89                 compliment_profile_std    2
# 132                   Number of Reviewers    2
# 188                 useful_mean_chain_avg    2
# 121                                  Male    2
# 193                  funny_mean_chain_avg    2
# 62                           std_of_stars    2
# 319          senti_polarity_sum_chain_std    2
# 235         compliment_cute_std_chain_avg    2
# 223           average_stars_std_chain_avg    2
# 214                   zstar_all_chain_avg    2
# 154                  gender_std_chain_avg    2
# 27                   review_count_usr_sum    2
# 326              first_sent_sum_chain_std    2
# 19                       friend_count_max    2
# 49                             funny_mean    2
# 48                              funny_sum    2
# 338                    cool_std_chain_std    2
# 45                            useful_amax    2
# 342                   cool_amax_chain_std    2
# 353          restaurant_density_chain_std    2
# 70                              zstar_all    2
# 307             photo_count_std_chain_std    2
# 78                      average_stars_sum    2
# 293                   diffs_min_chain_std    2
# 91                   compliment_cute_mean    2
# 171        review_count_usr_sum_chain_avg    2
# 94                   compliment_list_mean    2
# 169        review_count_usr_std_chain_avg    2
# 97                   compliment_note_mean    2
# 416    Average Customer Network_chain_std    2
# 178          senti_polarity_max_chain_avg    2
# 267                 Low Network_chain_avg    2
# 116                       elite_count_std    2
# 147                 rating_mean_chain_avg    2
# 415           Female Importance_chain_std    2
# 115                      elite_count_mean    2
# 114                       elite_count_sum    2
# 74                              stars_std    2
# 108                 compliment_writer_sum    2
# 251       compliment_writer_sum_chain_avg    2
# 260                    days_sum_chain_avg    2
# 356        zreview_per_week_all_chain_std    1
# 428              friends/review_chain_std    1
# 355           zreview_count_all_chain_std    1
# 410                 Low Network_chain_std    1
# 199                   cool_amax_chain_avg    1
# 177         senti_polarity_mean_chain_avg    1
# 194                  funny_amax_chain_avg    1
# 180              last_sent_mean_chain_avg    1
# 195                    cool_std_chain_avg    1
# 182               last_sent_std_chain_avg    1
# 381         compliment_list_std_chain_std    1
# 221           average_stars_sum_chain_avg    1
# 203            count_categories_chain_avg    1
# 345                  rating_pub_chain_std    1
# 272           Female Importance_chain_avg    1
# 275         Number of Reviewers_chain_avg    1
# 173        review_count_usr_max_chain_avg    1
# 284            review_count_loc_chain_avg    1
# 287                  rating_std_chain_std    1
# 288                  rating_min_chain_std    1
# 290                 rating_mean_chain_std    1
# 263              Male to Female_chain_avg    1
# 295                  diffs_mean_chain_std    1
# 258            elite_count_mean_chain_avg    1
# 257             elite_count_sum_chain_avg    1
# 303            friend_count_min_chain_std    1
# 317          senti_polarity_std_chain_std    1
# 236         compliment_list_sum_chain_avg    1
# 323              last_sent_mean_chain_std    1
# 228        compliment_more_mean_chain_avg    1
# 273    Average Customer Network_chain_avg    1
# 325               last_sent_std_chain_std    1
# 328                  useful_std_chain_std    1
# 206                std_of_stars_chain_avg    1
# 341                   cool_mean_chain_std    1
# 276           Convenience Level_chain_avg    1
# 429         first_min_last_sent_chain_std    1
# 113                 compliment_photos_std    1
# 76                              fans_mean    1
# 130              Average Customer Network    1
# 104                   compliment_cool_std    1
# 17                       friend_count_sum    1
# 109                compliment_writer_mean    1
# 144                  rating_std_chain_avg    1
# 50                             funny_amax    1
# 110                 compliment_writer_std    1
# 150                   diffs_min_chain_avg    1
# 80                      average_stars_std    1
# 54                              cool_mean    1
# 157                 gender_mean_chain_avg    1
# 77                               fans_std    1
# 55                              cool_amax    1
# 12                             gender_sum    1
# 53                               cool_sum    1
# 58                             rating_pub    1
# 161            friend_count_sum_chain_avg    1
# 59                       count_categories    1
# 164             photo_count_std_chain_avg    1
# 65                     reactions_per_week    1
# 122                                Female    1
# 112                compliment_photos_mean    1
# 36                         last_sent_mean    0
# 347            reviews_per_week_chain_std    0
# 348               oldest_review_chain_std    0
# 349                std_of_stars_chain_std    0
# 364           average_stars_sum_chain_std    0
# 350             median_of_stars_chain_std    0
# 363                    fans_std_chain_std    0
# 351           stars_linear_coef_chain_std    0
# 352          reactions_per_week_chain_std    0
# 361                    fans_sum_chain_std    0
# 362                   fans_mean_chain_std    0
# 24                        photo_count_max    0
# 22                        photo_count_sum    0
# 360                   stars_std_chain_std    0
# 21                        photo_count_min    0
# 357                   zstar_all_chain_std    0
# 37                         first_sent_std    0
# 359                  stars_mean_chain_std    0
# 358                   stars_sum_chain_std    0
# 346            count_categories_chain_std    0
# 337                  funny_amax_chain_std    0
# 344                   longitude_chain_std    0
# 329                 useful_amin_chain_std    0
# 312        review_count_usr_std_chain_std    0
# 313        review_count_usr_min_chain_std    0
# 314        review_count_usr_sum_chain_std    0
# 315       review_count_usr_mean_chain_std    0
# 316        review_count_usr_max_chain_std    0
# 318          senti_polarity_min_chain_std    0
# 320         senti_polarity_mean_chain_std    0
# 321          senti_polarity_max_chain_std    0
# 322             first_sent_mean_chain_std    0
# 327               last_sent_sum_chain_std    0
# 52                              cool_amin    0
# 331                 useful_mean_chain_std    0
# 343                    latitude_chain_std    0
# 332                 useful_amax_chain_std    0
# 333                   funny_std_chain_std    0
# 334                  funny_amin_chain_std    0
# 335                   funny_sum_chain_std    0
# 336                  funny_mean_chain_std    0
# 366           average_stars_std_chain_std    0
# 47                             funny_amin    0
# 339                   cool_amin_chain_std    0
# 340                    cool_sum_chain_std    0
# 46                              funny_std    0
# 42                            useful_amin    0
# 365          average_stars_mean_chain_std    0
# 174          senti_polarity_std_chain_avg    0
# 367          compliment_hot_sum_chain_std    0
# 13                            gender_mean    0
# 16                       friend_count_min    0
# 401            elite_count_mean_chain_std    0
# 402             elite_count_std_chain_std    0
# 403                    days_sum_chain_std    0
# 15                       friend_count_std    0
# 405                    days_std_chain_std    0
# 406              Male to Female_chain_std    0
# 407                        Male_chain_std    0
# 408                      Female_chain_std    0
# 409                High Network_chain_std    0
# 14                             gender_max    0
# 411                 Connoisseur_chain_std    0
# 412           Food Aestheticist_chain_std    0
# 414                 First Visit_chain_std    0
# 368         compliment_hot_mean_chain_std    0
# 11                             gender_min    0
# 417               Total Network_chain_std    0
# 418         Number of Reviewers_chain_std    0
# 419           Convenience Level_chain_std    0
# 420                  Free Wi-Fi_chain_std    0
# 421          Takes Reservations_chain_std    0
# 422             Outdoor Seating_chain_std    0
# 423                    Delivery_chain_std    0
# 424                      Caters_chain_std    0
# 6                               diffs_min    0
# 426                       Noisy_chain_std    0
# 427            review_count_loc_chain_std    0
# 4                              rating_max    0
# 399       compliment_photos_std_chain_std    0
# 398      compliment_photos_mean_chain_std    0
# 397       compliment_photos_sum_chain_std    0
# 396       compliment_writer_std_chain_std    0
# 369          compliment_hot_std_chain_std    0
# 370         compliment_more_sum_chain_std    0
# 310            photo_count_mean_chain_std    0
# 371        compliment_more_mean_chain_std    0
# 372         compliment_more_std_chain_std    0
# 373      compliment_profile_sum_chain_std    0
# 374     compliment_profile_mean_chain_std    0
# 375      compliment_profile_std_chain_std    0
# 376         compliment_cute_sum_chain_std    0
# 377        compliment_cute_mean_chain_std    0
# 378         compliment_cute_std_chain_std    0
# 379         compliment_list_sum_chain_std    0
# 380        compliment_list_mean_chain_std    0
# 382         compliment_note_sum_chain_std    0
# 383        compliment_note_mean_chain_std    0
# 384         compliment_note_std_chain_std    0
# 385        compliment_plain_sum_chain_std    0
# 386       compliment_plain_mean_chain_std    0
# 387        compliment_plain_std_chain_std    0
# 388         compliment_cool_sum_chain_std    0
# 389        compliment_cool_mean_chain_std    0
# 390         compliment_cool_std_chain_std    0
# 391        compliment_funny_sum_chain_std    0
# 392       compliment_funny_mean_chain_std    0
# 393        compliment_funny_std_chain_std    0
# 394       compliment_writer_sum_chain_std    0
# 395      compliment_writer_mean_chain_std    0
# 67             restaurant_similar_density    0
# 302            friend_count_std_chain_std    0
# 71                               is_chain    0
# 308             photo_count_min_chain_std    0
# 211  restaurant_similar_density_chain_avg    0
# 136                       Outdoor Seating    0
# 135                    Takes Reservations    0
# 134                            Free Wi-Fi    0
# 1                              rating_min    0
# 216                  stars_mean_chain_avg    0
# 217                   stars_std_chain_avg    0
# 218                    fans_sum_chain_avg    0
# 219                   fans_mean_chain_avg    0
# 220                    fans_std_chain_avg    0
# 131                         Total Network    0
# 222          average_stars_mean_chain_avg    0
# 224          compliment_hot_sum_chain_avg    0
# 225         compliment_hot_mean_chain_avg    0
# 226          compliment_hot_std_chain_avg    0
# 227         compliment_more_sum_chain_avg    0
# 128                           First Visit    0
# 229         compliment_more_std_chain_avg    0
# 230      compliment_profile_sum_chain_avg    0
# 231     compliment_profile_mean_chain_avg    0
# 232      compliment_profile_std_chain_avg    0
# 233         compliment_cute_sum_chain_avg    0
# 234        compliment_cute_mean_chain_avg    0
# 127                               Patrons    0
# 237        compliment_list_mean_chain_avg    0
# 120                        Male to Female    0
# 239         compliment_note_sum_chain_avg    0
# 210          restaurant_density_chain_avg    0
# 137                              Delivery    0
# 138                                Caters    0
# 190                   funny_std_chain_avg    0
# 168             photo_count_max_chain_avg    0
# 167            photo_count_mean_chain_avg    0
# 166             photo_count_sum_chain_avg    0
# 179             first_sent_mean_chain_avg    0
# 165             photo_count_min_chain_avg    0
# 181              first_sent_std_chain_avg    0
# 183              first_sent_sum_chain_avg    0
# 162           friend_count_mean_chain_avg    0
# 185                  useful_std_chain_avg    0
# 186                 useful_amin_chain_avg    0
# 159            friend_count_std_chain_avg    0
# 189                 useful_amax_chain_avg    0
# 191                  funny_amin_chain_avg    0
# 207             median_of_stars_chain_avg    0
# 192                   funny_sum_chain_avg    0
# 158                  gender_max_chain_avg    0
# 156                  gender_sum_chain_avg    0
# 196                   cool_amin_chain_avg    0
# 197                    cool_sum_chain_avg    0
# 198                   cool_mean_chain_avg    0
# 155                  gender_min_chain_avg    0
# 149                   diffs_std_chain_avg    0
# 202                  rating_pub_chain_avg    0
# 148                  rating_max_chain_avg    0
# 141                      review_count_loc    0
# 140                                 Noisy    0
# 240        compliment_note_mean_chain_avg    0
# 242        compliment_plain_sum_chain_avg    0
# 243       compliment_plain_mean_chain_avg    0
# 292                   diffs_std_chain_std    0
# 279             Outdoor Seating_chain_avg    0
# 280                    Delivery_chain_avg    0
# 281                      Caters_chain_avg    0
# 282                Bike Parking_chain_avg    0
# 283                       Noisy_chain_avg    0
# 84                    compliment_more_sum    0
# 285              friends/review_chain_avg    0
# 83                     compliment_hot_std    0
# 82                    compliment_hot_mean    0
# 81                     compliment_hot_sum    0
# 289                  rating_sum_chain_std    0
# 291                  rating_max_chain_std    0
# 294                   diffs_sum_chain_std    0
# 277                  Free Wi-Fi_chain_avg    0
# 296                   diffs_max_chain_std    0
# 75                               fans_sum    0
# 298                  gender_min_chain_std    0
# 299                  gender_sum_chain_std    0
# 300                 gender_mean_chain_std    0
# 301                  gender_max_chain_std    0
# 175          senti_polarity_min_chain_avg    0
# 73                             stars_mean    0
# 304            friend_count_sum_chain_std    0
# 305           friend_count_mean_chain_std    0
# 306            friend_count_max_chain_std    0
# 72                              stars_sum    0
# 278          Takes Reservations_chain_avg    0
# 86                    compliment_more_std    0
# 244        compliment_plain_std_chain_avg    0
# 259             elite_count_std_chain_avg    0
# 245         compliment_cool_sum_chain_avg    0
# 246        compliment_cool_mean_chain_avg    0
# 247         compliment_cool_std_chain_avg    0
# 248        compliment_funny_sum_chain_avg    0
# 249       compliment_funny_mean_chain_avg    0
# 250        compliment_funny_std_chain_avg    0
# 252      compliment_writer_mean_chain_avg    0
# 253       compliment_writer_std_chain_avg    0
# 254       compliment_photos_sum_chain_avg    0
# 255      compliment_photos_mean_chain_avg    0
# 256       compliment_photos_std_chain_avg    0
# 111                 compliment_photos_sum    0
# 107                  compliment_funny_std    0
# 87                 compliment_profile_sum    0
# 106                 compliment_funny_mean    0
# 105                  compliment_funny_sum    0
# 264                        Male_chain_avg    0
# 103                  compliment_cool_mean    0
# 102                   compliment_cool_sum    0
# 101                  compliment_plain_std    0
# 99                   compliment_plain_sum    0
# 93                    compliment_list_sum    0
# 271                 First Visit_chain_avg    0
# 92                    compliment_cute_std    0
# 90                    compliment_cute_sum    0
# 274               Total Network_chain_avg    0
# 215                   stars_sum_chain_avg    0

# %%
ga.sort_values("imp",ascending=False)
# Out:
#                                      name  imp
# 111                       elite_count_std  100
# 56                          oldest_review   99
# 39                            useful_mean   95
# 75                      average_stars_std   82
# 46                               cool_std   61
# 74                     average_stars_mean   41
# 30                        first_sent_mean   40
# 117                           Connoisseur   39
# 118                     Food Aestheticist   39
# 192               oldest_review_chain_avg   37
# 59                      stars_linear_coef   37
# 125                     Convenience Level   36
# 32                         first_sent_std   35
# 110                      elite_count_mean   34
# 63                      zreview_count_all   32
# 61                     restaurant_density   32
# 131                          Bike Parking   32
# 86                   compliment_cute_mean   31
# 25                     senti_polarity_std   29
# 80                   compliment_more_mean   29
# 52                              longitude   27
# 38                             useful_sum   25
# 33                          last_sent_std   25
# 51                               latitude   25
# 28                    senti_polarity_mean   24
# 20                   review_count_usr_std   23
# 18                       photo_count_mean   23
# 65                              zstar_all   22
# 191            reviews_per_week_chain_avg   22
# 64                   zreview_per_week_all   22
# 24                   review_count_usr_max   21
# 34                         first_sent_sum   20
# 115                          High Network   19
# 77                    compliment_hot_mean   19
# 54                       count_categories   18
# 83                compliment_profile_mean   18
# 55                       reviews_per_week   18
# 246             elite_count_std_chain_avg   17
# 19                        photo_count_max   17
# 0                              rating_std   17
# 15                        photo_count_std   17
# 89                   compliment_list_mean   15
# 17                        photo_count_sum   15
# 252                 Connoisseur_chain_avg   15
# 50                              cool_amax   15
# 332          restaurant_density_chain_std   15
# 135                   first_min_last_sent   13
# 175                 useful_mean_chain_avg   13
# 200        zreview_per_week_all_chain_avg   13
# 134                        friends/review   13
# 27                     senti_polarity_sum   13
# 8                             gender_mean   13
# 21                   review_count_usr_min   12
# 84                 compliment_profile_std   12
# 199           zreview_count_all_chain_avg   12
# 195           stars_linear_coef_chain_avg   12
# 85                    compliment_cute_sum   11
# 95                  compliment_plain_mean   11
# 401                Bike Parking_chain_std   10
# 187                    latitude_chain_avg   10
# 321                   cool_amax_chain_std   10
# 26                     senti_polarity_min   10
# 253           Food Aestheticist_chain_avg   10
# 112                        Male to Female    9
# 82                 compliment_profile_sum    9
# 71                              fans_mean    9
# 35                          last_sent_sum    9
# 391           Female Importance_chain_std    9
# 88                    compliment_list_sum    8
# 31                         last_sent_mean    8
# 270         first_min_last_sent_chain_avg    7
# 186                   cool_amax_chain_avg    7
# 11                       friend_count_min    7
# 198  restaurant_similar_density_chain_avg    7
# 171               last_sent_sum_chain_avg    7
# 12                       friend_count_sum    7
# 40                            useful_amax    7
# 120                           First Visit    6
# 109                       elite_count_sum    6
# 201                   zstar_all_chain_avg    6
# 41                              funny_std    6
# 36                             useful_std    6
# 269              friends/review_chain_avg    5
# 276                  gender_std_chain_std    5
# 260           Convenience Level_chain_avg    5
# 182                    cool_std_chain_avg    5
# 327               oldest_review_chain_std    5
# 81                    compliment_more_std    5
# 323                   longitude_chain_std    5
# 369         compliment_cool_std_chain_std    5
# 188                   longitude_chain_avg    5
# 116                           Low Network    4
# 249                      Female_chain_avg    4
# 113                                  Male    4
# 144                 gender_mean_chain_avg    4
# 168              first_sent_std_chain_avg    4
# 282            friend_count_min_chain_std    4
# 2                              rating_sum    4
# 60                     reactions_per_week    4
# 92                   compliment_note_mean    4
# 58                        median_of_stars    4
# 190            count_categories_chain_avg    3
# 210           average_stars_std_chain_avg    3
# 138                  rating_sum_chain_avg    3
# 157        review_count_usr_min_chain_avg    3
# 166             first_sent_mean_chain_avg    3
# 185                   cool_mean_chain_avg    3
# 336                   zstar_all_chain_std    3
# 316                  funny_amax_chain_std    3
# 76                     compliment_hot_sum    3
# 13                      friend_count_mean    3
# 250                High Network_chain_avg    3
# 254                     Patrons_chain_avg    3
# 404              friends/review_chain_std    3
# 3                             rating_mean    3
# 290             photo_count_max_chain_std    3
# 285            friend_count_max_chain_std    3
# 122              Average Customer Network    3
# 141                  gender_std_chain_avg    3
# 44                             funny_mean    2
# 295        review_count_usr_max_chain_std    2
# 212         compliment_hot_mean_chain_avg    2
# 233        compliment_cool_mean_chain_avg    2
# 146            friend_count_std_chain_avg    2
# 305              first_sent_sum_chain_std    2
# 158        review_count_usr_sum_chain_avg    2
# 160        review_count_usr_max_chain_avg    2
# 333  restaurant_similar_density_chain_std    2
# 105                 compliment_writer_std    2
# 104                compliment_writer_mean    2
# 43                              funny_sum    2
# 403            review_count_loc_chain_std    2
# 222         compliment_cute_std_chain_avg    2
# 114                                Female    2
# 62             restaurant_similar_density    2
# 170              first_sent_sum_chain_avg    2
# 266                Bike Parking_chain_avg    2
# 73                      average_stars_sum    2
# 124                   Number of Reviewers    2
# 194             median_of_stars_chain_avg    1
# 94                   compliment_plain_sum    1
# 329             median_of_stars_chain_std    1
# 181                  funny_amax_chain_avg    1
# 57                           std_of_stars    1
# 211          compliment_hot_sum_chain_avg    1
# 209          average_stars_mean_chain_avg    1
# 108                 compliment_photos_std    1
# 48                               cool_sum    1
# 45                             funny_amax    1
# 196          reactions_per_week_chain_avg    1
# 328                std_of_stars_chain_std    1
# 119                               Patrons    1
# 307                  useful_std_chain_std    1
# 221        compliment_cute_mean_chain_avg    1
# 14                       friend_count_max    1
# 279                 gender_mean_chain_std    1
# 278                  gender_sum_chain_std    1
# 381             elite_count_std_chain_std    1
# 275                  rating_max_chain_std    1
# 288             photo_count_sum_chain_std    1
# 380            elite_count_mean_chain_std    1
# 103                 compliment_writer_sum    1
# 268            review_count_loc_chain_avg    1
# 292        review_count_usr_min_chain_std    1
# 259         Number of Reviewers_chain_avg    1
# 298          senti_polarity_sum_chain_std    1
# 299         senti_polarity_mean_chain_std    1
# 10                       friend_count_std    1
# 248                        Male_chain_avg    1
# 303              first_sent_std_chain_std    1
# 244             elite_count_sum_chain_avg    1
# 240       compliment_writer_std_chain_avg    1
# 344          average_stars_mean_chain_std    1
# 317                    cool_std_chain_std    1
# 180                  funny_mean_chain_avg    1
# 29                     senti_polarity_max    1
# 389                     Patrons_chain_std    1
# 143                  gender_sum_chain_avg    1
# 136                  rating_std_chain_avg    1
# 87                    compliment_cute_std    1
# 155             photo_count_max_chain_avg    1
# 133                      review_count_loc    1
# 70                               fans_sum    1
# 72                               fans_std    1
# 163          senti_polarity_sum_chain_avg    1
# 164         senti_polarity_mean_chain_avg    1
# 283            friend_count_sum_chain_std    1
# 159       review_count_usr_mean_chain_avg    1
# 90                    compliment_list_std    1
# 93                    compliment_note_std    1
# 390                 First Visit_chain_std    1
# 91                    compliment_note_sum    1
# 304               last_sent_std_chain_std    0
# 301             first_sent_mean_chain_std    0
# 311                 useful_amax_chain_std    0
# 310                 useful_mean_chain_std    0
# 402                       Noisy_chain_std    0
# 400                      Caters_chain_std    0
# 309                  useful_sum_chain_std    0
# 308                 useful_amin_chain_std    0
# 367         compliment_cool_sum_chain_std    0
# 365       compliment_plain_mean_chain_std    0
# 363         compliment_note_std_chain_std    0
# 364        compliment_plain_sum_chain_std    0
# 366        compliment_plain_std_chain_std    0
# 306               last_sent_sum_chain_std    0
# 378       compliment_photos_std_chain_std    0
# 302              last_sent_mean_chain_std    0
# 346          compliment_hot_sum_chain_std    0
# 300          senti_polarity_max_chain_std    0
# 368        compliment_cool_mean_chain_std    0
# 284           friend_count_mean_chain_std    0
# 382              Male to Female_chain_std    0
# 376       compliment_photos_sum_chain_std    0
# 386                 Low Network_chain_std    0
# 286             photo_count_std_chain_std    0
# 375       compliment_writer_std_chain_std    0
# 374      compliment_writer_mean_chain_std    0
# 287             photo_count_min_chain_std    0
# 373       compliment_writer_sum_chain_std    0
# 289            photo_count_mean_chain_std    0
# 372        compliment_funny_std_chain_std    0
# 379             elite_count_sum_chain_std    0
# 371       compliment_funny_mean_chain_std    0
# 370        compliment_funny_sum_chain_std    0
# 291        review_count_usr_std_chain_std    0
# 293        review_count_usr_sum_chain_std    0
# 294       review_count_usr_mean_chain_std    0
# 296          senti_polarity_std_chain_std    0
# 388           Food Aestheticist_chain_std    0
# 362        compliment_note_mean_chain_std    0
# 297          senti_polarity_min_chain_std    0
# 312                   funny_std_chain_std    0
# 377      compliment_photos_mean_chain_std    0
# 313                  funny_amin_chain_std    0
# 335        zreview_per_week_all_chain_std    0
# 337                   stars_sum_chain_std    0
# 387                 Connoisseur_chain_std    0
# 396                  Free Wi-Fi_chain_std    0
# 395           Convenience Level_chain_std    0
# 353     compliment_profile_mean_chain_std    0
# 338                  stars_mean_chain_std    0
# 352      compliment_profile_sum_chain_std    0
# 339                   stars_std_chain_std    0
# 351         compliment_more_std_chain_std    0
# 394         Number of Reviewers_chain_std    0
# 383                        Male_chain_std    0
# 340                    fans_sum_chain_std    0
# 350        compliment_more_mean_chain_std    0
# 393               Total Network_chain_std    0
# 392    Average Customer Network_chain_std    0
# 341                   fans_mean_chain_std    0
# 342                    fans_std_chain_std    0
# 349         compliment_more_sum_chain_std    0
# 348          compliment_hot_std_chain_std    0
# 347         compliment_hot_mean_chain_std    0
# 343           average_stars_sum_chain_std    0
# 385                High Network_chain_std    0
# 334           zreview_count_all_chain_std    0
# 314                   funny_sum_chain_std    0
# 354      compliment_profile_std_chain_std    0
# 315                  funny_mean_chain_std    0
# 345           average_stars_std_chain_std    0
# 361         compliment_note_sum_chain_std    0
# 318                   cool_amin_chain_std    0
# 319                    cool_sum_chain_std    0
# 320                   cool_mean_chain_std    0
# 360         compliment_list_std_chain_std    0
# 322                    latitude_chain_std    0
# 359        compliment_list_mean_chain_std    0
# 358         compliment_list_sum_chain_std    0
# 399                    Delivery_chain_std    0
# 324                  rating_pub_chain_std    0
# 325            count_categories_chain_std    0
# 326            reviews_per_week_chain_std    0
# 398             Outdoor Seating_chain_std    0
# 357         compliment_cute_std_chain_std    0
# 356        compliment_cute_mean_chain_std    0
# 330           stars_linear_coef_chain_std    0
# 355         compliment_cute_sum_chain_std    0
# 331          reactions_per_week_chain_std    0
# 397          Takes Reservations_chain_std    0
# 384                      Female_chain_std    0
# 203                  stars_mean_chain_avg    0
# 281            friend_count_std_chain_std    0
# 123                         Total Network    0
# 127                    Takes Reservations    0
# 128                       Outdoor Seating    0
# 129                              Delivery    0
# 130                                Caters    0
# 132                                 Noisy    0
# 137                  rating_min_chain_avg    0
# 139                 rating_mean_chain_avg    0
# 140                  rating_max_chain_avg    0
# 142                  gender_min_chain_avg    0
# 145                  gender_max_chain_avg    0
# 147            friend_count_min_chain_avg    0
# 148            friend_count_sum_chain_avg    0
# 149           friend_count_mean_chain_avg    0
# 150            friend_count_max_chain_avg    0
# 151             photo_count_std_chain_avg    0
# 152             photo_count_min_chain_avg    0
# 153             photo_count_sum_chain_avg    0
# 154            photo_count_mean_chain_avg    0
# 156        review_count_usr_std_chain_avg    0
# 161          senti_polarity_std_chain_avg    0
# 162          senti_polarity_min_chain_avg    0
# 165          senti_polarity_max_chain_avg    0
# 167              last_sent_mean_chain_avg    0
# 169               last_sent_std_chain_avg    0
# 172                  useful_std_chain_avg    0
# 173                 useful_amin_chain_avg    0
# 174                  useful_sum_chain_avg    0
# 126                            Free Wi-Fi    0
# 121                     Female Importance    0
# 280                  gender_max_chain_std    0
# 107                compliment_photos_mean    0
# 4                              rating_max    0
# 5                              gender_std    0
# 6                              gender_min    0
# 7                              gender_sum    0
# 9                              gender_max    0
# 16                        photo_count_min    0
# 22                   review_count_usr_sum    0
# 23                  review_count_usr_mean    0
# 37                            useful_amin    0
# 42                             funny_amin    0
# 47                              cool_amin    0
# 49                              cool_mean    0
# 53                             rating_pub    0
# 66                               is_chain    0
# 67                              stars_sum    0
# 68                             stars_mean    0
# 69                              stars_std    0
# 78                     compliment_hot_std    0
# 79                    compliment_more_sum    0
# 96                   compliment_plain_std    0
# 97                    compliment_cool_sum    0
# 98                   compliment_cool_mean    0
# 99                    compliment_cool_std    0
# 100                  compliment_funny_sum    0
# 101                 compliment_funny_mean    0
# 102                  compliment_funny_std    0
# 106                 compliment_photos_sum    0
# 176                 useful_amax_chain_avg    0
# 177                   funny_std_chain_avg    0
# 178                  funny_amin_chain_avg    0
# 179                   funny_sum_chain_avg    0
# 234         compliment_cool_std_chain_avg    0
# 235        compliment_funny_sum_chain_avg    0
# 236       compliment_funny_mean_chain_avg    0
# 237        compliment_funny_std_chain_avg    0
# 238       compliment_writer_sum_chain_avg    0
# 239      compliment_writer_mean_chain_avg    0
# 241       compliment_photos_sum_chain_avg    0
# 242      compliment_photos_mean_chain_avg    0
# 243       compliment_photos_std_chain_avg    0
# 245            elite_count_mean_chain_avg    0
# 247              Male to Female_chain_avg    0
# 251                 Low Network_chain_avg    0
# 255                 First Visit_chain_avg    0
# 256           Female Importance_chain_avg    0
# 257    Average Customer Network_chain_avg    0
# 258               Total Network_chain_avg    0
# 261                  Free Wi-Fi_chain_avg    0
# 262          Takes Reservations_chain_avg    0
# 263             Outdoor Seating_chain_avg    0
# 264                    Delivery_chain_avg    0
# 265                      Caters_chain_avg    0
# 267                       Noisy_chain_avg    0
# 271                  rating_std_chain_std    0
# 272                  rating_min_chain_std    0
# 273                  rating_sum_chain_std    0
# 274                 rating_mean_chain_std    0
# 277                  gender_min_chain_std    0
# 232         compliment_cool_sum_chain_avg    0
# 231        compliment_plain_std_chain_avg    0
# 230       compliment_plain_mean_chain_avg    0
# 213          compliment_hot_std_chain_avg    0
# 183                   cool_amin_chain_avg    0
# 184                    cool_sum_chain_avg    0
# 189                  rating_pub_chain_avg    0
# 193                std_of_stars_chain_avg    0
# 197          restaurant_density_chain_avg    0
# 202                   stars_sum_chain_avg    0
# 1                              rating_min    0
# 204                   stars_std_chain_avg    0
# 205                    fans_sum_chain_avg    0
# 206                   fans_mean_chain_avg    0
# 207                    fans_std_chain_avg    0
# 208           average_stars_sum_chain_avg    0
# 214         compliment_more_sum_chain_avg    0
# 229        compliment_plain_sum_chain_avg    0
# 215        compliment_more_mean_chain_avg    0
# 216         compliment_more_std_chain_avg    0
# 217      compliment_profile_sum_chain_avg    0
# 218     compliment_profile_mean_chain_avg    0
# 219      compliment_profile_std_chain_avg    0
# 220         compliment_cute_sum_chain_avg    0
# 223         compliment_list_sum_chain_avg    0
# 224        compliment_list_mean_chain_avg    0
# 225         compliment_list_std_chain_avg    0
# 226         compliment_note_sum_chain_avg    0
# 227        compliment_note_mean_chain_avg    0
# 228         compliment_note_std_chain_avg    0
# 405         first_min_last_sent_chain_std    0

# %% [raw]
# from lightgbm import LGBMClassifier
# lgbm = LGBMClassifier(boosting_type='gbdt', objective='binary',
#                        num_class=1,early_stopping = 50,
#                        is_enable_sparse='true',tree_learner='data',num_leaves=31,num_iteration=10000,min_data_in_leaf=100,max_depth=14,
#                        learning_rate=0.1, n_estimators=1000, max_bin=255, subsample_for_bin=500,
#                        min_split_gain=5, min_child_weight=5, min_child_samples=5, subsample=0.995,
#                        subsample_freq=1, colsample_bytree=1, reg_alpha=0,
#                        reg_lambda=0, seed=0, nthread=-1, silent=True,)
#
# lgbm.fit(X, Y, eval_set=[(X, Y)],eval_metric='AUC',
#         early_stopping_rounds=5)
#
# y_pred = lgbm.predict(X_test)
# y_pred_proba = lgbm.predict_proba(X_test)
#
# dets["y_pred_proba"].iloc[:30000] = y_pred_proba[:,0]
#
# pd.set_option("display.max_rows",None)
#
# dets_test.sort_values("y_pred_proba",ascending=False)

# %% [raw]
# import xgboost as xgb
#
# gbm = xgb.XGBClassifier(max_depth=3, n_estimators=300, learning_rate=0.05).fit(X_train,y_train)
# y_pred = gbm.predict(X_test)
# accuracy_score(y_test, y_pred)
#
# # I have to run this again because I do not think that public appears here.
#
# ga = pd.DataFrame()
#
# ga["name"] = X.columns
#
# ga["imp"] = gbm.feature_importances_
#
# ga.sort_values("imp",ascending=False)
#
# import matplotlib.pyplot as plt
# import scikitplot as skplt
# y_pred_prob = gbm.predict_proba(X_test)
#
# skplt.metrics.plot_roc_curve(y_test, y_pred_prob)
# plt.show()

# %%
from catboost import Pool, CatBoostClassifier, cv, CatboostIpythonWidget
categorical_features_indices = np.where(X_train.dtypes != np.float)[0]

model = CatBoostClassifier(iterations=1200, learning_rate=0.02, depth=7, loss_function='Logloss', eval_metric='AUC', random_seed=99, od_type='Iter', od_wait=100) 
model.fit(X_train, y_train,cat_features=categorical_features_indices,eval_set=(X_test, y_test),plot=True)

y_pred = model.predict(X_test)
y_pred_proba = model.predict_proba(X_test)
accuracy_score(y_test, y_pred)

# %%
import matplotlib.pyplot as plt
import scikitplot as skplt
y_pred_prob = model.predict_proba(X_test)

skplt.metrics.plot_roc_curve(y_test, y_pred_prob)
plt.show()
# Out:
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: The spectral and spectral_r colormap was deprecated in version 2.0. Use nipy_spectral and nipy_spectral_r instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
import numpy as np
import statsmodels.formula.api as sm
import pandas as pd
import random
import matplotlib.pyplot as plt
from sklearn import tree
import scipy.interpolate
# No. dimensions of covariates
X = X.as_matrix()
def xi(x):
    return (1+1./(1.+np.exp(-20.*(x-1./3.))))
tau = np.multiply(xi(X[:,0]),xi(X[:,1]))

# %%
def tauxy(X_0,X_1):
    return np.multiply(xi(X_0),xi(X_1))
# Quick plot of tau as function of X_1, X_2 assuming continuous support
def plotFunc(func):
    X_0 = np.linspace(0, 1, 1000)
    X_1 = np.linspace(0, 1, 1000)
    X, Y = np.meshgrid(X_0, X_1)
    Z = func(X, Y)
    plt.style.use('seaborn-white')
    plt.imshow(Z, vmin=1., vmax=4., origin='lower',
              extent=[X_0.min(), X_0.max(), X_1.min(), X_1.max()],
             cmap='plasma')
    plt.colorbar()
    plt.xlabel(r'$X_0$')
    plt.ylabel(r'$X_1$')
plotFunc(tauxy)

# %%
# Draw a random subsample of size s.
# Choose s ints between 0 and n randomly
n = len(X)
s = int(len(X)/2)
subSampleMask = random.sample(range(0, n),s )
# Create set I
setIMask = random.sample(subSampleMask, np.int(np.ceil(s/2.)))
setI = [X[setIMask]]
# Create set J
setJMask = [i for i in subSampleMask if i not in setIMask]
setJ = [X[setJMask]]

# %%
setI[0]
# Out:
# array([[1.00087630e+00, 1.00000000e+00, 2.53000000e+02, ...,
#         1.39172555e+02, 1.42675236e-01, 5.60532586e-01],
#        [1.31412216e+00, 1.00000000e+00, 2.62000000e+02, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.78885438e+00, 1.00000000e+00, 1.40000000e+01, ...,
#         1.43814635e+01, 8.52511497e-01, 1.44160089e+00],
#        ...,
#        [1.07888421e+00, 1.00000000e+00, 1.86100000e+03, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.24078930e+00, 1.00000000e+00, 7.64000000e+02, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.56477015e+00, 1.00000000e+00, 3.60000000e+02, ...,
#         6.08742426e+01, 3.75796057e-01, 2.59047939e+00]])

# %%
# Out:
# 406

# %%
d = X.shape[1]

clf = tree.DecisionTreeRegressor(criterion='mse')
clf = clf.fit(setJ[0], tau[setJMask])
tau_hat = clf.predict(pd.DataFrame(setI[0]).iloc[:,:d])
# Out of sample R^2:

clf.score(pd.DataFrame(setI[0]).iloc[:,:d],tau[setIMask])
# Out:
# 0.9995475584221319

# %%
pd.DataFrame(setI[0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-82-8ef2d77e71da> in <module>()
# ----> 1 pd.DataFrame(setI[0])
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/IPython/core/displayhook.py in __call__(self, result)
#     255             self.start_displayhook()
#     256             self.write_output_prompt()
# --> 257             format_dict, md_dict = self.compute_format_data(result)
#     258             self.update_user_ns(result)
#     259             self.fill_exec_result(result)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in _repr_html_(self)
#     667
#     668             return self.to_html(max_rows=max_rows, max_cols=max_cols,
# --> 669                                 show_dimensions=show_dimensions, notebook=True)
#     670         else:
#     671             return None
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in to_html(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, bold_rows, classes, escape, max_rows, max_cols, show_dimensions, notebook, decimal, border)
#    1732                                            decimal=decimal)
#    1733         # TODO: a generic formatter wld b in DataFrameFormatter
# -> 1734         formatter.to_html(classes=classes, notebook=notebook, border=border)
#    1735
#    1736         if buf is None:
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/io/formats/format.py in to_html(self, classes, notebook, border)
#     731                                       border=border)
#     732         if hasattr(self.buf, 'write'):
# --> 733             html_renderer.write_result(self.buf)
#     734         elif isinstance(self.buf, compat.string_types):
#     735             with open(self.buf, 'w') as f:
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/io/formats/format.py in write_result(self, buf)
#    1214         indent += self.indent_delta
#    1215         indent = self._write_header(indent)
# -> 1216         indent = self._write_body(indent)
#    1217
#    1218         self.write('</table>', indent)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/io/formats/format.py in _write_body(self, indent)
#    1377                 self._write_hierarchical_rows(fmt_values, indent)
#    1378             else:
# -> 1379                 self._write_regular_rows(fmt_values, indent)
#    1380         else:
#    1381             for i in range(min(len(self.frame), self.max_rows)):
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/io/formats/format.py in _write_regular_rows(self, fmt_values, indent)
#    1417                 row.insert(dot_col_ix, '...')
#    1418             self.write_tr(row, indent, self.indent_delta, tags=None,
# -> 1419                           nindex_levels=1)
#    1420
#    1421     def _write_hierarchical_rows(self, fmt_values, indent):
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/io/formats/format.py in write_tr(self, line, indent, indent_delta, header, align, tags, nindex_levels)
#    1139                 self.write_th(s, indent, tags=val_tag)
#    1140             else:
# -> 1141                 self.write_td(s, indent, tags=val_tag)
#    1142
#    1143         indent -= indent_delta
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/io/formats/format.py in write_td(self, s, indent, tags)
#    1104
#    1105     def write_td(self, s, indent=0, tags=None):
# -> 1106         return self._write_cell(s, kind='td', indent=indent, tags=tags)
#    1107
#    1108     def _write_cell(self, s, kind='td', indent=0, tags=None):
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/io/formats/format.py in _write_cell(self, s, kind, indent, tags)
#    1120         rs = pprint_thing(s, escape_chars=esc).strip()
#    1121         self.write(u'{start}{rs}</{kind}>'
# -> 1122                    .format(start=start_tag, rs=rs, kind=kind), indent)
#    1123
#    1124     def write_tr(self, line, indent=0, indent_delta=4, header=False,
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/io/formats/format.py in write(self, s, indent)
#    1092
#    1093     def write(self, s, indent=0):
# -> 1094         rs = pprint_thing(s)
#    1095         self.elements.append(' ' * indent + rs)
#    1096
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/io/formats/printing.py in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     216         result = _pprint_dict(thing, _nest_lvl, quote_strings=True,
#     217                               max_seq_items=max_seq_items)
# --> 218     elif (is_sequence(thing) and
#     219           _nest_lvl < get_option("display.pprint_nest_depth")):
#     220         result = _pprint_seq(thing, _nest_lvl, escape_chars=escape_chars,
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/dtypes/inference.py in is_sequence(obj)
#     422         iter(obj)  # Can iterate over it.
#     423         len(obj)   # Has a length associated with it.
# --> 424         return not isinstance(obj, string_and_binary_types)
#     425     except (TypeError, AttributeError):
#     426         return False
#
# KeyboardInterrupt:

# %%
### For me I obviously just want the fastest one, there is no reason or me to squeeze erofrmance out of this.
